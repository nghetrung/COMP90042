# %% [markdown]
# # Homework 1: Preprocessing and Text Classification

# %% [markdown]
# Student Name: Minh Trung Nguyen
#
# Student ID: 1016151

# %% [markdown]
# # General Info
#
# <b>Due date</b>: Sunday, 5 Apr 2020 5pm
#
# <b>Submission method</b>: Canvas submission
#
# <b>Submission materials</b>: completed copy of this iPython notebook
#
# <b>Late submissions</b>: -20% per day (both week and weekend days counted)
#
# <b>Marks</b>: 10% of mark for class (with 9% on correctness + 1% on quality and efficiency of your code)
#
# <b>Materials</b>: See [Using Jupyter Notebook and Python page](https://canvas.lms.unimelb.edu.au/courses/17601/pages/using-jupyter-notebook-and-python?module_item_id=1678430) on Canvas (under Modules>Resources) for information on the basic setup required for this class, including an iPython notebook viewer and the python packages NLTK, Numpy, Scipy, Matplotlib, Scikit-Learn, and Gensim. In particular, if you are not using a lab computer which already has it installed, we recommend installing all the data for NLTK, since you will need various parts of it to complete this assignment. You can also use any Python built-in packages, but do not use any other 3rd party packages (the packages listed above are all fine to use); if your iPython notebook doesn't run on the marker's machine, you will lose marks. <b> You should use Python 3</b>.
#
# To familiarize yourself with NLTK, here is a free online book:  Steven Bird, Ewan Klein, and Edward Loper (2009). <a href=http://nltk.org/book>Natural Language Processing with Python</a>. O'Reilly Media Inc. You may also consult the <a href=https://www.nltk.org/api/nltk.html>NLTK API</a>.
#
# <b>Evaluation</b>: Your iPython notebook should run end-to-end without any errors in a reasonable amount of time, and you must follow all instructions provided below, including specific implementation requirements and instructions for what needs to be printed (please avoid printing output we don't ask for). You should edit the sections below where requested, but leave the rest of the code as is. You should leave the output from running your code in the iPython notebook you submit, to assist with marking. The amount each section is worth is given in parenthesis after the instructions.
#
# You will be marked not only on the correctness of your methods, but also the quality and efficency of your code: in particular, you should be careful to use Python built-in functions and operators when appropriate and pick descriptive variable names that adhere to <a href="https://www.python.org/dev/peps/pep-0008/">Python style requirements</a>. If you think it might be unclear what you are doing, you should comment your code to help the marker make sense of it.
#
# <b>Updates</b>: Any major changes to the assignment will be announced via Canvas. Minor changes and clarifications will be announced on the discussion board; we recommend you check it regularly.
#
# <b>Academic misconduct</b>: For most people, collaboration will form a natural part of the undertaking of this homework, and we encourge you to discuss it in general terms with other students. However, this ultimately is still an individual task, and so reuse of code or other instances of clear influence will be considered cheating. We will be checking submissions for originality and will invoke the University’s <a href="http://academichonesty.unimelb.edu.au/policy.html">Academic Misconduct policy</a> where inappropriate levels of collusion or plagiarism are deemed to have taken place.

# %% [markdown]
# # Overview
#
# In this homework, you'll be working with a collection tweets. The task is to classify whether a tweet constitutes a rumour event. This homework involves writing code to preprocess data and perform text classification.

# %% [markdown]
# # 1. Preprocessing (5 marks)

# %% [markdown]
# **Instructions**: Run the code below to download the tweet corpus for the assignment. Note: the download may take some time. **No implementation is needed.**

# %%
import requests
import os
from pathlib import Path

fname = 'rumour-data.tgz'
data_dir = os.path.splitext(fname)[0] #'rumour-data'

my_file = Path(fname)
if not my_file.is_file():
    url = "https://github.com/jhlau/jhlau.github.io/blob/master/files/rumour-data.tgz?raw=true"
    r = requests.get(url)

    #Save to the current directory
    with open(fname, 'wb') as f:
        f.write(r.content)
        
print("Done. File downloaded:", my_file)

# %% [markdown]
# **Instructions**: Run the code to extract the zip file. Note: the extraction may take a minute or two. **No implementation is needed.**

# %%
import tarfile

#decompress rumour-data.tgz
tar = tarfile.open(fname, "r:gz")
tar.extractall()
tar.close()

#remove superfluous files (e.g. .DS_store)
extra_files = []
for r, d, f in os.walk(data_dir):
    for file in f:
        if (file.startswith(".")):
            extra_files.append(os.path.join(r, file))
for f in extra_files:
    os.remove(f)

print("Extraction done.")
# Out:
# Extraction done.

# %% [markdown]
# ### Question 1 (1.0 mark)
#
# **Instructions**: The corpus data is in the *rumour-data* folder. It contains 2 sub-folders: *non-rumours* and *rumours*. As the names suggest, *rumours* contains all rumour-propagating tweets, while *non-rumours* has normal tweets. Within  *rumours* and *non-rumours*, you'll find some sub-folders, each named with an ID. Each of these IDs constitutes an 'event', where an event is defined as consisting a **source tweet** and its **reactions**.
#
# An illustration of the folder structure is given below:
#
#     rumour-data
#         - rumours
#             - 498254340310966273
#                 - reactions
#                     - 498254340310966273.json
#                     - 498260814487642112.json
#                 - source-tweet
#                     - 498254340310966273.json
#         - non-rumours
#
# Now we need to gather the tweet messages for rumours and non-rumour events. As the individual tweets are stored in json format, we need to use a json parser to parse and collect the actual tweet message. The function `get_tweet_text_from_json(file_path)` is provided to do that.
#
# **Task**: Complete the `get_events(event_dir)` function. The function should return **a list of events** for a particular class of tweets (e.g. rumours), and each event should contain the source tweet message and all reaction tweet messages.
#
# **Check**: Use the assertion statements in *"For your testing"* below for the expected output.

# %%
import json

def get_tweet_text_from_json(file_path):
    with open(file_path) as json_file:
        data = json.load(json_file)
        return data["text"]
    
def get_events(event_dir):
    event_list = []
    
    # each event is the ID e.g. '498254340310966273'
    for event in sorted(os.listdir(event_dir)):
        event_temp_list = []
        
        # get the source tweet
        source = get_tweet_text_from_json(os.path.join(event_dir, event, "source-tweet", event + ".json"))
        event_temp_list.append(source)
        
        # get the reaction tweets
        # each reaction is the ID.json e.g. '498254340310966273.json'
        for reaction in sorted(os.listdir(os.path.join(event_dir, event, "reactions"))):
            react = get_tweet_text_from_json(os.path.join(event_dir, event, "reactions", reaction))
            event_temp_list.append(react)
        
        event_list.append(event_temp_list)
        
    return event_list
    
#a list of events, and each event is a list of tweets (source tweet + reactions)    
rumour_events = get_events(os.path.join(data_dir, "rumours"))
nonrumour_events = get_events(os.path.join(data_dir, "non-rumours"))

print("Number of rumour events =", len(rumour_events))
print("Number of non-rumour events =", len(nonrumour_events))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-4c9415d34867> in <module>
#      29 #a list of events, and each event is a list of tweets (source tweet + reactions)
#      30 rumour_events = get_events(os.path.join(data_dir, "rumours"))
# ---> 31 nonrumour_events = get_events(os.path.join(data_dir, "non-rumours"))
#      32
#      33 print("Number of rumour events =", len(rumour_events))
#
# <ipython-input-5-4c9415d34867> in get_events(event_dir)
#      20         # each reaction is the ID.json e.g. '498254340310966273.json'
#      21         for reaction in sorted(os.listdir(os.path.join(event_dir, event, "reactions"))):
# ---> 22             react = get_tweet_text_from_json(os.path.join(event_dir, event, "reactions", reaction))
#      23             event_temp_list.append(react)
#      24
#
# <ipython-input-5-4c9415d34867> in get_tweet_text_from_json(file_path)
#       2
#       3 def get_tweet_text_from_json(file_path):
# ----> 4     with open(file_path) as json_file:
#       5         data = json.load(json_file)
#       6         return data["text"]
#
# c:\users\nghet\appdata\local\programs\python\python36\lib\_bootlocale.py in getpreferredencoding(do_setlocale)
#       9
#      10 if sys.platform.startswith("win"):
# ---> 11     def getpreferredencoding(do_setlocale=True):
#      12         return _locale._getdefaultlocale()[1]
#      13 else:
#
# KeyboardInterrupt:

# %% [markdown]
# **For your testing:**

# %%
assert(len(rumour_events) == 500)
assert(len(nonrumour_events) == 1000)

# %% [markdown]
# ### Question 2 (1.0 mark)
#
# **Instructions**: Next we need to preprocess the collected tweets to create a bag-of-words representation. The preprocessing steps required here are: (1) tokenize each tweet into individual word tokens (using NLTK `TweetTokenizer`); and (2) remove stopwords (based on NLTK `stopwords`).
#
# **Task**: Complete the `preprocess_events(event)` function. The function takes **a list of events** as input, and returns **a list of preprocessed events**. Each preprocessed event should have a dictionary of words and frequencies.
#
# **Check**: Use the assertion statements in *"For your testing"* below for the expected output.

# %%
import nltk
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords
nltk.download('stopwords')
from collections import defaultdict, Counter

tt = TweetTokenizer()
stopwords = set(stopwords.words('english'))

def preprocess_events(events):
    preprocessed_events = []
    for event in events:
        bow = Counter()
        for tweet in event:
            tokens = tt.tokenize(tweet)
            for word in tokens:
                if word not in stopwords:
                    bow[word] = bow.get(word, 0) + 1
        preprocessed_events.append(bow)
                
    return preprocessed_events


preprocessed_rumour_events = preprocess_events(rumour_events)
preprocessed_nonrumour_events = preprocess_events(nonrumour_events)

print("Number of preprocessed rumour events =", len(preprocessed_rumour_events))
print("Number of preprocessed non-rumour events =", len(preprocessed_nonrumour_events))
# Out:
# [nltk_data] Downloading package stopwords to /Users/MAC/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Number of preprocessed rumour events = 500
# Number of preprocessed non-rumour events = 1000

# %%
preprocessed_rumour_events
# Out:
# [Counter({'Michael': 2,
#           'Brown': 2,
#           '17': 4,
#           'yr': 2,
#           'old': 4,
#           'boy': 5,
#           'shot': 7,
#           '10x': 2,
#           '&': 4,
#           'killed': 2,
#           'police': 10,
#           '#Ferguson': 3,
#           'today': 2,
#           '.': 47,
#           'Media': 2,
#           'reports': 2,
#           '"': 22,
#           'shoot': 2,
#           'man': 3,
#           '#blackboysonly': 2,
#           '@AmeenaGK': 38,
#           '@jaythenerdkid': 3,
#           'And': 1,
#           'long': 1,
#           'conservative': 1,
#           'pundit': 1,
#           'finds': 1,
#           'pic': 1,
#           'messing': 1,
#           'around': 2,
#           'friends': 1,
#           'ID': 1,
#           '@d_m_elms': 2,
#           "they'll": 1,
#           'drag': 1,
#           'entire': 1,
#           'history': 1,
#           'every': 2,
#           'stolen': 1,
#           'sip': 1,
#           "dad's": 1,
#           'beer': 1,
#           ',': 17,
#           'second-hand': 1,
#           'tendril': 1,
#           'pot': 1,
#           'smoke': 1,
#           'watch': 1,
#           'traces': 1,
#           'back': 6,
#           'bogus': 1,
#           'allegations': 1,
#           'something': 1,
#           'kindergarten': 1,
#           'All': 2,
#           'justify': 1,
#           'dangerous': 1,
#           'CHILD': 1,
#           'KILLED': 1,
#           'TO': 1,
#           'PROTECT': 1,
#           'CANDY': 1,
#           'headline': 1,
#           '@CyMadD0x': 6,
#           'An': 1,
#           'unarmed': 1,
#           'black': 8,
#           'year': 2,
#           'cops': 2,
#           'instead': 1,
#           'fellow': 1,
#           'blacks': 1,
#           '...': 2,
#           'Better': 1,
#           'make': 2,
#           'national': 1,
#           'news': 1,
#           'You': 2,
#           'know': 2,
#           'right': 2,
#           '?': 15,
#           'Also': 1,
#           'libertarian': 1,
#           'siding': 1,
#           'pigs': 1,
#           '@PsychicDogTalk': 6,
#           'pointing': 1,
#           'double': 1,
#           'Standard': 1,
#           'violence': 3,
#           'barely': 1,
#           'reported': 2,
#           "I'm": 1,
#           'screaming': 1,
#           'racism': 1,
#           'The': 2,
#           'reason': 1,
#           'nobody': 1,
#           'gives': 1,
#           'shit': 1,
#           'poor': 1,
#           'people': 3,
#           'kill': 1,
#           "It's": 1,
#           'leftist': 1,
#           'conspiracy': 1,
#           'seem': 2,
#           'less': 1,
#           'violent': 1,
#           '#tinfoilin': 1,
#           '=p': 1,
#           'democrats': 1,
#           'run': 1,
#           'days': 2,
#           '#racism': 1,
#           'sexism': 1,
#           'communism': 1,
#           'I': 5,
#           'hope': 1,
#           'incident': 1,
#           'captured': 1,
#           'camera': 1,
#           '#Trayvon': 1,
#           'tru': 1,
#           'marginlized': 1,
#           'grps': 1,
#           'nyc': 1,
#           'try': 1,
#           'reporting': 1,
#           'gay': 1,
#           'domestic': 1,
#           'bed': 1,
#           'stuy': 1,
#           'meant': 1,
#           'MSM': 1,
#           'report': 2,
#           'NYPD': 1,
#           'point': 1,
#           'taken': 1,
#           '@justinstoned': 1,
#           'msm': 1,
#           "that's": 1,
#           'cable': 1,
#           '@RaavynnDigitaL': 2,
#           'quaint': 1,
#           'men': 3,
#           'boys': 1,
#           'saying': 1,
#           'would': 2,
#           'get': 1,
#           'trouble': 1,
#           "they're": 1,
#           'thugs': 1,
#           'fucking': 1,
#           'joke': 1,
#           '@retrocombine': 16,
#           'Was': 1,
#           'six': 1,
#           'feet': 1,
#           '200lbs': 1,
#           '@kevinwmiller': 12,
#           "i'm": 1,
#           'sure': 1,
#           'matters': 2,
#           "he's": 2,
#           'still': 2,
#           'underage': 1,
#           "He's": 1,
#           'young': 1,
#           '@TrueNameBrand': 1,
#           'must': 1,
#           'racist': 1,
#           'notice': 1,
#           '#WarOnWomen': 1,
#           'stopping': 1,
#           'us': 1,
#           'getting': 1,
#           'equal': 1,
#           'pay': 1,
#           'Does': 1,
#           'excuse': 1,
#           'ten': 1,
#           'times': 1,
#           'Ten': 1,
#           'To': 1,
#           'protect': 1,
#           'candy': 1,
#           'Boy': 1,
#           'Racist': 1,
#           '18': 1,
#           'assaulted': 1,
#           'officer': 2,
#           'Even': 1,
#           'case': 3,
#           'warrant': 1,
#           '8': 1,
#           'bullets': 2,
#           'agree': 2,
#           'consider': 1,
#           'excessive': 1,
#           'force': 1,
#           'Yeah': 1,
#           'Just': 1,
#           'sit': 1,
#           'wait': 1,
#           'facts': 1,
#           'See': 1,
#           'really': 1,
#           'happened': 4,
#           'may': 2,
#           'resolve': 1,
#           'one': 1,
#           "there's": 3,
#           'larger': 2,
#           'problem': 3,
#           'needs': 1,
#           'addressed': 1,
#           'According': 1,
#           'CBS': 1,
#           'http://t.co/Joj9cniAE4': 1,
#           'Two': 2,
#           'struggled': 1,
#           'pushes': 1,
#           'went': 2,
#           'sidearm': 1,
#           'Weapon': 1,
#           'fired': 3,
#           'inside': 2,
#           'car': 4,
#           'shots': 1,
#           'outside': 1,
#           'Where': 1,
#           'eight': 1,
#           "That's": 2,
#           'mother': 1,
#           'says': 1,
#           ';': 1,
#           'even': 1,
#           'chief': 1,
#           'said': 1,
#           'couple': 1,
#           'http://t.co/iUTZSW8ZgE': 1,
#           'understand': 1,
#           'jumping': 1,
#           'conclusions': 1,
#           'turning': 1,
#           'everything': 1,
#           'race': 4,
#           'war': 2,
#           'Of': 1,
#           'course': 1,
#           'upset': 1,
#           'son': 1,
#           'dead': 1,
#           'It': 2,
#           'matter': 1,
#           'fault': 1,
#           'regardless': 1,
#           'whether': 1,
#           "something's": 1,
#           'serious': 1,
#           'racial': 1,
#           'issues': 2,
#           'US': 1,
#           'bring': 1,
#           'major': 1,
#           'This': 1,
#           'racially': 1,
#           'motivated': 2,
#           'seemed': 1,
#           'like': 1,
#           'criminal': 1,
#           'trying': 1,
#           'take': 1,
#           'officers': 1,
#           'gun': 2,
#           'got': 2,
#           'If': 3,
#           'pushed': 2,
#           'cop': 2,
#           "I'd": 2,
#           'assume': 1,
#           'Me': 1,
#           'white': 1,
#           'reaction': 1,
#           'brought': 1,
#           'lot': 1,
#           'racially-motivated': 1,
#           'events': 1,
#           'light': 1,
#           'idea': 1,
#           'deal': 1,
#           'specific': 1,
#           'much': 1,
#           'What': 1,
#           'BEFORE': 1,
#           'story': 1,
#           'How': 1,
#           'else': 1}),
#  Counter({'17': 3,
#           'year': 3,
#           'old': 3,
#           'unarmed': 3,
#           'kid': 3,
#           'shot': 3,
#           'ten': 4,
#           'times': 4,
#           'police': 5,
#           'stealing': 6,
#           'candy': 9,
#           '.': 28,
#           'I': 7,
#           'know': 4,
#           'punishable': 5,
#           'death': 5,
#           '(': 3,
#           'read': 3,
#           '#ferguson': 4,
#           'tag': 3,
#           ')': 3,
#           'No': 1,
#           'excuse': 2,
#           '“': 1,
#           '@inthefade': 18,
#           ':': 1,
#           '@AnneMarieFlynn2': 2,
#           '@adam_zander': 1,
#           'This': 3,
#           'unbelievable': 1,
#           ',': 8,
#           "there's": 1,
#           '@divineem': 1,
#           'It': 2,
#           'applies': 1,
#           'Black': 1,
#           'people': 1,
#           'story': 2,
#           'makes': 1,
#           'physically': 1,
#           'sick': 1,
#           '@marieann66': 1,
#           'http://t.co/PDo2pakAln': 1,
#           '@Alllwftopic': 1,
#           'Agreed': 1,
#           '!': 4,
#           'Should': 1,
#           'charged': 1,
#           'w': 1,
#           '/': 1,
#           'murder': 1,
#           '@Alasscan_': 3,
#           'apparently': 1,
#           '@JackieWillard2': 1,
#           'These': 1,
#           'days': 1,
#           'anything': 1,
#           'especially': 1,
#           'Stand': 1,
#           'Your': 1,
#           'Ground': 1,
#           'even': 2,
#           'sneeze': 1,
#           'true': 1,
#           "It's": 1,
#           'not-unless': 1,
#           'happen': 1,
#           'black': 3,
#           'male': 1,
#           'apparently.We': 1,
#           'make': 1,
#           'far': 1,
#           'accountable': 1,
#           "can't": 1,
#           'go': 1,
#           'We': 1,
#           'stole': 2,
#           'proof': 1,
#           'guess': 1,
#           'skittles': 1,
#           'become': 1,
#           'reason': 1,
#           'kill': 1,
#           'teens': 1,
#           '@pjhnsn8': 1,
#           'going': 1,
#           'early': 1,
#           'last': 1,
#           'night': 1,
#           "Wasn't": 1,
#           'real': 1,
#           'news': 1,
#           'point': 1,
#           'understand': 1,
#           'changed': 1,
#           'cigs': 1,
#           'tussle': 1,
#           'car': 1,
#           'saggy': 1,
#           'pants': 1,
#           'maybe': 1,
#           'never': 1,
#           'truthful': 1,
#           '#Shot': 1,
#           '?': 1,
#           'God': 1,
#           'mercy': 1,
#           '@Smilingl8dy': 1,
#           'say': 1,
#           '"': 2,
#           'allegedly': 1,
#           'Also': 1,
#           'stmt': 1,
#           'mention': 1,
#           'cause': 1,
#           'someone': 1,
#           'starts': 1,
#           'assaulting': 1,
#           'officer': 1,
#           'He': 2,
#           '18': 1,
#           'Nothing': 1,
#           'walking': 1,
#           'street': 1,
#           'Horrible': 1,
#           'situation': 1,
#           'But': 1,
#           'stop': 1,
#           'spreading': 1,
#           'false': 1,
#           'facts': 1,
#           '@klemosy': 1,
#           'Anything': 1,
#           'youth': 1}),
#  Counter({'White': 1,
#           'man': 1,
#           'aiming': 1,
#           'police': 1,
#           '...': 1,
#           'nothing': 1,
#           'happens': 1,
#           '.': 2,
#           'Unarmed': 1,
#           'black': 1,
#           'kid': 1,
#           'walking': 1,
#           'back': 1,
#           'store': 1,
#           'shot': 1,
#           '10': 1,
#           'times': 1,
#           '#Ferguson': 1,
#           'http://t.co/48EcUF2Bwa': 1}),
#  Counter({'Teenager': 2,
#           '#MikeBrown': 3,
#           'start': 3,
#           'college': 3,
#           'Monday': 3,
#           'shot': 4,
#           'ten': 4,
#           'times': 5,
#           '#Ferguson': 4,
#           'police': 7,
#           'officer': 3,
#           '.': 29,
#           'http://t.co/B4hWevO7l9': 2,
#           '@YourAnonGlobal': 22,
#           'What': 2,
#           'Mike': 2,
#           '?': 12,
#           '@ArmyBulldog20': 2,
#           'walking': 2,
#           'black': 3,
#           '@YourAnonNews': 10,
#           'Can': 1,
#           'give': 1,
#           'link': 2,
#           'I': 9,
#           'read': 3,
#           'please': 1,
#           '@TefPoe': 1,
#           'WTF': 1,
#           'Is': 1,
#           'real': 1,
#           '@sweden': 7,
#           'St': 1,
#           'Louis': 1,
#           'Post': 1,
#           'Dispatch': 1,
#           'story': 4,
#           ':': 2,
#           'http://t.co/I6hatQKNWI': 1,
#           'Apparently': 1,
#           'shoplifted': 1,
#           'candy': 1,
#           'bar': 1,
#           'Eyewitness': 1,
#           'report': 1,
#           'Post-Dispatch': 1,
#           'says': 1,
#           'Brown': 1,
#           'fled': 1,
#           'put': 1,
#           'car': 1,
#           '>': 1,
#           'Which': 1,
#           'probably': 1,
#           'good': 1,
#           'idea': 1,
#           ',': 6,
#           'way': 1,
#           'deserve': 1,
#           'getting': 1,
#           'killed': 1,
#           '@RedwoodGirl': 4,
#           'Oh': 1,
#           'god': 1,
#           'For': 1,
#           'shoplifting': 1,
#           'This': 1,
#           'awful': 2,
#           '!': 2,
#           'Thank': 1,
#           'Yes': 1,
#           'event': 1,
#           'Check': 1,
#           'hashtag': 1,
#           'lots': 1,
#           'anger': 1,
#           'sadness': 1,
#           "what's": 1,
#           'sad': 1,
#           'posting': 1,
#           'picture': 1,
#           'poor': 1,
#           'kid': 1,
#           'dead': 2,
#           'means': 1,
#           'nothing': 1,
#           'Thanks': 2,
#           'help': 2,
#           'Glad': 1,
#           'could': 1,
#           'Are': 1,
#           'really': 1,
#           'Sweden': 1,
#           'The': 1,
#           'US': 1,
#           'must': 1,
#           'seem': 1,
#           'barbaric': 1,
#           'Europeans': 1,
#           'stories': 1,
#           'like': 2,
#           ':(': 1,
#           'Well': 1,
#           'things': 2,
#           'bad': 2,
#           'But': 1,
#           'much': 2,
#           '@Renemies': 1,
#           'http://t.co/W1n9bYASlc': 1,
#           '@youranonglobal': 1,
#           '@youranonnews': 1,
#           'http://t.co/cFWVhcZMx1': 2,
#           '@armybulldog20': 2,
#           'Ten': 1,
#           'many': 1,
#           '“': 1,
#           'http://t.co/FABNrZ9iCQ': 1,
#           '”': 1,
#           '@2squig': 2,
#           'holy': 1,
#           'crap': 1,
#           '...': 1,
#           'teen': 1,
#           '"': 2,
#           'Black': 1,
#           'Like': 1,
#           'Me': 1,
#           'progressed': 1,
#           '@billthenewguy': 1,
#           'Racism': 1,
#           'dumb': 1,
#           'gets': 1,
#           "We're": 1,
#           'race': 1,
#           '(': 1,
#           'human': 1,
#           ')': 1,
#           '@7um9_': 2,
#           'Should': 1,
#           'thank': 1,
#           'worries': 1,
#           '@cannotthinkwhy': 1,
#           '10': 1,
#           'bloody': 1,
#           'shots': 1,
#           'someone': 1,
#           'Bionic': 1,
#           'man': 2,
#           'Or': 1,
#           'overkill': 1,
#           '@TonyMoule47': 1,
#           'Looks': 1,
#           'cops': 1,
#           'feel': 1,
#           'free': 1,
#           'shoot': 1,
#           'kill': 1,
#           'target': 1,
#           'doubt': 1,
#           "we'll": 1,
#           'see': 1,
#           'cop': 1,
#           'jailed': 1,
#           'Same': 1,
#           'age': 1,
#           'son': 1,
#           '@I_hate_it_here_': 1,
#           'everybody': 1,
#           'knows': 1,
#           "'": 2,
#           'serious': 1,
#           'crime': 1,
#           'racist': 1,
#           'Obvs': 1,
#           '&': 1,
#           'UK': 1,
#           'Home': 1,
#           'Office': 1,
#           'relaxed': 1,
#           'routinely': 1,
#           'arming': 1,
#           'definitely': 1,
#           'think': 1,
#           '@robert_veres': 1,
#           "Brown's": 1,
#           'family': 1,
#           'wish': 1,
#           'post': 1,
#           'pictures': 1,
#           'body': 1,
#           'thx': 1,
#           '@cosmiclandmine': 1,
#           'There': 1,
#           'may': 1,
#           'little': 1,
#           "I'll": 1,
#           'wait': 1,
#           'pass': 1,
#           'judgement': 1,
#           'It': 1,
#           'always': 1,
#           'person': 1,
#           'dies': 1}),
#  Counter({'Supposedly': 1,
#           'might': 1,
#           'one': 1,
#           'two': 1,
#           'witnesses': 1,
#           'shooting': 2,
#           'part': 1,
#           'recorded': 1,
#           'phones': 1,
#           '.': 1,
#           '#Ferguson': 1}),
#  Counter({'St': 1,
#           '.': 1,
#           'Louis': 1,
#           ':': 1,
#           'Unarmed': 1,
#           'teenager': 1,
#           '#MikeBrown': 1,
#           'shot': 1,
#           'ten': 1,
#           'times': 1,
#           '#Ferguson': 1,
#           'police': 1,
#           'officer': 1,
#           'accusation': 1,
#           'shoplifting': 1,
#           'http://t.co/cmaG8mnMiP': 1}),
#  Counter({'Witness': 3,
#           ':': 4,
#           'Police': 5,
#           'allegedly': 3,
#           'stopped': 3,
#           'Mike': 3,
#           'Brown': 3,
#           'yelling': 3,
#           'walk': 4,
#           'sidewalk': 3,
#           '.': 15,
#           '#Ferguson': 3,
#           'http://t.co/XG00R6w0k6': 2,
#           '@MichaelSkolnik': 21,
#           'cool': 1,
#           '!': 11,
#           'Darkskinned': 1,
#           'man': 1,
#           'crime': 1,
#           'element': 1,
#           'village': 2,
#           '?': 10,
#           'So': 1,
#           ',': 9,
#           '#obama': 1,
#           'alive': 1,
#           'yet': 1,
#           'Another': 1,
#           'win': 1,
#           'gene': 1,
#           'pool': 1,
#           '@Agent_Kindi': 6,
#           '@Supreme___Power': 6,
#           'These': 1,
#           'responses': 1,
#           'explain': 1,
#           'thiskeeps': 1,
#           'happening': 1,
#           'Too': 1,
#           'many': 3,
#           'white': 3,
#           'men': 2,
#           'hate': 1,
#           'black': 2,
#           'Sad': 1,
#           '@TimmyTurnUp': 5,
#           'fuck': 1,
#           'Is': 4,
#           'anyone': 1,
#           'streets': 1,
#           'knife': 1,
#           'gun': 1,
#           'U': 2,
#           'want': 1,
#           'say': 1,
#           '"': 2,
#           'guilty': 1,
#           'In': 3,
#           'Moscow': 1,
#           'guys': 2,
#           'sold': 1,
#           'drugs': 1,
#           '...': 1,
#           '@AC_BOwen': 6,
#           '#Cleveland': 6,
#           'Any': 1,
#           'Excuse': 1,
#           'Will': 1,
#           'Do': 1,
#           'A': 4,
#           'Chase': 1,
#           '11-29-': 2,
#           '12': 4,
#           '~': 10,
#           '#2UnarmedBLACKS': 1,
#           '#MURDERED': 3,
#           'By': 1,
#           '#13RACISTCOPS': 1,
#           '#137GUNSHOTS': 1,
#           '@CivilRights': 2,
#           '#MalissaWilliamsAndTimothyRussell': 2,
#           'Were': 1,
#           'Shot': 2,
#           'Up': 2,
#           '#UNARMED': 1,
#           'Of': 2,
#           '#13RacistCops': 2,
#           '#NotCHARGED': 2,
#           '#GOOGLE': 1,
#           'Shoot': 1,
#           '137': 1,
#           'Times': 1,
#           '<': 10,
#           '#MURDERING': 1,
#           '#2UNARMEDBLACKS': 2,
#           'They': 1,
#           'Have': 1,
#           'Many': 1,
#           '#UNARMEDBLACKS': 2,
#           'The': 5,
#           'Case': 1,
#           'Was': 2,
#           'Being': 1,
#           'Covered': 1,
#           'Mayor': 1,
#           'On': 1,
#           'Cops': 1,
#           'Sides': 1,
#           'Got': 1,
#           'No': 1,
#           '#Justice': 1,
#           '#BlackLifeMatters': 1,
#           'Cop': 2,
#           '19yr': 1,
#           'Old': 1,
#           'Head': 1,
#           '#Black': 1,
#           '#Unarmed': 1,
#           '#MomsOnlyChild': 1,
#           'Said': 1,
#           'He': 3,
#           '#THOUGHT': 1,
#           'Saw': 1,
#           'Gun': 1,
#           '@SecretService': 2,
#           'I': 1,
#           "Don't": 1,
#           'Like': 3,
#           'His': 1,
#           'Tweet': 1,
#           'Asking': 1,
#           'Why': 2,
#           '#Obama': 3,
#           'Alive': 2,
#           'Yet': 1,
#           '#WePray': 1,
#           '#SecretService': 2,
#           'Protects': 1,
#           '#PresidentObama': 1,
#           "Get's": 1,
#           'Threats': 1,
#           'All': 1,
#           'Time': 1,
#           'It': 1,
#           'People': 1,
#           'You': 3,
#           'That': 1,
#           '#MURDER': 1,
#           'Ask': 1,
#           'Still': 1,
#           '#RACIST': 1,
#           '#KKK': 1,
#           '#SMH': 1,
#           '@Progress4Ohio': 2,
#           "I'm": 2,
#           'glad': 1,
#           'amigo': 1,
#           'love': 1,
#           'president': 1,
#           'kills': 1,
#           'children': 1,
#           'Ukrain': 1,
#           'Gaza': 1,
#           'places': 1,
#           ';-)': 2,
#           'RACIST': 1,
#           'We': 1,
#           'live': 1,
#           'together': 1,
#           '200': 1,
#           'nations': 1,
#           'Russia': 1,
#           'And': 1,
#           'go': 1,
#           'words': 1,
#           'mucacho': 1,
#           '“': 1,
#           'http://t.co/TYdMSNxGlo': 1,
#           '”': 1,
#           'edgy': 1,
#           'If': 1,
#           'u': 1,
#           'think': 1,
#           'something': 1,
#           'another': 1,
#           'says': 1,
#           'somehow': 1,
#           'hold': 1,
#           'back': 1,
#           'loser': 1,
#           '&': 1,
#           'deserve': 1,
#           'failure': 1,
#           'White': 2,
#           'jealous': 1,
#           '@ValMackinnon': 1,
#           'perfect': 1,
#           ')': 2,
#           'Daniel': 1,
#           'Craig': 1,
#           'throw': 1,
#           'GF': 1,
#           'window': 1,
#           'girls': 1,
#           'smart': 1}),
#  Counter({'.': 34,
#           '@NBCNews': 19,
#           'I': 6,
#           'demand': 2,
#           'retract': 2,
#           'lie': 2,
#           '#Ferguson': 2,
#           'people': 2,
#           'shouting': 2,
#           '"': 14,
#           'Kill': 2,
#           'police': 2,
#           'Reporters': 2,
#           'scene': 3,
#           'refuted': 2,
#           '@QuadCityPat': 23,
#           'Yes': 1,
#           ',': 10,
#           'tell': 1,
#           '@AP': 4,
#           '&': 1,
#           '@blackvoices': 4,
#           '!': 12,
#           'It': 2,
#           'divisive': 1,
#           'propaganda': 1,
#           'Oh': 1,
#           'ISH': 1,
#           'So': 1,
#           '@NBC': 1,
#           'lied': 1,
#           '?': 7,
#           'The': 1,
#           'media': 1,
#           'must': 1,
#           'narrative': 1,
#           'Unarmed': 1,
#           'blk': 1,
#           'boy': 1,
#           'shot': 1,
#           '10': 1,
#           'times': 1,
#           'cut': 1,
#           '4': 2,
#           '@KMBTweets': 3,
#           'AP': 1,
#           'conservative': 1,
#           'bias': 1,
#           '#liberalmediamyfoot': 1,
#           'link': 1,
#           'local': 2,
#           'reporters': 2,
#           'refuting': 1,
#           "I'm": 1,
#           'working': 1,
#           'piece': 1,
#           'would': 1,
#           'like': 1,
#           'include': 1,
#           'Thanks': 1,
#           '@kileykroh': 5,
#           'links': 1,
#           'specific': 1,
#           'looking': 1,
#           'video': 1,
#           'protests.They': 1,
#           'saying': 1,
#           'No': 3,
#           'Justice': 1,
#           'Peace': 1,
#           'And': 1,
#           'Stop': 1,
#           'Killing': 1,
#           'Us': 1,
#           'yeah': 1,
#           'hoping': 1,
#           'find': 1,
#           'something': 1,
#           'someone': 1,
#           'ground': 1,
#           'retweeted': 1,
#           'vine': 1,
#           'shows': 1,
#           'chanting': 1,
#           'Hey': 1,
#           'hey': 1,
#           'ho': 2,
#           'killer': 2,
#           'cops': 3,
#           'got': 1,
#           'go': 1,
#           'thank': 1,
#           'tweet': 1,
#           'God': 1,
#           'bless': 1,
#           'seems': 1,
#           'small': 1,
#           'step': 1,
#           'mishearing': 1,
#           'kill': 1,
#           'For': 1,
#           'worth': 1,
#           '@_MylesHigh': 1,
#           'anything': 1,
#           'promote': 1,
#           'fear': 1,
#           'huh': 1,
#           '#Sad': 1,
#           '“': 1,
#           'Get': 1,
#           'Out': 1,
#           'Town': 1,
#           'Cracker': 1,
#           '”': 1,
#           'sprayed': 1,
#           'white': 1,
#           'man': 1,
#           '’': 1,
#           'burnt-down': 1,
#           'house': 1,
#           'March': 1,
#           '28': 1,
#           '2014': 2,
#           'CRIME': 2,
#           '/': 3,
#           'IS': 2,
#           '..': 3,
#           'REGARDLESS': 1,
#           '@Donna_West': 1,
#           ':': 2,
#           "That's": 1,
#           'LYING': 1,
#           'ASS': 1,
#           'MEDIA': 1,
#           'ya': 1,
#           'Blacks': 1,
#           'beat': 1,
#           'Matthew': 1,
#           'Boorujuy': 1,
#           'death': 2,
#           'calling': 1,
#           'cracker': 1,
#           'May': 1,
#           'NO': 1,
#           'KILLING': 1,
#           'RIGHT': 1,
#           'W': 1,
#           'BLACK.BLK/WHITE': 1,
#           '@Conservativrulz': 6,
#           'fuck': 2,
#           'outta': 1,
#           'troll': 1,
#           '#scram': 1,
#           'Parity': 1,
#           'HOW': 1,
#           'THE': 2,
#           'FUCK': 1,
#           'DOES': 1,
#           'IT': 2,
#           'WORK': 1,
#           '#moron': 1,
#           'Heh': 1,
#           'She': 1,
#           'shares': 1,
#           'name': 1,
#           'birth': 1,
#           'control': 1,
#           'pill': 1,
#           'AH': 1,
#           'SHARPTON': 1,
#           'field': 1,
#           'day': 1,
#           "He's": 1,
#           'biggest': 1,
#           'racists': 1,
#           'planet': 2,
#           '...': 1,
#           '@SharonMelendes': 1,
#           'ignorance': 1,
#           '>': 4,
#           'JUST': 1,
#           'CONSERVATIVES': 1,
#           'KILL': 1,
#           'PEOPLE': 1,
#           'GEEESH': 1,
#           'YEP': 1,
#           'BUSH': 1,
#           'DID': 1,
#           '@3ChicsPolitico': 1,
#           '@nbc': 1,
#           'George': 1,
#           'Bush': 1,
#           'Of': 1,
#           'course': 1,
#           'LORD': 1,
#           'IGNORANCE': 1,
#           'Ok': 1,
#           'idiot': 2,
#           'compare': 1,
#           'vandalism': 2,
#           'shooting': 1,
#           'gets': 1,
#           'vote': 1,
#           "You're": 1,
#           'comparing': 1,
#           'murder': 1,
#           'Eff': 1,
#           'life': 1,
#           'Media': 1,
#           'always': 1,
#           'falsely': 1,
#           'reported': 1,
#           'racial': 1,
#           'issues': 1,
#           'keep': 1,
#           'races': 1,
#           'America': 1,
#           'divided': 1,
#           'Division': 1,
#           'wks': 1,
#           '1': 1,
#           '%': 1,
#           '@adbridgeforth': 1,
#           'Exactly': 1,
#           'justice': 1,
#           'peace': 1,
#           '@daiconrad': 1,
#           'thanks': 1,
#           'included': 1,
#           'http://t.co/hUi26I5oZZ': 1}),
#  Counter({'So': 2,
#           'last': 2,
#           'week': 2,
#           'NYPD': 2,
#           'tried': 2,
#           'tell': 2,
#           'us': 5,
#           '#EricGarner': 2,
#           'chokehold': 2,
#           ',': 3,
#           '#Ferguson': 2,
#           'police': 2,
#           'telling': 3,
#           '#MikeBrown': 3,
#           'assaulted': 2,
#           'officer': 2,
#           '@SoulRevision': 2,
#           'Even': 1,
#           'true': 1,
#           '(': 1,
#           'almost': 1,
#           'definitely': 1,
#           ')': 1,
#           "that's": 1,
#           'excuse': 1,
#           'execute': 1,
#           'street': 1,
#           '.': 1,
#           '@zellieimani': 1,
#           'They': 1,
#           'lies': 1,
#           'Sunday': 1}),
#  Counter({'So': 3,
#           '#Ferguson': 2,
#           'Police': 2,
#           'afford': 7,
#           'machine': 3,
#           'guns': 3,
#           "can't": 3,
#           'dash': 2,
#           'cameras': 3,
#           'squad': 2,
#           'cars': 3,
#           '?': 5,
#           '#interesting': 2,
#           '#MikeBrown': 3,
#           '@unpreachedtruth': 14,
#           '@TheAnonMessage': 8,
#           "they're": 1,
#           'still': 2,
#           'boxes': 2,
#           'chief': 1,
#           'police': 1,
#           'said': 1,
#           'last': 1,
#           'night': 1,
#           'got': 1,
#           '.': 17,
#           "that's": 1,
#           'important': 1,
#           'ready': 1,
#           'slaughter': 1,
#           'people': 1,
#           'think': 1,
#           'rights': 1,
#           'That': 1,
#           'proves': 1,
#           'never': 2,
#           'thought': 1,
#           'purchased': 1,
#           'installed': 3,
#           '@norwind': 2,
#           'huh': 1,
#           '@BallerinaX': 1,
#           '1033': 1,
#           'program': 1,
#           ',': 6,
#           'rifles': 1,
#           'probably': 1,
#           'cost': 1,
#           'less': 1,
#           'body': 1,
#           'cams': 1,
#           '@Wanderer19': 3,
#           'Protecting': 1,
#           'serving': 2,
#           'right': 1,
#           '@vdogg9': 1,
#           'open': 2,
#           '@runsammrun': 2,
#           'smh': 1,
#           'install': 1,
#           'sure': 1,
#           'I': 2,
#           'read': 2,
#           'matter': 1,
#           'laziness': 1,
#           '/': 4,
#           'disorganization': 1,
#           'carelessness': 1,
#           '@DaleGunn3': 1,
#           'They': 3,
#           'protecting': 1,
#           'Clearly': 1,
#           '#smh': 1,
#           "That's": 1,
#           'crazy': 1,
#           'seem': 1,
#           'disorganized': 1,
#           'came': 1,
#           'preparing': 1,
#           'riots': 1,
#           'ha': 1,
#           'stakes': 1,
#           'higher': 1,
#           '@rockermom53': 2,
#           '|': 2,
#           'video': 2,
#           'patrol': 1,
#           'make': 1,
#           '&': 3,
#           'audio': 1,
#           'recording': 1,
#           'contact': 1,
#           'public': 1,
#           'suspect': 1,
#           'But': 1,
#           'LOT': 1,
#           'fire': 1,
#           'power': 1,
#           'small': 1,
#           'city': 1,
#           'Agree': 1,
#           'plenty': 1,
#           'war-hardware': 1,
#           'need': 1,
#           'focus': 1,
#           'ppl': 1,
#           'skills': 1,
#           'train': 1,
#           'serve': 1,
#           'protect': 1,
#           'Like': 1,
#           'pro-gunners': 1,
#           'find': 1,
#           '$': 1,
#           'AR': 1,
#           '-': 1,
#           '15s': 1,
#           'claim': 1,
#           'mandatory': 1,
#           'gun': 1,
#           'insurance': 1,
#           'would': 1,
#           'financial': 1,
#           'hardship': 1,
#           '@deBeauxOs1': 1,
#           'well': 1,
#           'least': 1,
#           'bothered': 1,
#           'take': 1,
#           'box': 1}),
#  Counter({'Line': 1,
#           'police': 1,
#           'cars': 1,
#           'high': 1,
#           'beams': 1,
#           'greets': 1,
#           'anyone': 1,
#           'trying': 1,
#           'enter': 1,
#           '#Ferguson': 2,
#           '.': 14,
#           "It's": 1,
#           'shut': 1,
#           'No': 1,
#           'media': 1,
#           'allowed': 1,
#           'http://t.co/bk6jFFM7jj': 1,
#           '@AnonymousPress': 14,
#           "that's": 1,
#           'last': 2,
#           'night': 2,
#           'Not': 1,
#           'tonight': 1,
#           'Yeah': 1,
#           'Land': 1,
#           'Free': 1,
#           'My': 1,
#           'A': 1,
#           '%': 1,
#           '&': 1,
#           'Why': 1,
#           'I': 1,
#           'reminded': 1,
#           'Tienanmen': 1,
#           'Square': 1,
#           'These': 1,
#           'pigs': 1,
#           'need': 1,
#           'taken': 1,
#           '!': 3,
#           '@CFormigoni5': 1,
#           'Chef': 1,
#           'board': 1,
#           'photo': 1,
#           '?': 6,
#           'Please': 1,
#           'clarify': 1,
#           'using': 1,
#           'present': 1,
#           'tense': 1,
#           'cop': 1,
#           'shoots': 1,
#           'unarmed': 1,
#           'black': 1,
#           'man': 2,
#           ',': 3,
#           'citizens': 1,
#           'start': 1,
#           'looting': 1,
#           'burning': 1,
#           'community.is': 1,
#           'make': 1,
#           'sense': 1,
#           'Freedom': 1,
#           'press': 1,
#           'ass': 1,
#           'Is': 1,
#           'Ferguson': 1,
#           'joining': 1,
#           'Russia': 1,
#           'China': 1,
#           'communist': 1,
#           'style': 1,
#           'governance': 1,
#           'The': 1,
#           'cops': 1,
#           'calling': 1,
#           'protesters': 1,
#           'animals': 1,
#           'And': 2,
#           'FAA': 1,
#           'declared': 1,
#           'no-fly': 1,
#           'zone': 1,
#           'guys': 1,
#           'boneheads': 1,
#           '~': 1,
#           '>': 1,
#           'Gaza': 1,
#           'Iraq': 1,
#           'Soon': 1,
#           'burst': 1,
#           'homes': 1,
#           'rape': 1,
#           'babies': 1,
#           'force': 1,
#           'mothers': 1,
#           'watch': 1,
#           'tyranny': 1,
#           '...': 1,
#           'Beuller': 1,
#           'fuck': 1}),
#  Counter({'Before': 9,
#           'death': 9,
#           '#MikeBrown': 9,
#           'told': 10,
#           'mother': 10,
#           ',': 10,
#           '"': 22,
#           'The': 9,
#           'world': 9,
#           'know': 10,
#           '#MichaelBrown': 9,
#           '!': 10,
#           '#Ferguson': 9,
#           '@BridjesONeil': 16,
#           '@AntonioFrench': 3,
#           'naaaaaaawwwww': 1,
#           'real': 2,
#           '?': 4,
#           '😞': 2,
#           '“': 6,
#           ':': 7,
#           '”': 6,
#           'Sounds': 1,
#           'like': 2,
#           'something': 1,
#           'someone': 1,
#           'kamikaze': 1,
#           'mission': 1,
#           'would': 1,
#           'say': 1,
#           '.': 11,
#           'sounds': 2,
#           'bullshit': 1,
#           '...': 2,
#           'sigh': 1,
#           '@xbreakingeven': 1,
#           'It': 2,
#           'little': 1,
#           'made': 1,
#           ':(': 1,
#           '@GingePurps': 1,
#           'His': 1,
#           'spoken': 1,
#           'tonight': 1,
#           'Another': 1,
#           'speaker': 1,
#           'shared': 1,
#           'information': 1,
#           "must've": 1,
#           'Seriously': 1,
#           'I': 3,
#           'doubt': 1,
#           'Maybe': 1,
#           'likely': 1,
#           'love': 2,
#           'ya': 1,
#           'momma': 1,
#           '@saramarietweets': 1,
#           'regardless': 1,
#           'We': 2,
#           'always': 1,
#           'known': 1,
#           'child': 1,
#           'another': 1,
#           'morn': 1,
#           '@Donna_West': 2,
#           'gonna': 1,
#           'call': 1,
#           'big': 1,
#           'probably': 1,
#           'one': 1,
#           'meaning': 1,
#           "can't": 1,
#           'imagine': 1,
#           'anyone': 1,
#           'outside': 1,
#           'movie': 1,
#           'saying': 1,
#           'thing': 1,
#           'Speechless': 1,
#           'RT': 1,
#           '@nellbernstein': 1,
#           'heart': 1,
#           'wrenching': 1,
#           'Holy': 1,
#           'Moly': 1,
#           'amazing': 1,
#           'قال': 1,
#           'زو': 1,
#           'الثمانية': 1,
#           'عشر': 1,
#           'لوالدته': 1,
#           'قبل': 1,
#           'مقتله': 1,
#           'بيد': 1,
#           'الشرطي': 1,
#           'الامريكي': 1,
#           'سيعلم': 1,
#           'العالم': 1,
#           'من': 1,
#           'هو': 1,
#           'ً': 1,
#           'ميكي': 1,
#           'براون': 1}),
#  Counter({'Currently': 3,
#           '#FoxNews': 4,
#           'website': 4,
#           'zero': 3,
#           ',': 19,
#           'repeat': 2,
#           'ZERO': 2,
#           'coverage': 4,
#           '#Ferguson': 3,
#           'protests': 2,
#           'probably': 2,
#           'due': 2,
#           'lack': 3,
#           'cowboy': 2,
#           'hats': 2,
#           '.': 27,
#           '@clydetheslyde': 39,
#           'Shocking': 1,
#           '...': 4,
#           'Earlier': 1,
#           'segment': 1,
#           'TV': 1,
#           'asking': 1,
#           'black': 4,
#           'America': 1,
#           'would': 3,
#           'anything': 1,
#           'stop': 1,
#           'looting': 1,
#           'Ferguson': 2,
#           'They': 2,
#           'obsessed': 1,
#           'Michelle': 2,
#           'Obama': 2,
#           "'": 3,
#           'derrière': 1,
#           '#perverts': 1,
#           'get': 1,
#           '"': 4,
#           'tread': 1,
#           'flags': 1,
#           'fox': 1,
#           'go': 1,
#           'Too': 1,
#           'busy': 1,
#           'bitching': 1,
#           'POTUS': 1,
#           'sure': 1,
#           '“': 1,
#           ':': 4,
#           '/': 2,
#           'three': 1,
#           'wise': 1,
#           'monkeys': 1,
#           'commented': 1,
#           'see': 1,
#           'evil': 3,
#           'hear': 1,
#           'speak': 1,
#           'Na': 1,
#           'many': 3,
#           'people': 3,
#           'care': 2,
#           'There': 1,
#           'plenty': 1,
#           'world': 1,
#           'cover': 2,
#           'instead': 1,
#           'focusing': 1,
#           'one': 2,
#           "woman's": 1,
#           'ass': 1,
#           'assholes': 1,
#           'FOXNEWS': 1,
#           'major': 1,
#           'reason': 1,
#           'stupid': 1,
#           'cops': 1,
#           'give': 1,
#           'damn': 1,
#           'life': 1,
#           'young': 2,
#           'kids': 1,
#           'Thanks': 1,
#           '4': 1,
#           'going': 1,
#           'us': 1,
#           'wonder': 1,
#           '✌': 1,
#           '️': 1,
#           'No': 1,
#           'surprises': 1,
#           'really': 4,
#           'articles': 1,
#           'ran': 1,
#           'car': 1,
#           'fast': 1,
#           '@michael_flinch': 7,
#           'fact': 1,
#           'dig': 1,
#           'find': 1,
#           'problem': 1,
#           'headline': 1,
#           'news': 2,
#           'http://t.co/0LKOR9MyqV': 1,
#           '#Bengazie': 1,
#           "It's": 2,
#           'gots': 1,
#           'loose': 1,
#           'weight': 1,
#           'butt': 1,
#           '#gross': 1,
#           '@smeezi': 6,
#           'turn': 1,
#           'Fox': 2,
#           'News': 1,
#           'yeh': 1,
#           'dont': 1,
#           'want': 2,
#           'watch': 1,
#           'shitty': 1,
#           'programming': 1,
#           'believe': 1,
#           'headlining': 1,
#           'even': 1,
#           'homepage': 1,
#           'foxnews': 2,
#           'tho': 1,
#           'actually': 1,
#           'interesting': 1,
#           'say': 1,
#           '?': 5,
#           'conservative': 1,
#           'taking': 1,
#           'different': 1,
#           'pov': 1,
#           'I': 4,
#           'talking': 1,
#           'Plus': 1,
#           'dude': 1,
#           'joke': 1,
#           'Get': 1,
#           '!': 7,
#           'http://t.co/shgRwLx9Ww': 1,
#           'yikes': 1,
#           'Their': 1,
#           'cameras': 1,
#           "can't": 1,
#           'focus': 1,
#           'brown': 1,
#           'Yikes': 1,
#           'indeed': 1,
#           '@GrooveSDC': 1,
#           'hillbilly': 1,
#           'viewers': 1,
#           'start': 1,
#           'thinking': 1,
#           'race': 2,
#           'war': 1,
#           'finally': 1,
#           'started': 1,
#           'yet': 2,
#           '#FOXNEWS': 1,
#           '@mchenthompson': 1,
#           "Isn't": 1,
#           'truth': 1,
#           'property': 2,
#           'damage': 1,
#           'On': 1,
#           '>': 1,
#           'missing': 1,
#           'pretty': 1,
#           'blonde': 1,
#           'white': 4,
#           'girl': 1,
#           'right': 2,
#           'remain': 1,
#           'silent': 1,
#           'ended': 1,
#           'http://t.co/SErbzckzdX': 1,
#           'My': 1,
#           'column': 1,
#           'AN': 1,
#           'EXECUTION': 1,
#           'IN': 2,
#           'FERGUSON': 1,
#           'http://t.co/bh8fgwu3gZ': 1,
#           '#ferguson': 1,
#           '#michaelbrown': 1,
#           '#policebrutality': 1,
#           '@SacJim2012': 4,
#           'release': 1,
#           'name': 1,
#           'cop': 1,
#           'shooting': 2,
#           '&': 3,
#           'spoke': 1,
#           'witnesses': 1,
#           '..': 11,
#           '#BuyingTime': 1,
#           'already': 1,
#           "f'd": 1,
#           '#different': 1,
#           'accounts': 1,
#           'happened': 1,
#           '#dirtyTruth': 1,
#           'come': 1,
#           'light': 1,
#           '@my2bits4u': 2,
#           '@DMeralles': 1,
#           'http://t.co/u8QxZ0Dv60': 1,
#           '@graceslick77': 3,
#           'Buying': 1,
#           'Time': 1,
#           'Protect': 1,
#           'Racist': 2,
#           'Murdering': 1,
#           'Cop': 1,
#           '#Sick': 2,
#           '#Coward': 1,
#           'know': 2,
#           "that's": 1,
#           'hoping': 1,
#           'god': 1,
#           '#Someone': 1,
#           'captured': 1,
#           'phone': 1,
#           '+': 2,
#           'came': 1,
#           'forward': 1,
#           '-': 1,
#           '(': 1,
#           'video': 1,
#           ')': 1,
#           'If': 1,
#           'Jail': 1,
#           'Rogue': 1,
#           'Cops': 1,
#           'Stop': 1,
#           'Killing': 1,
#           'Unarmed': 1,
#           'Black': 1,
#           'Men': 1,
#           'raised': 1,
#           'hater': 1,
#           ';': 1,
#           'knew': 1,
#           'wrong-always.But': 1,
#           'baffles': 1,
#           'w': 1,
#           '#Diversity': 1,
#           'creation': 1,
#           'ppl': 1,
#           'hate': 1,
#           'rt': 1,
#           '#HatersHate': 1,
#           '#LiarsLie': 1,
#           'tragic': 1,
#           '@mylifeishid': 4,
#           '#MikeBrown': 1,
#           'need': 2,
#           'shot': 1,
#           '#Benghazi': 1,
#           '#foxnews': 1,
#           '@mechphree': 3,
#           'Nicely': 1,
#           'played': 1,
#           'sir': 1,
#           'FOX': 1,
#           'HAS': 1,
#           'BECOME': 1,
#           'A': 1,
#           'REPUBLICAN': 1,
#           'POLITICIANS': 1,
#           'INFOMERCIAL': 1,
#           "ISN'T": 1,
#           'REALLY': 1,
#           'INTERESTED': 1,
#           'REAL': 1,
#           'NEWS': 1,
#           'BOYCOTT': 1,
#           '@moiskd': 1,
#           'Imagine': 1,
#           'folks': 1,
#           'strutting': 1,
#           'around': 1,
#           "AR's": 1,
#           'Think': 1,
#           'Perry': 1,
#           'Hannity': 1,
#           'hunkered': 1,
#           'solidarity': 1,
#           'Your': 1,
#           'tweet': 1,
#           'makes': 1,
#           'page': 1,
#           'stronger': 1,
#           'http://t.co/QNABzh699U': 1,
#           '@Madaza41': 2,
#           'remember': 1,
#           'type': 1,
#           'invaded': 1,
#           'Iraq': 1,
#           'Boots': 2,
#           'ground': 2,
#           'Cont': 1,
#           'Who': 1,
#           'cares': 1,
#           'We': 1,
#           'Brittney': 1,
#           'Spears': 1,
#           'blobs': 1,
#           'Or': 2,
#           'old': 2,
#           'rich': 1,
#           'Senator': 1,
#           'Good': 1,
#           'exactly': 1,
#           'expected': 1,
#           'liar': 1,
#           'http://t.co/CZk1kFS41Q': 1}),
#  Counter({'The': 7,
#           'ferguson': 3,
#           'chief': 4,
#           'says': 3,
#           'feelings': 6,
#           'hurt': 4,
#           'ppl': 6,
#           'consider': 3,
#           'part': 4,
#           'problem': 5,
#           '.': 69,
#           '#ferguson': 2,
#           'http://t.co/VoJGrMOPbZ': 2,
#           '@WyzeChef': 59,
#           'What': 1,
#           'SMOKING': 1,
#           '?': 6,
#           'He': 2,
#           'cannot': 1,
#           'stupid': 1,
#           '“': 3,
#           ':': 1,
#           'http://t.co/HUlpIqjoFL': 1,
#           '”': 2,
#           '-': 2,
#           'lol': 1,
#           '@radicalhearts': 1,
#           'wow': 1,
#           '...': 5,
#           'Making': 1,
#           'feel': 2,
#           'feels': 1,
#           'teen': 1,
#           'murdered': 1,
#           '!': 5,
#           '@AdmireLaniya__': 41,
#           'White': 1,
#           'people': 14,
#           'love': 2,
#           'victim': 3,
#           'card': 2,
#           "They've": 1,
#           'making': 2,
#           'whole': 2,
#           'situation': 2,
#           'focusing': 1,
#           'looting': 3,
#           '@TheBlackVoice': 1,
#           'serious': 1,
#           'They': 3,
#           'oblivious': 1,
#           'damn': 1,
#           'near': 1,
#           'hilarious': 1,
#           '@OberstabKrieger': 2,
#           'I': 23,
#           'think': 2,
#           'effective': 1,
#           'But': 4,
#           "I'm": 2,
#           'going': 2,
#           'judge': 3,
#           'live': 1,
#           'If': 5,
#           'happened': 1,
#           'neighborhood': 1,
#           "can't": 2,
#           'promise': 2,
#           'want': 1,
#           'tear': 1,
#           'something': 1,
#           '@xianb8': 1,
#           'story': 1,
#           'kid': 3,
#           'attacking': 1,
#           'cop': 2,
#           'reason': 1,
#           'way': 1,
#           "grandmother's": 1,
#           'house': 1,
#           'makes': 1,
#           'much': 1,
#           'sense': 1,
#           'Red': 1,
#           'Riding': 1,
#           'Hood': 1,
#           'black': 2,
#           ',': 9,
#           'media': 2,
#           '/': 2,
#           'cops': 2,
#           "would've": 1,
#           'put': 1,
#           'wolf': 2,
#           'paid': 1,
#           'vacation': 1,
#           '&': 1,
#           'talked': 1,
#           'tearz': 1,
#           '@tklowenstein': 1,
#           '#Ferguson': 2,
#           'officially': 1,
#           'favorite': 1,
#           'use': 1,
#           'thinks': 1,
#           'relevant': 1,
#           'job': 1,
#           "that's": 3,
#           'probably': 1,
#           '@Principia': 4,
#           'bummer': 1,
#           '…': 3,
#           'So': 5,
#           'since': 1,
#           'start': 1,
#           'could': 1,
#           'My': 1,
#           'officers': 1,
#           '’': 1,
#           'go': 2,
#           'around': 2,
#           'gratuitously': 2,
#           'shooting': 2,
#           'bragging': 1,
#           'seedy': 1,
#           'paramilitary': 1,
#           'bars': 1,
#           '"': 7,
#           'agonize': 1,
#           'social': 1,
#           'write': 1,
#           'poetry': 1,
#           'Art': 1,
#           'srsly': 1,
#           'Douglas': 1,
#           'Adams': 1,
#           'called': 1,
#           '@ShannonLeeKiss': 26,
#           "That's": 2,
#           'pot': 1,
#           'calling': 1,
#           'kettle': 1,
#           'Please': 1,
#           'thing': 2,
#           'reverse': 2,
#           "It's": 5,
#           'white': 9,
#           ':)': 1,
#           '@LibertyIsALady': 10,
#           'doubt': 1,
#           '♥': 1,
#           'many': 4,
#           'buy': 1,
#           'racism': 2,
#           'farce': 1,
#           '@joshmhump': 17,
#           'see': 2,
#           'young': 1,
#           'man': 1,
#           'know': 2,
#           'one': 2,
#           'Never': 1,
#           'said': 3,
#           'replying': 1,
#           'racist': 2,
#           'comment': 3,
#           'It': 1,
#           'seems': 2,
#           'non': 1,
#           'Black': 1,
#           'focused': 1,
#           'civil': 1,
#           'disturbances': 1,
#           'dead': 1,
#           'awful': 2,
#           'self': 1,
#           'centered': 1,
#           'affected': 1,
#           'would': 5,
#           'never': 2,
#           'happen': 1,
#           'really': 1,
#           'seem': 1,
#           'care': 1,
#           'upsetting': 1,
#           'officer': 1,
#           'held': 1,
#           'accountable': 1,
#           'action': 1,
#           'Absolutely': 1,
#           'unfortunate': 1,
#           'lived': 1,
#           'react': 1,
#           'differently': 1,
#           'interested': 1,
#           'raking': 1,
#           'protesters': 1,
#           'coals': 1,
#           'instead': 1,
#           'looking': 1,
#           'caused': 1,
#           'reaction': 1,
#           'Thanks': 1,
#           'listening': 1,
#           'We': 4,
#           'respond': 1,
#           'crime': 2,
#           "what's": 3,
#           'right': 3,
#           'Even': 1,
#           'though': 1,
#           'difficult': 1,
#           'This': 1,
#           'country': 1,
#           'need': 2,
#           'racial': 1,
#           'division': 1,
#           'Americans': 1,
#           'agree': 2,
#           'hope': 1,
#           'Ferguson': 1,
#           'PD': 1,
#           'comes': 1,
#           'conclusion': 2,
#           'sure': 1,
#           'BTW': 1,
#           'felt': 1,
#           'judged': 1,
#           'skin': 1,
#           'color': 1,
#           'boo': 1,
#           'fucking': 1,
#           'hoo': 1,
#           'join': 1,
#           'club': 1,
#           'Advocate': 1,
#           'PoC': 1,
#           'stop': 1,
#           'thinking': 2,
#           'You': 1,
#           'recognize': 1,
#           'friend': 2,
#           'believe': 1,
#           'solution': 1,
#           'everyone': 1,
#           'Well': 1,
#           'And': 2,
#           'done': 1,
#           'anything': 1,
#           'prove': 1,
#           'whatever': 1,
#           'means': 1,
#           'u': 2,
#           'r': 2,
#           'tweeting': 1,
#           'w': 1,
#           'ur': 1,
#           'side': 2,
#           'yet': 1,
#           'condemned': 1,
#           'us': 2,
#           'C': 1,
#           'Your': 1,
#           'anger': 1,
#           'understandable': 1,
#           'generalized': 1,
#           'judgement': 1,
#           'shame': 1,
#           '@petee224': 9,
#           'Yes': 1,
#           'Because': 1,
#           'blessing': 2,
#           'thankful': 1,
#           'generalization': 3,
#           'condescending': 1,
#           'always': 1,
#           'stand': 2,
#           'together': 1,
#           'http://t.co/f4lkRMjFMU': 1,
#           'exactly': 1,
#           'lose': 1,
#           'purpose': 1,
#           'tweet': 1,
#           'RahRahing': 2,
#           'genrlztn': 1,
#           'advocating': 1,
#           'meaningless': 1,
#           'harmless': 1,
#           'prejudice': 2,
#           'advocate': 1,
#           'saying': 1,
#           'every': 1,
#           'person': 1,
#           'clearly': 1,
#           'personally': 1,
#           'individuals': 1,
# ...
#           'If': 1,
#           'making': 1,
#           'Islam': 1,
#           'seem': 1,
#           'movie': 1,
#           'Invasion': 1,
#           'Body': 1,
#           'Snatchers': 1,
#           'It': 2,
#           'makes': 1,
#           'stop': 1,
#           'using': 1,
#           'brain': 1,
#           '@IL4me': 1,
#           'True': 1,
#           'would': 1,
#           '@cox24563': 1,
#           'Michael': 1,
#           'Mannheimer': 1,
#           'break': 1,
#           'story': 1,
#           'His': 1,
#           'website': 1,
#           'doesnt': 1,
#           'react': 1,
#           '@th_christine': 1,
#           'claim': 1,
#           'work': 1,
#           'place': 1,
#           'violence': 1,
#           'Obama': 1,
#           'Me': 1,
#           'way': 1,
#           'world': 1,
#           'Leftists': 1,
#           'truth': 1,
#           'NOT': 1,
#           'LIES': 1,
#           'different': 1,
#           'faiths': 1,
#           'unlike': 1,
#           'RIGHT': 1,
#           '#USURY': 1,
#           'TREASON': 1,
#           'dumb': 1,
#           'masses': 1,
#           '@JackJolis': 1}),
#  Counter({'Report': 6,
#           ':': 12,
#           'Germanwings': 6,
#           'Co-Pilot': 6,
#           'Treated': 5,
#           'For': 6,
#           'Depression': 6,
#           'http://t.co/ewynIJ23A2': 1,
#           '@nprnews': 20,
#           'This': 2,
#           'embarrassing': 1,
#           ',': 24,
#           'racist': 1,
#           'ableist': 1,
#           'otherwise': 1,
#           'appalling': 1,
#           'reporting': 1,
#           '.': 29,
#           'What': 1,
#           'u': 1,
#           'know': 1,
#           'That': 2,
#           'thought': 1,
#           'beginning': 1,
#           'Along': 1,
#           '~': 1,
#           '6': 1,
#           '%': 1,
#           'global': 1,
#           'population': 1,
#           'apparently': 1,
#           'must': 1,
#           'pointed': 1,
#           'NOT': 1,
#           'flown': 1,
#           'planes': 1,
#           'mountainsides': 1,
#           'Inform': 1,
#           '!': 4,
#           'Please': 1,
#           'participate': 1,
#           'sensationalism': 1,
#           'stigmatise': 1,
#           'depression': 4,
#           '@justincapps': 1,
#           'exactly': 1,
#           'stigmatizing': 1,
#           'mental': 2,
#           'illness': 2,
#           'THis': 1,
#           'time': 1,
#           'cost': 1,
#           '@amras': 1,
#           'Came': 1,
#           'say': 1,
#           'Tweets': 1,
#           'powerful': 1,
#           'statements': 1,
#           'convey': 1,
#           'far': 1,
#           '140': 1,
#           'characters': 1,
#           'whether': 1,
#           'intended': 1,
#           'So': 1,
#           'else': 1,
#           'going': 1,
#           'forbid': 1,
#           'people': 5,
#           '?': 6,
#           "I'd": 1,
#           'like': 1,
#           'list': 1,
#           '-': 1,
#           "I've": 1,
#           'diagnosed': 1,
#           'since': 1,
#           'I': 4,
#           'teen': 1,
#           '“': 5,
#           'received': 1,
#           '18': 1,
#           'months': 1,
#           'psychiatric': 1,
#           'treatment': 1,
#           'http://t.co/UaNq0REgiP': 1,
#           '”': 4,
#           'Raise': 1,
#           'virtual': 1,
#           'hand': 3,
#           'killed': 1,
#           '🙋': 1,
#           '#nostigma': 1,
#           'MT': 2,
#           'Tx': 1,
#           'Some': 1,
#           'may': 1,
#           'mentally': 1,
#           'ill': 1,
#           ';': 1,
#           'murderers': 1,
#           'But': 1,
#           'things': 1,
#           'go': 1,
#           'story': 1,
#           'serves': 1,
#           'airlines': 1,
#           'bc': 1,
#           'blames': 1,
#           'something': 1,
#           'identifiable': 1,
#           'ppl': 1,
#           'feel': 1,
#           'safe': 1,
#           'even': 1,
#           'thing': 1,
#           'cause': 1,
#           'http://t.co/38qVFIkC5v': 1,
#           'OK': 1,
#           'http://t.co/6R9oHad22d”@JonRottenberg': 1,
#           '#depression': 1,
#           'Cue': 1,
#           'bashing': 1,
#           'http://t.co/2CEYFKu69M': 1,
#           '1': 1,
#           'He': 1,
#           'flying': 1,
#           '2': 2,
#           'Foreign': 1,
#           'carriers': 1,
#           'STILL': 1,
#           'cabin': 1,
#           'times': 1,
#           'policy': 1,
#           'Why': 1,
#           '@MorningEdition': 4,
#           'relevant': 1,
#           'let': 2,
#           '’': 4,
#           'careful': 2,
#           'If': 2,
#           'red': 2,
#           'flag': 2,
#           'end': 2,
#           'one': 4,
#           'fly': 2,
#           'drive': 2,
#           'buses': 1,
#           'teach': 2,
#           'kids': 1,
#           'etc': 2,
#           "LET'S": 1,
#           'STIGMATIZE': 1,
#           'THIS': 1,
#           'INCREDIBLY': 1,
#           'COMMON': 1,
#           'ILLNESS': 1,
#           '@david_burns': 5,
#           'real': 1,
#           'question': 1,
#           'WHY': 1,
#           'many': 1,
#           'Americans': 1,
#           'depressed': 1,
#           'Cant': 1,
#           'contributed': 1,
#           'chemical': 1,
#           'embalance': 1,
#           '@SPLaws': 2,
#           'Germans': 1,
#           'evidently': 1,
#           'Or': 1,
#           'least': 1,
#           'right': 2,
#           'David': 1,
#           'jumped': 1,
#           'As': 1,
#           'citizen': 1,
#           'overactive': 1,
#           'imagination': 1,
#           'pilot': 1,
#           '4': 1,
#           'reasons': 1,
#           'TBD': 1,
#           'point': 1,
#           'worry': 1,
#           'knee-jerk': 1,
#           'over-reactions': 1,
#           'Not': 1,
#           "we're": 1,
#           'prone': 1,
#           'America': 1,
#           'anything': 1,
#           'Wow': 1,
#           'yeah': 1,
#           'NPR': 1,
#           "I'm": 1,
#           'chewing': 1,
#           'bit': 1,
#           '...': 1,
#           'Good': 1,
#           'call': 1,
#           'DB': 1,
#           'You': 1,
#           'paint': 1,
#           'rather': 1,
#           'fine': 1,
#           'portrait': 1,
#           'type': 1,
#           'large': 1,
#           'brush': 1,
#           'use': 1,
#           'whitewash': 1,
#           'barn': 1}),
#  Counter({'#Germanwings': 1,
#           '#CoPilot': 1,
#           'recent': 1,
#           'Muslim': 4,
#           'convert': 1,
#           'well': 1,
#           'psychiatric': 1,
#           'patient': 1,
#           '.': 24,
#           '#ISIS': 1,
#           'lauding': 1,
#           'hero': 1,
#           'http://t.co/J29Y3tDjOP': 1,
#           '@Zone6Combat': 20,
#           'Noooooooooooooooo': 1,
#           'Who': 1,
#           'would': 1,
#           'EVER': 1,
#           'thought': 1,
#           'great': 1,
#           'fact': 1,
#           'checking': 1,
#           'idiots': 2,
#           '@ellepuntopi': 3,
#           'È': 1,
#           'bellissimo': 1,
#           'che': 1,
#           'mettono': 1,
#           'la': 1,
#           'foto': 1,
#           'dove': 1,
#           "c'è": 1,
#           'scritto': 1,
#           '"': 4,
#           'known': 2,
#           'terrorist': 4,
#           'asserendo': 1,
#           'il': 1,
#           'contrario': 1,
#           '@DanOClunaigh': 4,
#           'Find': 1,
#           'article': 1,
#           ',': 13,
#           'complete': 1,
#           'w': 2,
#           '/': 2,
#           'screenshots': 1,
#           'personal': 1,
#           'Facebook': 2,
#           'acct': 1,
#           'Jihadist': 1,
#           'rhetoric': 1,
#           'calling': 1,
#           'ppl': 1,
#           '@SimZombie': 1,
#           'Not': 1,
#           'watch': 1,
#           'list': 1,
#           'mean': 1,
#           'jihadist': 1,
#           'sympathies': 1,
#           'beliefs': 1,
#           'better': 1,
#           'yet': 1,
#           'link': 1,
#           'ridiculous': 1,
#           'tweet': 1,
#           'everyone': 1,
#           'read': 2,
#           'The': 2,
#           "'": 2,
#           'Andreas': 1,
#           'Lubitz': 1,
#           'Fans': 1,
#           'page': 2,
#           'set': 1,
#           'brainless': 1,
#           'fool': 1,
#           'variety': 1,
#           'agent': 1,
#           'provocateur': 1,
#           "It's": 1,
#           'As': 2,
#           'say': 1,
#           '#facepalm': 1,
#           'Yeah': 1,
#           "I'm": 3,
#           'delusional': 1,
#           'one': 2,
#           'He': 1,
#           '10': 1,
#           'mins': 1,
#           'microphone': 1,
#           'whole': 1,
#           'world': 2,
#           'listening': 1,
#           'voice': 1,
#           'recorder': 1,
#           'political': 2,
#           'message': 1,
#           '?': 6,
#           'could': 1,
#           'aimed': 1,
#           'plane': 1,
#           'Sagrada': 1,
#           'Familia': 1,
#           'Trade': 1,
#           'Center': 1,
#           'Barcelona': 1,
#           'come': 1,
#           'WHERE': 1,
#           'speak': 1,
#           "Let's": 1,
#           'see': 1,
#           'needs': 1,
#           'evidence': 5,
#           '!': 1,
#           'Um': 1,
#           'yes': 1,
#           'terrorism': 2,
#           'definition': 1,
#           'Lack': 1,
#           'substantial': 2,
#           'motives': 3,
#           'means': 1,
#           'found': 1,
#           'Yep': 1,
#           'sound': 1,
#           'logic': 1,
#           '...': 1,
#           'investigation': 1,
#           'works': 1,
#           'among': 1,
#           'professionals': 1,
#           'hysterical': 1,
#           'islamophobes': 1,
#           'actually': 1,
#           'kidding': 1,
#           'Please': 1,
#           'point': 2,
#           'Evidence': 1,
#           'pls': 1,
#           'Even': 1,
#           'bit': 1,
#           '::': 2,
#           ':': 3,
#           'yawn': 1,
#           'http://t.co/NjBemt7cHo': 1,
#           '@OkKelly22': 3,
#           "there's": 1,
#           'absolutely': 1,
#           'copilot': 1,
#           'either': 2,
#           'Now': 1,
#           'getting': 1,
#           'back': 1,
#           'absence': 1,
#           'ANY': 1,
#           'assertions': 1,
#           'groundless': 1,
#           'make': 1,
#           "Didn't": 1,
#           'assume': 1,
#           'u': 2,
#           'thread': 1,
#           'saw': 1,
#           'tiresome': 1,
#           'word': 1,
#           'mention': 1,
#           'pilot': 1,
#           'r': 1,
#           'non': 1,
#           'curious': 1,
#           'concerns': 1,
#           'implication': 1,
#           'Islamic': 1,
#           'involvement': 2,
#           'I': 1,
#           'concern': 1,
#           'Islamist': 1,
#           'looks': 1,
#           'like': 1,
#           'good': 1,
#           'European': 1,
#           'Christian': 1,
#           'anything': 1}),
#  Counter({'GERMAN': 1,
#           'NEWS': 1,
#           'REPORT': 1,
#           ':': 1,
#           'Co-Pilot': 1,
#           'Germanwings': 1,
#           'Airbus': 1,
#           'Was': 1,
#           'MUSLIM': 1,
#           'CONVERT': 1,
#           '…': 1,
#           '’': 2,
#           'Hero': 1,
#           'Islamic': 1,
#           'State': 1,
#           '?': 4,
#           'http://t.co/Pw2kxje31m': 1,
#           'via': 1,
#           '@gatewaypundit': 8,
#           '@jjauthor': 7,
#           'knew': 2,
#           'scarf': 1,
#           'wearing': 1,
#           'photo': 1,
#           'meant': 1,
#           'trouble': 1,
#           '!': 3,
#           '.': 6,
#           'I': 3,
#           'Those': 1,
#           'crazy': 1,
#           'bastards': 1,
#           'ones': 1,
#           'evil': 1,
#           'enough': 1,
#           'shit': 1,
#           'like': 1,
#           'terrorism': 1,
#           'Hmmm.Doesn': 1,
#           "'": 1,
#           'pundit': 1,
#           'mean': 1,
#           'joke': 1,
#           'seen': 1,
#           'news': 1,
#           "Isn't": 1,
#           'Islam': 1,
#           'wonderfully': 1,
#           'peaceful': 2,
#           'religion': 1,
#           'wonder': 1,
#           'Iran': 1,
#           'centrifuges': 1,
#           'O': 1,
#           'gave': 1,
#           '@DesireeAaron': 1,
#           'surprise': 1,
#           'MSM': 1,
#           'refuses': 1,
#           'say': 1,
#           'muslim': 2,
#           'Just': 1,
#           'mental': 1,
#           'case': 1,
#           'As': 1,
#           '/': 1,
#           'jihads': 1}),
#  Counter({'BREAKING': 1,
#           ':': 1,
#           'German': 1,
#           'Media': 1,
#           'Site': 1,
#           'Says': 1,
#           'Germanwings': 2,
#           'Co-Pilot': 1,
#           'Was': 1,
#           'Muslim': 3,
#           'Convert': 1,
#           'http://t.co/bTKvcLMN60': 1,
#           'via': 1,
#           '@anyclinic': 24,
#           '@RWSurferGirl': 25,
#           'mental': 2,
#           'illness': 1,
#           'girlfriend': 2,
#           'discovered': 1,
#           "he's": 1,
#           'convert': 1,
#           'I': 3,
#           'question': 1,
#           'relevancy': 1,
#           'religion': 1,
#           'stability': 1,
#           ',': 8,
#           'Is': 2,
#           'claim': 2,
#           'radicalism': 1,
#           '?': 4,
#           "I've": 1,
#           'seen': 1,
#           'several': 1,
#           'smaller': 1,
#           'websites': 1,
#           'proclaim': 1,
#           'thing': 1,
#           '.': 12,
#           "I'm": 2,
#           'waiting': 1,
#           'confirmation': 1,
#           'retweeting': 1,
#           'legit': 1,
#           'news': 1,
#           'sight': 1,
#           'It': 1,
#           'looks': 1,
#           'suspicious': 1,
#           'true': 3,
#           'said': 1,
#           'cover': 1,
#           'incompetence': 1,
#           'confused': 1,
#           'read': 2,
#           'suffering': 1,
#           'depression': 1,
#           '&': 1,
#           'DRs': 1,
#           'notes': 1,
#           'excusing': 1,
#           'work': 1,
#           '@JohnnyUtah27': 4,
#           "it'll": 1,
#           'awhile': 1,
#           'let': 1,
#           'little': 1,
#           'jewel': 1,
#           '!': 6,
#           'dam': 1,
#           'thought': 1,
#           'muslim': 1,
#           'wonder': 1,
#           'depreased': 1,
#           '@CedarStArt': 2,
#           'Hah': 1,
#           'Literally': 1,
#           'first': 2,
#           'word': 1,
#           'plane': 1,
#           'crash': 1,
#           '"': 2,
#           'Not': 1,
#           'terrorism': 1,
#           'Time': 1,
#           'tell': 1,
#           '@MrJamieD': 2,
#           "can't": 1,
#           'sain': 1,
#           'cut': 1,
#           'heads': 1,
#           'would': 2,
#           'know': 1,
#           'thirty': 1,
#           'seconds': 1,
#           '...': 2,
#           '@weekiwachee03': 2,
#           'In': 1,
#           'fairness': 1,
#           'muslims': 1,
#           'story': 1,
#           'unsubstantiated': 1,
#           'croc': 1,
#           'source': 1,
#           '154': 1,
#           'followers': 1,
#           '@FredSanford13': 2,
#           'A': 1,
#           'good': 1,
#           'rumor': 1,
#           'start': 1,
#           'somewhere': 1,
#           'probably': 2,
#           'nonsense': 2,
#           'though': 1,
#           'yup': 1,
#           'painting': 1,
#           'narrative': 1,
#           'They': 1,
#           'well': 1,
#           'embarrassing': 1,
#           'conservative': 1,
#           'sites': 1,
#           'publish': 1,
#           'makes': 1,
#           'look': 1,
#           'like': 2,
#           'daily': 1,
#           'kos': 1,
#           'yes': 1,
#           'No': 1,
#           'Way': 1,
#           '😵': 1,
#           'Especially': 1,
#           'since': 2,
#           'posts': 1,
#           'twitter': 1,
#           'BS': 1,
#           'nothing': 1,
#           'taken': 2,
#           'granted': 1,
#           'find': 1,
#           'suicide': 1,
#           'revelation': 1,
#           'Screenshots': 1,
#           'social': 1,
#           'media': 1,
#           'enough': 1,
#           'turns': 1,
#           'guy': 1,
#           'handle': 1,
#           'losing': 1,
#           'job': 1,
#           'dumping': 1,
#           'added': 1,
#           'problem': 1,
#           '..': 2,
#           'man': 1,
#           'sick': 1,
#           'allowed': 1,
#           'fly': 1,
#           'doctor': 1,
#           'mentioned': 1,
#           'proactive': 1,
#           '@SoTrophyHntrs': 2,
#           "It's": 1,
#           'legitimate': 1,
#           '@rwsurfergirl': 2,
#           "'": 1,
#           'honesty': 1,
#           '@pbanik': 1,
#           'Away': 1,
#           'troll': 1,
#           'If': 1,
#           'trolls': 1,
#           '/': 1,
#           'follow': 1,
#           'Some': 1,
#           'tweets': 1,
#           'based': 1,
#           'dishonesty': 1})]

# %% [markdown]
# **For your testing**:

# %%
assert(len(preprocessed_rumour_events) == 500)
assert(len(preprocessed_nonrumour_events) == 1000)

# %% [markdown]
# **Instructions**: Hashtags (i.e. topic tags which start with #) pose an interesting tokenisation problem because they often include multiple words written without spaces or capitalization. Run the code below to collect all unique hashtags in the preprocessed data. **No implementation is needed.**

# %%
def get_all_hashtags(events):
    hashtags = set([])
    for event in events:
        for word, frequency in event.items():
            if word.startswith("#"):
                hashtags.add(word)
    return hashtags

hashtags = get_all_hashtags(preprocessed_rumour_events + preprocessed_nonrumour_events)
print("Number of hashtags =", len(hashtags))
# Out:
# Number of hashtags = 1829

# %%
hashtags
# Out:
# {'#EatADick',
#  '#Dudelove',
#  '#furgeson',
#  '#Fascism',
#  '#катасрофа',
#  '#energy',
#  '#terrorizing',
#  '#info4',
#  '#NESARA',
#  '#LiarsLie',
#  '#WE',
#  '#Islamic_State',
#  '#NewsCorpse',
#  '#pnpcbc',
#  '#unitedbywings',
#  '#frustrating',
#  '#VictimHood',
#  '#Facepalm',
#  '#OneBastardBitesTheDust',
#  '#punintended',
#  '#thewholeworldiswatching',
#  '#Yeah',
#  '#Armour',
#  "#Ferguson'da",
#  '#FascistCops',
#  '#dumbasses',
#  '#AirbusCrash',
#  '#BundyRanch',
#  '#CNN',
#  '#thinkforyourself',
#  '#butthurt',
#  '#givefacts',
#  '#Flightradar24',
#  '#Hindi',
#  '#Democracy',
#  '#COVERUP',
#  '#PKdebate',
#  '#Australians',
#  '#commonsense',
#  '#fuckinghilarious',
#  '#KentState',
#  '#MiraclesDoHappen',
#  '#Harnof',
#  '#uber',
#  '#Prayers',
#  '#GoodGuysWithGuns',
#  '#MiliarizedPolice',
#  '#PeaceHasToRule',
#  '#US',
#  '#PostMedia',
#  '#Justic4all',
#  '#Ukrainians',
#  '#cancerofcorruption',
#  '#USURY',
#  '#OttowaShooting',
#  '#sysdneysiege',
#  '#kidnapper',
#  '#Police',
#  '#AvsFam',
#  '#framing',
#  '#Shot',
#  '#Gulen',
#  '#nojustice',
#  '#Nazi',
#  '#pegida',
#  '#london2011',
#  '#provocation',
#  '#GunControl',
#  '#Lies',
#  '#StayStrongOttawa',
#  '#Backtothesixties',
#  '#logicerror',
#  '#Music101',
#  '#JusticeForMikeBrown',
#  '#TruthNorthStrong',
#  '#VivelaFrance',
#  '#Giuliani',
#  '#BlueLivesMatter',
#  '#OPFerguson',
#  '#MoveAlongFools',
#  '#becauseitsthePenscup',
#  '#4u925',
#  '#Myprayers',
#  '#CaptainObviousReporting',
#  '#Asshole',
#  '#pray',
#  '#7news',
#  '#ctv',
#  '#28hours',
#  '#CIAda',
#  '#ottawashooting',
#  '#radical',
#  '#realthreat',
#  '#PISSOFF',
#  '#PrayForFerguson',
#  '#Lufthansa',
#  '#scumbags',
#  '#IwantFacts',
#  '#MoreAntiTerrorLawsPlease',
#  '#peacefuloutcome',
#  '#journalism',
#  '#brutesquad',
#  '#chokenchickens',
#  '#DemocratUnion',
#  '#HandsUpDontShoot',
#  '#AH5017',
#  '#FergusonTruthers',
#  '#impressive',
#  '#prayforottowa',
#  '#RonKovic',
#  '#Kassig',
#  '#Alnusra',
#  '#violencedestroys',
#  '#justice',
#  '#VietCong',
#  '#American',
#  '#kingdavidhotelbombing',
#  '#13RacistCops',
#  '#DorianJohnson',
#  '#blackboysonly',
#  '#SecondAmendment',
#  '#Waco',
#  '#French',
#  '#sydneyseige',
#  '#fb',
#  '#NoNegotiationswithTerrorists',
#  '#classy',
#  '#This',
#  '#nos',
#  '#myNYPD',
#  '#greatpoint',
#  '#blingring',
#  '#Goose',
#  '#KayBurley',
#  "#TedCruz's",
#  '#NorthKorea',
#  '#zimmerman',
#  '#notinmyname',
#  '#RameshJadhav',
#  '#IS',
#  '#SydneyHostageCrisis',
#  '#notmyamerica',
#  '#NRA',
#  '#sidneysiege',
#  '#Egypt',
#  '#Rettungskräfte',
#  '#parlimenthill',
#  '#MyPasspostEP_LunchParty',
#  '#intolerance',
#  '#msm',
#  '#CommunityPolicing',
#  '#FuckYou',
#  '#Suicide',
#  '#NotInMyCountry',
#  '#ProphetMohammed',
#  '#extremists',
#  '#70sflashback',
#  '#UnsucessfulFrancePolice',
#  '#StopKillingInnocentPeople',
#  '#naive',
#  '#Farkhunda',
#  '#Indy',
#  '#BullShit',
#  '#TMLtalk',
#  '#casual',
#  '#JailSupport',
#  '#NorthCounty',
#  '#ugly',
#  '#Noted',
#  '#Bang',
#  '#COPPOLITICS',
#  '#PJNET',
#  '#MumbaiSeige',
#  '#KiezenTussenTweeKwaden',
#  '#UKpoli',
#  '#TakeBackTheHill',
#  '#zionismterrorism',
#  '#Penguins',
#  '#Chemtrails',
#  '#FTP',
#  '#societygoingdownthedrain',
#  '#RACISTCOPS',
#  '#Insecurityinfrance',
#  '#pigs',
#  '#Leafs',
#  '#SkyPollNo',
#  '#accountability',
#  '#saidnooneever',
#  '#twib',
#  '#morons',
#  '#MissouriAfterSlavery',
#  '#parisshooting',
#  '#GunsAintRoses',
#  '#muslim',
#  '#EnoughIsEnough',
#  '#MidwestUSA',
#  '#cartoonist',
#  '#DrawMohammedDay',
#  '#Justice',
#  '#NationalGuard',
#  '#Terrorists',
#  '#bbc',
#  '#aftonbladet',
#  '#JusticeforMikeBrown',
#  '#SupportersAgainstIsrael',
#  '#ابن_الذيب',
#  '#Europe',
#  '#Maryville',
#  '#IwantScania',
#  '#TrueNorthStrong',
#  '#CopyeditThis',
#  '#seriousinvestifation',
#  '#gross',
#  '#p2',
#  '#RedneckRacists',
#  '#Houston',
#  '#Mankind',
#  '#Gatineau',
#  '#incredible',
#  '#dangerousnegroes',
#  '#wakeup',
#  '#PoliceBrutality',
#  '#complot',
#  '#newcaledonia',
#  '#boycottthetelegaph',
#  '#MURDERED',
#  '#PravasiBhartiyaDivas',
#  '#LoonShine',
#  '#is',
#  '#sarcasm',
#  '#martinplacesiege',
#  '#zionistvermin',
#  '#Angry',
#  '#Islamophobia',
#  '#KillerCops',
#  '#community',
#  '#MumbaiAttacks',
#  '#cnn',
#  '#BarackObama',
#  '#GermanWingsCrash',
#  '#England',
#  '#NoModerateIslam',
#  '#parismurders',
#  '#HomenajeaJovenesdeVzla',
#  '#flogs',
#  '#incompetentFrancePolice',
#  '#educateyourself',
#  '#measured',
#  '#EveryoneDrawMohammed',
#  '#michaelbrown',
#  '#greetedAsLiberators',
#  '#StandtallCanada',
#  '#Pakistan',
#  '#Rwanda',
#  '#Peace',
#  '#riseup',
#  '#DowntownOttawa',
#  '#btmf',
#  '#AndreasLubitz',
#  '#Praying',
#  '#HANDSUP',
#  '#20',
#  '#longisland',
#  '#nowletourmatesgo',
#  '#crazy',
#  '#MaintainRights',
#  '#ModiSilenceMedia',
#  '#solittle',
#  '#LoveForCanada',
#  '#pedantry',
#  '#PRFail',
#  '#BlackOnBlack',
#  '#Freedom',
#  '#RIP',
#  '#IslamicState',
#  '#unarmedWhitepeople',
#  '#goFurself',
#  '#blackmirror',
#  '#justsayin',
#  '#Gunsense',
#  '#convenient',
#  '#Airbus320',
#  '#wankers',
#  '#PrayForSydneyHostages',
#  '#polqc',
#  '#StayClassy',
#  '#imnotnaive',
#  '#WHATISWRONGWITHYOU',
#  '#Mobocracy',
#  '#milkit',
#  '#CanadaNeedsWBC',
#  '#newsspeak',
#  '#KSLAM',
#  '#redblacks',
#  '#Americans',
#  '#VictimBlaming',
#  '#PresidentMukherjee',
#  '#peaceout',
#  '#Violence',
#  '#mccann',
#  '#AFP',
#  '#Germanwings',
#  '#BeSafeOttawa',
#  '#المهاجم',
#  '#SithLords',
#  '#Liberals',
#  '#OttawaShootings',
#  '#iStandWithCharlie',
#  '#HangEmHigh',
#  '#joke',
#  '#solidarity',
#  '#tongueincheek',
#  '#guilty',
#  '#MomsOnlyChild',
#  '#Sidney',
#  '#FreedomOfSpeech',
#  '#crimesAgainstHumanity',
#  '#genderbiasedlaw',
#  '#JeSuisJuif',
#  '#sydneystrong',
#  '#delusional',
#  '#nhpolitics',
#  '#Jesuischarliehebdo',
#  '#lmao',
#  '#nicetry',
#  '#MICHAELBROWN',
#  '#sydneycafe',
#  '#RafaelCruz',
#  '#inners',
#  '#MURDERING',
#  '#PeaceOnEarth',
#  '#notaclue',
#  '#NotParadise',
#  '#FCC',
#  '#cougar',
#  '#CoverUp',
#  '#bbcbias',
#  '#FergusonLies',
#  '#theWholePicture',
#  '#ninjaplease',
#  '#PT',
#  '#NotInMyName',
#  '#ottshooting',
#  '#Ford',
#  '#Wikieaks',
#  '#TooManyCrashes',
#  '#GOP',
#  '#ZeroTolerance',
#  '#airbus',
#  '#psych',
#  '#GPC',
#  '#Fell',
#  '#Furgeson',
#  '#photoshop',
#  '#military',
#  '#CharlyHebdo',
#  '#StayWoke',
#  '#KevinVickers',
#  '#Crowdfunding',
#  '#charliehedbo',
#  '#Right',
#  '#Government',
#  '#WePray',
#  '#corporateNews',
#  '#MSGTheFilm',
#  '#MaryamrajaviI',
#  '#nra',
#  '#FergusonPoliceAparthied',
#  '#CIA',
#  '#EVERYTHING',
#  '#FR',
#  '#GermanWings',
#  '#policestate',
#  '#Israeli',
#  '#MyPeopleMyPeople',
#  '#WayToGoFerguson',
#  '#Anarchy',
#  '#Smallbiz',
#  "#Obama's",
#  '#NYPD',
#  '#WhiteMuslims',
#  '#fact',
#  '#tank',
#  '#ceasefire',
#  '#Israel',
#  '#Rotherham',
#  '#charliehebdo',
#  '#WonderWoman',
#  '#Kargil',
#  '#Rednecks',
#  '#FalseFlag',
#  '#reparations',
#  '#ProbablyNot',
#  '#Barbarism',
#  '#kiteintheoldcity',
#  '#ffrf',
#  '#toodumbtobedumb',
#  '#SCOTTBROWN',
#  '#Revenge',
#  '#BostonStrong',
#  '#God',
#  '#charlie_hebdo',
#  '#HandsUpDontRobMe',
#  '#muricalogic',
#  '#USAID',
#  '#OccupyFerguson',
#  '#Paris',
#  '#religionofpeace',
#  '#Attack',
#  '#truenorthstrongandfree',
#  '#VancouverCanada',
#  '#PrioritiesMessedUp',
#  '#sadinns',
#  '#nudity_bitterly_cold',
#  '#2UnarmedBLACKS',
#  '#PrayForParis',
#  '#CharlieHebdoFalseFlag',
#  '#VoterPlantation',
#  '#Black',
#  '#phony',
#  '#repeated',
#  '#asshole',
#  '#heavyheart',
#  '#whatever',
#  '#patience',
#  '#blackgirlsrock',
#  '#ivegotyourback911',
#  '#siege',
#  '#CanadaUnderAttack',
#  '#STL',
#  '#StaySafeSydney',
#  '#dontshoot',
#  '#Kudos',
#  '#702sydney',
#  '#dirtyTruth',
#  '#westernsydney',
#  '#isisMerda',
#  '#FuckIslam',
#  '#cbc',
#  '#MartialLaw',
#  '#UsefulImbecile',
#  '#Canpoli',
#  '#C_vous_avez',
#  '#FirstAmendment',
#  '#Justice4RameshJadhav',
#  '#CANADA',
#  '#Gaza',
#  '#arms',
#  "#Ottawa's",
#  '#heroesinlifenotdeath',
#  '#Fans',
#  '#Hypocrisy',
#  '#MichaelBrown',
#  '#CHURCHOFENGLAND',
#  '#HarNof',
#  '#HamOnt',
#  '#Psychology',
#  '#teamsheike',
#  '#freeexpression',
#  '#RoyStewart',
#  '#thug',
#  '#wtf',
#  '#ConMen',
#  '#lawabidinggunowner',
#  '#anarchy',
#  '#Rojava',
#  '#proud',
#  '#YourGodsNotRealButMineIs',
#  '#CPC',
#  '#parisattack',
#  '#TortureReport',
#  '#unarmedblackteen',
#  '#edgy',
#  '#Mikebrown',
#  '#Hamilton',
#  '#Satire',
#  '#impressed',
#  '#bestcityintheworld',
#  '#Germanwing',
#  '#cia',
#  '#LiberalLogic',
#  '#ParisAttack',
#  '#LGBT',
#  '#BlackYouthMatter',
#  '#onsemoquedenous',
#  '#JESUISCHARLIE',
#  '#Diversity',
#  '#double',
#  '#HinduMuslimSikhIsai',
#  '#moron',
#  '#roft',
#  '#Token',
#  '#GreenWings',
#  '#r4today',
#  '#Networking',
#  '#ProtectItOrLoseIt',
#  '#islamophobia',
#  '#islam',
#  '#NoThanks',
#  '#MIKEBROWN',
#  '#fox',
#  '#152',
#  '#weneedallareblacks',
#  '#follow',
#  '#AllLivesMatter',
#  '#ViveLaFranceViveLaNation',
#  '#Leadership',
#  '#CharieHebdo',
#  '#AmIRight',
#  '#137GUNSHOTS',
#  '#ArtistHelp',
#  '#PTSD',
#  '#awesome',
#  '#ShittyButTrue',
#  '#smem',
#  '#watchyourback',
#  '#Excessive',
#  '#jul',
#  '#jesuischarlie',
#  '#FEMA',
#  '#Ignorant',
#  '#kosher',
#  '#world',
#  '#class',
#  '#strawman',
#  '#Equality',
#  '#PrayersforParis',
#  '#ISIL',
#  '#MakeInIndia',
#  '#UnitedbyWings',
#  '#not',
#  '#FergusonShooting',
#  '#DONTSHOOT',
#  '#KeepingItRealRadio',
#  '#SecretService',
#  '#DeathCult',
#  '#Drill',
#  '#Chinada',
#  '#CamerasOnCopsNow',
#  '#blackvalue',
#  '#imnotcharlie',
#  '#poorjournalism',
#  '#YES',
#  '#irony',
#  '#JeSuisCharlie',
#  '#HULK',
#  '#militarized',
#  '#passiveness',
#  '#Fioptics',
#  '#FreeMarineA',
#  '#svenskar',
#  '#EAGLES',
#  '#JihadistJoe',
#  '#perspective',
#  '#sick',
#  '#journalismisnotacrime',
#  '#Sick',
#  '#zionismiswrong',
#  '#endreligionnow',
#  '#israelchildrenkiller',
#  '#11',
#  '#Breaking',
#  '#Sydneycafeseige',
#  '#syndeysiege',
#  '#HDL',
#  '#ImpactOnFlying',
#  '#StaySafeOttawa',
#  '#standards',
#  '#standwithisrael',
#  '#CleanIndia',
#  '#Auspol',
#  '#notallamericans',
#  '#policebrutality',
#  '#CrushTheTerror',
#  '#HUalum',
#  '#NotGunnaHappen',
#  '#mightaswellbeCubaorChina',
#  '#NAACPBombing',
#  '#openminds',
#  '#DIY',
#  '#14Words',
#  '#LETSDOFURY',
#  '#hockey',
#  '#senseless',
#  '#Those',
#  '#India',
#  '#ReligionofPeace',
#  '#Patriots',
#  '#rop',
#  '#UKnowWhat',
#  '#CanadaStrong',
#  '#wth',
#  '#NBP',
#  '#theyluvit',
#  '#StLouisShooting',
#  '#America',
#  '#outlawIslam',
#  '#oklahomabeheading',
#  '#13RACISTCOPS',
#  '#трагедия',
#  '#Digne',
#  '#coverup',
#  '#thedayIunfollowedwikileaks',
#  '#foxnews',
#  '#building7',
#  '#Isis-style',
#  '#parisisburning',
#  '#JewsForScalise',
#  '#depression',
#  '#brand',
#  '#FALSEFLAG',
#  '#METHODISTCONF',
#  '#Sept11',
#  '#echr',
#  '#unnamed',
#  '#KeyStoner',
#  '#PewChurchAttack',
#  '#developing',
#  '#FoxNews',
#  '#agenda',
#  '#Liberal',
#  '#GoJaysGo',
#  '#weak',
#  '#Repent',
#  '#StLouisCountyPD',
#  '#FixFlying',
#  '#TwitterKurds',
#  '#September11',
#  '#4U2521',
#  '#CharlieHedbo',
#  "#I'llridewithyou",
#  '#stopfuelingfire',
#  '#Sickening',
#  '#NUJ',
#  '#sydney',
#  '#ACAB',
#  '#islamophobe',
#  '#nothing',
#  '#raceriot',
#  '#nonMuslimlivesmatter',
#  '#guncontrol',
#  '#WeAreJewish',
#  '#SydneyCafe',
#  '#execute',
#  '#LoveUSydney',
#  '#Новороссия',
#  '#discription',
#  '#Cdnpoli',
#  '#notATypo',
#  '#Sydneyseige',
#  '#Calgary',
#  '#Sotlof',
#  '#muslims',
#  '#news',
#  '#OTTAWA',
#  '#ParisShooting',
#  '#Spirituality',
#  '#HuffPost',
#  '#DoorKnob',
#  "#I'llReadWithYou",
#  '#ReligionOfPeace',
#  '#judi',
#  '#новости',
#  '#nopeace',
#  '#FB',
#  '#MH17',
#  '#LeftistLuzer',
#  '#Bands',
#  '#Haines',
#  '#FortHood',
#  '#besafe',
#  '#American_values',
#  '#SportsCentre',
#  '#FreeSpeech',
#  '#ONUS',
#  '#StLootus',
#  '#JanDhanYojana',
#  '#Organized',
#  '#FilthyCanadaUnderSiege',
#  '#FergusonPolice',
#  '#uspoli',
#  '#UnitedByWings',
#  '#ATerroristCannotBeARealMuslim',
#  '#RACIST',
#  '#ccot',
#  '#Iloveasuburnedcountry',
#  '#DarrenWilson',
#  '#hit',
#  '#confused',
#  '#Benghazi',
#  '#youidjit',
#  '#faze',
#  '#Veterans',
#  '#Murder',
#  '#enemy',
#  '#Shooter',
#  '#FergusonCoverUp',
#  '#ciaunderbus',
#  '#MakeBacon',
#  '#refugee',
#  '#HANDSUPdontshoot',
#  '#press',
#  '#Islaimcterror',
#  '#IWontReadYou',
#  '#snipertime',
#  '#mindless',
#  '#iamcharlie',
#  '#MuslimConvert',
#  '#usa',
#  '#MackBraaoown',
#  '#mooi',
#  '#DammartinEnGoele',
#  '#PerpetualRecomplicationStrategy',
#  '#AccidenteAvionARV',
#  '#cartoonists',
#  '#thoughtsandprayers',
#  '#Classy',
#  '#UNFOLLOW',
#  '#pressfreedom',
#  '#WeOweIt2EachOther',
#  '#NotCHARGED',
#  '#CRIMINAL',
#  '#wikileaks',
#  '#foodforthought',
#  '#JustinBieber',
#  "#ICan'tBreathe",
#  '#truecount',
#  '#prt',
#  '#NOW',
#  '#WeAreONE',
#  '#DrEd',
#  '#parliamentsquare',
#  '#aerotoxic',
#  '#wow',
#  '#Malala',
#  '#ChokeHold',
#  '#LiberteDelaPresse',
#  '#yeg',
#  '#Sumpmwrong',
#  '#ProofPlease',
#  '#facts',
#  '#WeLoveYouCanada',
#  '#hostage',
#  '#Fail',
#  '#dearyme',
#  '#ottawastrong',
#  '#racist',
#  '#blockedbybishop',
#  '#good',
#  '#LetThatSinkIn',
#  '#LikeLondon',
#  '#Manly',
#  '#welcometoSTL',
#  '#Tiananmen',
#  '#KeepingItReal',
#  '#PeacefulProtest',
#  '#waterboard',
#  '#Merkel',
#  '#TerrorHasNoReligion',
#  '#ISRAEL',
#  '#victimcard',
#  '#WarOnWomen',
#  '#ParliamentHill',
#  '#professionals',
#  '#PrayForAustralia',
#  '#GermanyWings',
#  '#ottawa',
#  '#ABCbudgetcutsfuckyeah',
#  '#blowback',
#  '#CactusJack',
#  '#Netanayahu',
#  '#Jerusalem',
#  '#Saudi',
#  '#Penrith',
#  '#cbcOTT',
#  '#Assange',
#  '#OttawaToBoston',
#  '#Montrouge',
#  '#different',
#  '#YourRacismIsShowing',
#  '#jackass',
#  '#tracking',
#  '#Terrorist',
#  '#lulz',
#  '#LindtCafeSiege',
#  '#apartheidstlouis',
#  '#kellyfile',
#  '#MEXICO',
#  '#cowards',
#  '#alqaeda',
#  '#dipshit',
#  '#der',
#  '#VoteForNesha',
#  '#TeinemanSquare',
#  '#AmazonPrime',
#  '#properganda',
#  '#MM330',
#  '#FactsonFactsonFacts',
#  '#dhimmis',
#  '#mnwild',
#  '#EaglesNation',
#  '#Boston',
#  '#Wikileaks',
#  '#Foley',
#  '#foolsnotmartyrs',
#  '#AlpsCrash',
#  '#conservativeasiankid',
#  '#OpenCarry',
#  '#heroes',
#  '#9News',
#  '#Eagles',
#  '#real',
#  '#occult',
#  '#IDIOTSERVANTS',
#  '#noshit',
#  '#Favorite',
#  '#OCanada',
#  '#RIGHTNOW',
#  '#interesting',
#  '#AlQaida',
#  '#MLB',
#  '#DUHHH',
#  '#KMOV',
#  '#911',
#  '#FactCheck',
#  '#peshwarattack',
#  '#Iraq',
#  '#DEMOCRACY',
#  '#notwhatimseeing',
#  '#ILLSHOPWITHJEW',
#  '#ClivenBundy',
#  '#TeaNuts',
#  '#thankyou',
#  '#standwithterrorvictims',
#  '#TonyAbbott',
#  '#trauma',
#  '#Earth',
#  '#SMH',
#  '#PeshawarAttack',
#  '#FilmThePolice',
#  '#Veteran',
#  '#PrayForOttawa',
#  '#pissoff',
#  '#stopthehate',
#  '#copsaretops',
#  '#frustration',
#  '#proudcanadian',
#  '#StreisandEffect',
#  '#Ottawa',
#  '#MediaWatch',
#  '#onpoli',
#  '#HidingWontHelp',
#  '#CharliHebdo',
#  '#defend',
#  '#Canadiancitizen',
#  '#owned',
#  '#Mindblowing',
#  '#ато',
#  '#rusian',
#  '#1A',
#  '#assange',
#  '#Pray',
#  '#Apartheid',
#  '#dontgiveupthefight',
#  '#murica',
#  '#AccidenteAereo',
#  '#DieHard',
#  '#prayforparise',
#  '#Blocked',
#  '#Cameron',
#  '#Lindt',
#  '#Blair',
#  '#kmov',
#  '#MO',
#  '#aweshit',
#  '#ottnews',
#  '#MH370',
#  '#LiveInLove',
#  '#FascistPolice',
#  '#sydneycafesiege',
#  '#clayton',
#  '#Quran',
#  '#KeepPhilSafe',
#  '#ProudlyFree',
#  '#incredulous',
#  '#coady55',
#  '#justiceformikebrown',
#  '#WakeUpAmerica',
#  '#Parisians',
#  '#4u9525',
#  '#divideandrule',
#  '#MaryamRajavi',
#  '#atheism',
#  '#weWontRideWithYou',
#  '#ParisShootings',
#  '#pen_gun',
#  '#SebabSuntuk',
#  '#MuslimTerrorists',
#  '#junta',
#  "#Isis's",
#  '#brokenrecords',
#  '#chills',
#  '#Idiots',
#  '#no',
#  '#2A',
#  '#hometown',
#  '#Oklahoma',
#  '#BanuQuraizah',
#  '#wedpnotnegotiatewithterrorists',
#  '#scram',
#  '#FF',
#  '#fucktard',
#  '#KKK',
#  '#ALLlivesMatter',
#  '#excitoes',
#  '#maintainrights',
#  '#uneducatedpeopleproblems',
#  '#fergusonanimals',
#  '#WeStandWithYouParis',
#  '#BusTourMovement',
#  '#partoftheproblem',
#  '#isis',
#  '#RogueCops',
#  '#terrorsim',
#  '#ICC4Israel',
#  '#proudaussie',
#  '#hope',
#  '#CanadianDucks',
#  '#JeNeSuisPasCharlie',
#  '#peace',
#  '#inhumane',
#  '#SydneySiege',
#  '#AggressiveContact',
#  '#AntiAmerican',
#  '#BFFs',
#  '#trytokeepup',
#  '#ETDISCLOSURE',
#  '#AKP',
#  '#FreePalestine',
#  '#fuckthepolice',
#  '#gunfail',
#  '#Redlake',
#  '#Muslim',
#  '#GetARope',
#  '#Belgium',
#  '#BRILLIANT',
#  '#Norighttobeoffended',
#  '#Sweden',
#  '#canadastrong',
#  '#very',
#  '#WARONBLACKMALES',
#  '#medicine_food',
#  '#BuyingTime',
#  '#BlackLifeMatters',
#  '#nonviolence',
#  '#Bokoharam',
#  '#banksy',
#  '#SYDNEY',
#  '#doubletap',
#  '#overkill',
#  '#despicalbe',
#  '#lindtcafe',
#  '#workplaceviolence',
#  '#Fergusen',
#  '#pureevil',
#  '#AlSharpton',
#  '#Uganda',
#  '#provocative',
#  '#israeli',
#  '#RT',
#  '#pigsofafeatherflocktogether',
#  '###ards',
#  '#FOUR',
#  '#JEDIS',
#  '#media',
#  '#GodBlessCanada',
#  '#alive',
#  '#imams',
#  '#autodafe',
#  '#GetReal',
#  '#power',
#  '#HandsOffMyGun',
#  '#OpFerguson',
#  '#lies',
#  '#Really',
#  '#specialkindofstupid',
#  '#SWAT',
#  '#unionsquareevictiontheaterrainynightmemory',
#  '#Palestine',
#  '#Justsaying',
#  '#copaganda',
#  '#Islam',
#  '#sydn',
#  '#stlouis',
#  '#cantread',
#  '#VetoDemocrático',
#  '#rip',
#  '#cadet',
#  '#respectforfamily',
#  '#illstandwithyou',
#  ...}

# %% [markdown]
# ### Question 3 (2.0 mark)
#
# **Instructions**: Our task here to tokenize the hashtags, by implementing a reversed version of the MaxMatch algorithm discussed in class, where matching begins at the end of the hashtag and progresses backwards. NLTK has a list of words that you can use for matching, see starter code below. Be careful about efficiency with respect to doing word lookups. One extra challenge you have to deal with is that the provided list of words includes only lemmas: your MaxMatch algorithm should match inflected forms by converting them into lemmas using the NLTK lemmatizer before matching. When lemmatising a word, you also need to provide the part-of-speech tag of the word. You should use `nltk.tag.pos_tag` for doing part-of-speech tagging.
#
# Note that the list of words is incomplete, and, if you are unable to make any longer match, your code should default to matching a single letter. Create a new list of tokenized hashtags (this should be a list of lists of strings) and use slicing to print out the last 20 hashtags in the list.
#
# For example, given "#speakup", the algorithm should produce: \["#", "speak", "up"\]. And note that you do not need to delete the hashtag symbol ("#") from the tokenised outputs.
#
# **Task**: Complete the `tokenize_hashtags(hashtags)` function by implementing a reversed MaxMatch algorithm. The function takes as input **a set of hashtags**, and returns **a dictionary** where key="hashtag" and value="a list of word tokens".
#
# **Check**: Use the assertion statements in *"For your testing"* below for the expected output.

# %%
from nltk.tag import pos_tag

def get_wordnet_pos(word):
    """Map POS tag to first character lemmatize() accepts"""
    tag = pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}

    return tag_dict.get(tag, wordnet.NOUN)

# %%
from nltk.corpus import wordnet
nltk.download('words')

lemmatizer = nltk.stem.wordnet.WordNetLemmatizer()
words = set(nltk.corpus.words.words()) #a list of words provided by NLTK
words_lower = map(lambda x:x.lower(), words) # lowercase the NLTK word list
words_lower = set(words_lower)


def maxMatch(hashtag, tokens):
    """Match the words in hashtag to a list of words in backward direction (from right to left)"""
    if hashtag == '':
        return tokens
    for i in range(len(hashtag), 0, -1):
        firstword = hashtag[-i:]
        remainder = hashtag[:len(hashtag)-i]
        firstword_lower = firstword.lower() # lowercase prior to matching
        # Lemmatize the firstword before matching
        lemma = lemmatizer.lemmatize(firstword_lower, get_wordnet_pos(firstword_lower))
        
        if lemma in words_lower:
            tokens.insert(0, firstword) # append at the front of a list
            return maxMatch(remainder, tokens) # recursive call
        # keep the #
        elif len(lemma) == 1: 
            tokens.insert(0, firstword)
            return maxMatch(remainder, tokens)
        
        
def tokenize_hashtags(hashtags):
    tokenized_hashtags = {}
    for hashtag in hashtags:
        tokens = []
        tokenized_hashtags[hashtag] = maxMatch(hashtag, tokens)
    return tokenized_hashtags


tokenized_hashtags = tokenize_hashtags(hashtags)

print(list(tokenized_hashtags.items())[:20])
# Out:
# [nltk_data] Downloading package words to /Users/MAC/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [('#EatADick', ['#', 'E', 'atA', 'Dick']), ('#Dudelove', ['#', 'Dude', 'love']), ('#furgeson', ['#', 'f', 'urge', 'son']), ('#Fascism', ['#', 'Fascism']), ('#катасрофа', ['#', 'к', 'а', 'т', 'а', 'с', 'р', 'о', 'ф', 'а']), ('#energy', ['#', 'energy']), ('#terrorizing', ['#', 'terrorizing']), ('#info4', ['#', 'in', 'fo', '4']), ('#NESARA', ['#', 'NE', 'SARA']), ('#LiarsLie', ['#', 'Liars', 'Lie']), ('#WE', ['#', 'WE']), ('#Islamic_State', ['#', 'Islamic', '_', 'State']), ('#NewsCorpse', ['#', 'News', 'Corpse']), ('#pnpcbc', ['#', 'p', 'n', 'p', 'c', 'b', 'c']), ('#unitedbywings', ['#', 'united', 'by', 'wings']), ('#frustrating', ['#', 'frustrating']), ('#VictimHood', ['#', 'VictimHood']), ('#Facepalm', ['#', 'Face', 'palm']), ('#OneBastardBitesTheDust', ['#', 'One', 'Bastard', 'Bites', 'The', 'Dust']), ('#punintended', ['#', 'p', 'unintended'])]

# %%
tokenized_hashtags
# Out:
# {'#EatADick': ['#', 'E', 'atA', 'Dick'],
#  '#Dudelove': ['#', 'Dude', 'love'],
#  '#furgeson': ['#', 'f', 'urge', 'son'],
#  '#Fascism': ['#', 'Fascism'],
#  '#катасрофа': ['#', 'к', 'а', 'т', 'а', 'с', 'р', 'о', 'ф', 'а'],
#  '#energy': ['#', 'energy'],
#  '#terrorizing': ['#', 'terrorizing'],
#  '#info4': ['#', 'in', 'fo', '4'],
#  '#NESARA': ['#', 'NE', 'SARA'],
#  '#LiarsLie': ['#', 'Liars', 'Lie'],
#  '#WE': ['#', 'WE'],
#  '#Islamic_State': ['#', 'Islamic', '_', 'State'],
#  '#NewsCorpse': ['#', 'News', 'Corpse'],
#  '#pnpcbc': ['#', 'p', 'n', 'p', 'c', 'b', 'c'],
#  '#unitedbywings': ['#', 'united', 'by', 'wings'],
#  '#frustrating': ['#', 'frustrating'],
#  '#VictimHood': ['#', 'VictimHood'],
#  '#Facepalm': ['#', 'Face', 'palm'],
#  '#OneBastardBitesTheDust': ['#', 'One', 'Bastard', 'Bites', 'The', 'Dust'],
#  '#punintended': ['#', 'p', 'unintended'],
#  '#thewholeworldiswatching': ['#',
#   'the',
#   'who',
#   'lew',
#   'or',
#   'l',
#   'dis',
#   'watching'],
#  '#Yeah': ['#', 'Yeah'],
#  '#Armour': ['#', 'Arm', 'our'],
#  "#Ferguson'da": ['#', 'Ferguson', "'", 'da'],
#  '#FascistCops': ['#', 'Fascist', 'Cops'],
#  '#dumbasses': ['#', 'dum', 'basses'],
#  '#AirbusCrash': ['#', 'Air', 'bus', 'Crash'],
#  '#BundyRanch': ['#', 'Bundy', 'Ranch'],
#  '#CNN': ['#', 'C', 'N', 'N'],
#  '#thinkforyourself': ['#', 'think', 'for', 'yourself'],
#  '#butthurt': ['#', 'but', 'thurt'],
#  '#givefacts': ['#', 'give', 'facts'],
#  '#Flightradar24': ['#', 'Flight', 'radar', '2', '4'],
#  '#Hindi': ['#', 'Hindi'],
#  '#Democracy': ['#', 'Democracy'],
#  '#COVERUP': ['#', 'COVER', 'UP'],
#  '#PKdebate': ['#', 'P', 'K', 'debate'],
#  '#Australians': ['#', 'Australians'],
#  '#commonsense': ['#', 'common', 'sense'],
#  '#fuckinghilarious': ['#', 'fu', 'c', 'king', 'hilarious'],
#  '#KentState': ['#', 'Kent', 'State'],
#  '#MiraclesDoHappen': ['#', 'Miracles', 'Do', 'Happen'],
#  '#Harnof': ['#', 'Harn', 'of'],
#  '#uber': ['#', 'u', 'ber'],
#  '#Prayers': ['#', 'Prayers'],
#  '#GoodGuysWithGuns': ['#', 'Good', 'Guy', 'sWith', 'Guns'],
#  '#MiliarizedPolice': ['#', 'Mi', 'liar', 'i', 'zed', 'Police'],
#  '#PeaceHasToRule': ['#', 'Peace', 'Has', 'To', 'Rule'],
#  '#US': ['#', 'US'],
#  '#PostMedia': ['#', 'PostMedia'],
#  '#Justic4all': ['#', 'J', 'us', 'tic', '4', 'all'],
#  '#Ukrainians': ['#', 'Ukrainians'],
#  '#cancerofcorruption': ['#', 'cancer', 'of', 'corruption'],
#  '#USURY': ['#', 'USURY'],
#  '#OttowaShooting': ['#', 'Otto', 'wa', 'Shooting'],
#  '#sysdneysiege': ['#', 's', 'ys', 'd', 'n', 'ey', 'siege'],
#  '#kidnapper': ['#', 'k', 'id', 'napper'],
#  '#Police': ['#', 'Police'],
#  '#AvsFam': ['#', 'A', 'vs', 'Fam'],
#  '#framing': ['#', 'framing'],
#  '#Shot': ['#', 'Shot'],
#  '#Gulen': ['#', 'G', 'u', 'len'],
#  '#nojustice': ['#', 'no', 'justice'],
#  '#Nazi': ['#', 'Nazi'],
#  '#pegida': ['#', 'peg', 'ida'],
#  '#london2011': ['#', 'l', 'on', 'don', '2', '0', '1', '1'],
#  '#provocation': ['#', 'provocation'],
#  '#GunControl': ['#', 'G', 'unControl'],
#  '#Lies': ['#', 'Lies'],
#  '#StayStrongOttawa': ['#', 'Stay', 'Strong', 'Ottawa'],
#  '#Backtothesixties': ['#', 'Back', 'to', 'the', 'sixties'],
#  '#logicerror': ['#', 'logic', 'error'],
#  '#Music101': ['#', 'Music', '1', '0', '1'],
#  '#JusticeForMikeBrown': ['#', 'Justice', 'For', 'Mike', 'Brown'],
#  '#TruthNorthStrong': ['#', 'Truth', 'North', 'Strong'],
#  '#VivelaFrance': ['#', 'V', 'i', 'vela', 'F', 'rance'],
#  '#Giuliani': ['#', 'Gi', 'u', 'li', 'ani'],
#  '#BlueLivesMatter': ['#', 'Blue', 'Live', 'sMatter'],
#  '#OPFerguson': ['#', 'O', 'P', 'Ferguson'],
#  '#MoveAlongFools': ['#', 'Move', 'Along', 'Fools'],
#  '#becauseitsthePenscup': ['#', 'because', 'its', 'the', 'Pen', 'scup'],
#  '#4u925': ['#', '4', 'u', '9', '2', '5'],
#  '#Myprayers': ['#', 'My', 'prayers'],
#  '#CaptainObviousReporting': ['#', 'Cap', 'ta', 'inObvious', 'Re', 'porting'],
#  '#Asshole': ['#', 'As', 'shole'],
#  '#pray': ['#', 'pray'],
#  '#7news': ['#', '7', 'news'],
#  '#ctv': ['#', 'c', 't', 'v'],
#  '#28hours': ['#', '2', '8', 'hours'],
#  '#CIAda': ['#', 'C', 'I', 'Ada'],
#  '#ottawashooting': ['#', 'ottawa', 'shooting'],
#  '#radical': ['#', 'radical'],
#  '#realthreat': ['#', 'real', 'threat'],
#  '#PISSOFF': ['#', 'PISS', 'OFF'],
#  '#PrayForFerguson': ['#', 'Pray', 'For', 'Ferguson'],
#  '#Lufthansa': ['#', 'Lu', 'f', 't', 'hansa'],
#  '#scumbags': ['#', 'scum', 'bags'],
#  '#IwantFacts': ['#', 'I', 'want', 'Facts'],
#  '#MoreAntiTerrorLawsPlease': ['#',
#   'More',
#   'Anti',
#   'Terror',
#   'Laws',
#   'Please'],
#  '#peacefuloutcome': ['#', 'peaceful', 'outcome'],
#  '#journalism': ['#', 'journalism'],
#  '#brutesquad': ['#', 'brute', 'squad'],
#  '#chokenchickens': ['#', 'cho', 'ken', 'chickens'],
#  '#DemocratUnion': ['#', 'Democrat', 'Union'],
#  '#HandsUpDontShoot': ['#', 'Hand', 'sUp', 'Dont', 'Shoot'],
#  '#AH5017': ['#', 'AH', '5', '0', '1', '7'],
#  '#FergusonTruthers': ['#', 'Ferguson', 'T', 'rut', 'hers'],
#  '#impressive': ['#', 'impressive'],
#  '#prayforottowa': ['#', 'pray', 'for', 'otto', 'wa'],
#  '#RonKovic': ['#', 'Ron', 'Ko', 'vic'],
#  '#Kassig': ['#', 'Kas', 'sig'],
#  '#Alnusra': ['#', 'Alnus', 'ra'],
#  '#violencedestroys': ['#', 'violence', 'des', 'troys'],
#  '#justice': ['#', 'justice'],
#  '#VietCong': ['#', 'Vie', 't', 'Con', 'g'],
#  '#American': ['#', 'American'],
#  '#kingdavidhotelbombing': ['#', 'king', 'david', 'hotel', 'bom', 'bing'],
#  '#13RacistCops': ['#', '1', '3', 'Racist', 'Cops'],
#  '#DorianJohnson': ['#', 'Dorian', 'John', 'son'],
#  '#blackboysonly': ['#', 'blackboy', 'sonly'],
#  '#SecondAmendment': ['#', 'Second', 'Amendment'],
#  '#Waco': ['#', 'Waco'],
#  '#French': ['#', 'French'],
#  '#sydneyseige': ['#', 'syd', 'n', 'ey', 'se', 'i', 'ge'],
#  '#fb': ['#', 'f', 'b'],
#  '#NoNegotiationswithTerrorists': ['#',
#   'No',
#   'Negotiation',
#   'swith',
#   'Terrorists'],
#  '#classy': ['#', 'classy'],
#  '#This': ['#', 'This'],
#  '#nos': ['#', 'nos'],
#  '#myNYPD': ['#', 'm', 'yN', 'Y', 'P', 'D'],
#  '#greatpoint': ['#', 'great', 'point'],
#  '#blingring': ['#', 'b', 'ling', 'ring'],
#  '#Goose': ['#', 'Goose'],
#  '#KayBurley': ['#', 'Kay', 'Burley'],
#  "#TedCruz's": ['#', 'Ted', 'C', 'r', 'u', 'z', "'", 's'],
#  '#NorthKorea': ['#', 'North', 'Ko', 'rea'],
#  '#zimmerman': ['#', 'z', 'i', 'm', 'merman'],
#  '#notinmyname': ['#', 'no', 'tin', 'my', 'name'],
#  '#RameshJadhav': ['#', 'Ramesh', 'J', 'a', 'dha', 'v'],
#  '#IS': ['#', 'IS'],
#  '#SydneyHostageCrisis': ['#', 'Syd', 'n', 'ey', 'Hostage', 'Crisis'],
#  '#notmyamerica': ['#', 'not', 'my', 'america'],
#  '#NRA': ['#', 'N', 'RA'],
#  '#sidneysiege': ['#', 'sidney', 'siege'],
#  '#Egypt': ['#', 'Egypt'],
#  '#Rettungskräfte': ['#', 'Ret', 'tungs', 'k', 'r', 'ä', 'f', 'te'],
#  '#parlimenthill': ['#', 'par', 'limen', 'thill'],
#  '#MyPasspostEP_LunchParty': ['#',
#   'My',
#   'P',
#   'ass',
#   'po',
#   'stEP',
#   '_',
#   'Lunch',
#   'Party'],
#  '#intolerance': ['#', 'intolerance'],
#  '#msm': ['#', 'ms', 'm'],
#  '#CommunityPolicing': ['#', 'Community', 'Policing'],
#  '#FuckYou': ['#', 'Fu', 'c', 'k', 'You'],
#  '#Suicide': ['#', 'Suicide'],
#  '#NotInMyCountry': ['#', 'No', 'tIn', 'My', 'Country'],
#  '#ProphetMohammed': ['#', 'Prophet', 'Mo', 'hammed'],
#  '#extremists': ['#', 'extremists'],
#  '#70sflashback': ['#', '7', '0s', 'flash', 'back'],
#  '#UnsucessfulFrancePolice': ['#',
#   'Uns',
#   'u',
#   'cess',
#   'fu',
#   'l',
#   'F',
#   'rance',
#   'Police'],
#  '#StopKillingInnocentPeople': ['#', 'Stop', 'Killing', 'Innocent', 'People'],
#  '#naive': ['#', 'naive'],
#  '#Farkhunda': ['#', 'F', 'ark', 'hun', 'da'],
#  '#Indy': ['#', 'Indy'],
#  '#BullShit': ['#', 'BullS', 'hit'],
#  '#TMLtalk': ['#', 'T', 'M', 'L', 'talk'],
#  '#casual': ['#', 'casual'],
#  '#JailSupport': ['#', 'Jail', 'Support'],
#  '#NorthCounty': ['#', 'North', 'County'],
#  '#ugly': ['#', 'ugly'],
#  '#Noted': ['#', 'Noted'],
#  '#Bang': ['#', 'Bang'],
#  '#COPPOLITICS': ['#', 'COP', 'POLITICS'],
#  '#PJNET': ['#', 'P', 'J', 'NET'],
#  '#MumbaiSeige': ['#', 'Mum', 'b', 'ai', 'Se', 'i', 'ge'],
#  '#KiezenTussenTweeKwaden': ['#',
#   'K',
#   'ie',
#   'zen',
#   'T',
#   'us',
#   'senT',
#   'weeK',
#   'wa',
#   'den'],
#  '#UKpoli': ['#', 'U', 'K', 'po', 'li'],
#  '#TakeBackTheHill': ['#', 'Take', 'Back', 'The', 'Hill'],
#  '#zionismterrorism': ['#', 'zionism', 'terrorism'],
#  '#Penguins': ['#', 'Penguins'],
#  '#Chemtrails': ['#', 'C', 'hem', 'trails'],
#  '#FTP': ['#', 'F', 'T', 'P'],
#  '#societygoingdownthedrain': ['#',
#   'society',
#   'going',
#   'down',
#   'the',
#   'drain'],
#  '#RACISTCOPS': ['#', 'RACIST', 'COPS'],
#  '#Insecurityinfrance': ['#', 'In', 'sec', 'u', 'rit', 'yin', 'f', 'rance'],
#  '#pigs': ['#', 'pigs'],
#  '#Leafs': ['#', 'Leafs'],
#  '#SkyPollNo': ['#', 'Sky', 'Poll', 'No'],
#  '#accountability': ['#', 'accountability'],
#  '#saidnooneever': ['#', 'said', 'no', 'one', 'ever'],
#  '#twib': ['#', 'twi', 'b'],
#  '#morons': ['#', 'morons'],
#  '#MissouriAfterSlavery': ['#', 'Missouri', 'After', 'Slavery'],
#  '#parisshooting': ['#', 'paris', 'shooting'],
#  '#GunsAintRoses': ['#', 'G', 'unsAint', 'Roses'],
#  '#muslim': ['#', 'mu', 'slim'],
#  '#EnoughIsEnough': ['#', 'E', 'no', 'ug', 'hIs', 'Enough'],
#  '#MidwestUSA': ['#', 'Mid', 'we', 'stU', 'SA'],
#  '#cartoonist': ['#', 'cartoonist'],
#  '#DrawMohammedDay': ['#', 'Draw', 'Mo', 'hammed', 'Day'],
#  '#Justice': ['#', 'Justice'],
#  '#NationalGuard': ['#', 'National', 'Guard'],
#  '#Terrorists': ['#', 'Terrorists'],
#  '#bbc': ['#', 'b', 'b', 'c'],
#  '#aftonbladet': ['#', 'a', 'f', 'ton', 'b', 'l', 'adet'],
#  '#JusticeforMikeBrown': ['#', 'Justice', 'for', 'Mike', 'Brown'],
#  '#SupportersAgainstIsrael': ['#', 'Supporters', 'Against', 'Israel'],
#  '#ابن_الذيب': ['#', 'ا', 'ب', 'ن', '_', 'ا', 'ل', 'ذ', 'ي', 'ب'],
#  '#Europe': ['#', 'Eu', 'rope'],
#  '#Maryville': ['#', 'Mary', 'ville'],
#  '#IwantScania': ['#', 'I', 'want', 'Scania'],
#  '#TrueNorthStrong': ['#', 'True', 'North', 'Strong'],
#  '#CopyeditThis': ['#', 'Copy', 'edit', 'This'],
#  '#seriousinvestifation': ['#',
#   'serio',
#   'u',
#   'sin',
#   'ves',
#   'ti',
#   'fat',
#   'ion'],
#  '#gross': ['#', 'gross'],
#  '#p2': ['#', 'p', '2'],
#  '#RedneckRacists': ['#', 'Red', 'neck', 'Racists'],
#  '#Houston': ['#', 'Ho', 'us', 'ton'],
#  '#Mankind': ['#', 'Mankind'],
#  '#Gatineau': ['#', 'Ga', 'tinea', 'u'],
#  '#incredible': ['#', 'incredible'],
#  '#dangerousnegroes': ['#', 'dangerous', 'negroes'],
#  '#wakeup': ['#', 'wa', 'keup'],
#  '#PoliceBrutality': ['#', 'Police', 'Brutality'],
#  '#complot': ['#', 'complot'],
#  '#newcaledonia': ['#', 'new', 'caledonia'],
#  '#boycottthetelegaph': ['#', 'boycott', 'the', 'tele', 'gap', 'h'],
#  '#MURDERED': ['#', 'MURDERED'],
#  '#PravasiBhartiyaDivas': ['#',
#   'P',
#   'r',
#   'ava',
#   'si',
#   'Bhar',
#   'ti',
#   'ya',
#   'Divas'],
#  '#LoonShine': ['#', 'Loon', 'Shine'],
#  '#is': ['#', 'is'],
#  '#sarcasm': ['#', 'sarcasm'],
#  '#martinplacesiege': ['#', 'martin', 'place', 'siege'],
#  '#zionistvermin': ['#', 'zionist', 'vermin'],
#  '#Angry': ['#', 'Angry'],
#  '#Islamophobia': ['#', 'I', 'sla', 'moph', 'obi', 'a'],
#  '#KillerCops': ['#', 'Killer', 'Cops'],
#  '#community': ['#', 'community'],
#  '#MumbaiAttacks': ['#', 'Mum', 'b', 'ai', 'Attacks'],
#  '#cnn': ['#', 'c', 'n', 'n'],
#  '#BarackObama': ['#', 'Bara', 'c', 'kOb', 'ama'],
#  '#GermanWingsCrash': ['#', 'German', 'Wings', 'Crash'],
#  '#England': ['#', 'En', 'gland'],
#  '#NoModerateIslam': ['#', 'No', 'Moderate', 'Islam'],
#  '#parismurders': ['#', 'paris', 'murders'],
#  '#HomenajeaJovenesdeVzla': ['#',
#   'Home',
#   'na',
#   'j',
#   'ea',
#   'Jove',
#   'nes',
#   'deV',
#   'z',
#   'la'],
#  '#flogs': ['#', 'f', 'logs'],
#  '#incompetentFrancePolice': ['#', 'incompetent', 'F', 'rance', 'Police'],
#  '#educateyourself': ['#', 'educate', 'yourself'],
#  '#measured': ['#', 'measured'],
#  '#EveryoneDrawMohammed': ['#', 'Everyone', 'Draw', 'Mo', 'hammed'],
#  '#michaelbrown': ['#', 'michael', 'brown'],
#  '#greetedAsLiberators': ['#', 'gree', 'te', 'dAs', 'Liberators'],
#  '#StandtallCanada': ['#', 'Stand', 'tall', 'Canada'],
#  '#Pakistan': ['#', 'P', 'ak', 'i', 'stan'],
#  '#Rwanda': ['#', 'R', 'w', 'anda'],
#  '#Peace': ['#', 'Peace'],
#  '#riseup': ['#', 'rise', 'up'],
#  '#DowntownOttawa': ['#', 'Downtown', 'Ottawa'],
#  '#btmf': ['#', 'b', 't', 'm', 'f'],
#  '#AndreasLubitz': ['#', 'Andreas', 'Lu', 'bit', 'z'],
#  '#Praying': ['#', 'Praying'],
#  '#HANDSUP': ['#', 'HAND', 'SUP'],
#  '#20': ['#', '2', '0'],
#  '#longisland': ['#', 'long', 'island'],
#  '#nowletourmatesgo': ['#', 'n', 'owl', 'e', 'tour', 'mates', 'go'],
#  '#crazy': ['#', 'crazy'],
#  '#MaintainRights': ['#', 'Maintain', 'Rights'],
#  '#ModiSilenceMedia': ['#', 'Mo', 'di', 'Silence', 'Media'],
#  '#solittle': ['#', 'so', 'little'],
#  '#LoveForCanada': ['#', 'Love', 'For', 'Canada'],
#  '#pedantry': ['#', 'pedantry'],
#  '#PRFail': ['#', 'P', 'R', 'Fail'],
#  '#BlackOnBlack': ['#', 'B', 'lac', 'kOn', 'Black'],
#  '#Freedom': ['#', 'Freedom'],
#  '#RIP': ['#', 'RIP'],
#  '#IslamicState': ['#', 'Islamic', 'State'],
#  '#unarmedWhitepeople': ['#', 'unarmed', 'White', 'people'],
#  '#goFurself': ['#', 'go', 'Fur', 'self'],
#  '#blackmirror': ['#', 'black', 'mirror'],
#  '#justsayin': ['#', 'j', 'us', 'ts', 'ayin'],
#  '#Gunsense': ['#', 'G', 'unsense'],
#  '#convenient': ['#', 'convenient'],
#  '#Airbus320': ['#', 'Air', 'bus', '3', '2', '0'],
#  '#wankers': ['#', 'wan', 'k', 'ers'],
#  '#PrayForSydneyHostages': ['#', 'Pray', 'For', 'Syd', 'n', 'ey', 'Hostages'],
#  '#polqc': ['#', 'pol', 'q', 'c'],
#  '#StayClassy': ['#', 'Stay', 'Classy'],
#  '#imnotnaive': ['#', 'i', 'm', 'not', 'naive'],
#  '#WHATISWRONGWITHYOU': ['#', 'W', 'H', 'ATIS', 'WRONG', 'WITH', 'YOU'],
#  '#Mobocracy': ['#', 'Mobocracy'],
#  '#milkit': ['#', 'mil', 'kit'],
#  '#CanadaNeedsWBC': ['#', 'Canada', 'Needs', 'W', 'B', 'C'],
#  '#newsspeak': ['#', 'news', 'speak'],
#  '#KSLAM': ['#', 'K', 'SLAM'],
#  '#redblacks': ['#', 'red', 'blacks'],
#  '#Americans': ['#', 'Americans'],
#  '#VictimBlaming': ['#', 'Victim', 'Blaming'],
#  '#PresidentMukherjee': ['#', 'President', 'Mu', 'k', 'her', 'j', 'e', 'e'],
#  '#peaceout': ['#', 'peace', 'out'],
#  '#Violence': ['#', 'Violence'],
#  '#mccann': ['#', 'm', 'c', 'c', 'ann'],
#  '#AFP': ['#', 'A', 'F', 'P'],
#  '#Germanwings': ['#', 'German', 'wings'],
#  '#BeSafeOttawa': ['#', 'Be', 'Safe', 'Ottawa'],
#  '#المهاجم': ['#', 'ا', 'ل', 'م', 'ه', 'ا', 'ج', 'م'],
#  '#SithLords': ['#', 'Sith', 'Lords'],
#  '#Liberals': ['#', 'Liberals'],
#  '#OttawaShootings': ['#', 'Ottawa', 'Shootings'],
#  '#iStandWithCharlie': ['#', 'i', 'Stand', 'With', 'Charlie'],
#  '#HangEmHigh': ['#', 'Han', 'gEm', 'High'],
#  '#joke': ['#', 'joke'],
#  '#solidarity': ['#', 'solidarity'],
#  '#tongueincheek': ['#', 'tongue', 'in', 'cheek'],
#  '#guilty': ['#', 'guilty'],
#  '#MomsOnlyChild': ['#', 'M', 'om', 'sOnly', 'Child'],
#  '#Sidney': ['#', 'Sidney'],
#  '#FreedomOfSpeech': ['#', 'Freedom', 'Of', 'Speech'],
#  '#crimesAgainstHumanity': ['#', 'crimes', 'Against', 'Humanity'],
#  '#genderbiasedlaw': ['#', 'gender', 'biased', 'law'],
#  '#JeSuisJuif': ['#', 'JeSu', 'is', 'Ju', 'if'],
#  '#sydneystrong': ['#', 'syd', 'n', 'ey', 'strong'],
#  '#delusional': ['#', 'delusional'],
#  '#nhpolitics': ['#', 'n', 'h', 'politics'],
#  '#Jesuischarliehebdo': ['#', 'Jesu', 'is', 'charlie', 'he', 'b', 'do'],
#  '#lmao': ['#', 'l', 'mao'],
#  '#nicetry': ['#', 'nice', 'try'],
#  '#MICHAELBROWN': ['#', 'MICHAEL', 'BROWN'],
#  '#sydneycafe': ['#', 'syd', 'n', 'ey', 'ca', 'fe'],
#  '#RafaelCruz': ['#', 'Rafael', 'C', 'r', 'u', 'z'],
#  '#inners': ['#', 'inn', 'ers'],
#  '#MURDERING': ['#', 'MURDERING'],
#  '#PeaceOnEarth': ['#', 'Pea', 'c', 'eOn', 'Earth'],
#  '#notaclue': ['#', 'no', 'ta', 'clue'],
#  '#NotParadise': ['#', 'Not', 'Paradise'],
#  '#FCC': ['#', 'F', 'C', 'C'],
#  '#cougar': ['#', 'cougar'],
#  '#CoverUp': ['#', 'Cover', 'Up'],
#  '#bbcbias': ['#', 'b', 'b', 'c', 'bias'],
#  '#FergusonLies': ['#', 'Ferguson', 'Lies'],
#  '#theWholePicture': ['#', 'the', 'Whole', 'Picture'],
#  '#ninjaplease': ['#', 'ninja', 'please'],
#  '#PT': ['#', 'P', 'T'],
#  '#NotInMyName': ['#', 'No', 'tIn', 'My', 'Name'],
#  '#ottshooting': ['#', 'o', 't', 't', 'shooting'],
#  '#Ford': ['#', 'Ford'],
#  '#Wikieaks': ['#', 'Wi', 'k', 'ie', 'aks'],
#  '#TooManyCrashes': ['#', 'Too', 'Many', 'Crashes'],
#  '#GOP': ['#', 'GO', 'P'],
#  '#ZeroTolerance': ['#', 'Zero', 'Tolerance'],
#  '#airbus': ['#', 'air', 'bus'],
#  '#psych': ['#', 'psych'],
#  '#GPC': ['#', 'G', 'P', 'C'],
#  '#Fell': ['#', 'Fell'],
#  '#Furgeson': ['#', 'F', 'urge', 'son'],
#  '#photoshop': ['#', 'photo', 'shop'],
#  '#military': ['#', 'military'],
#  '#CharlyHebdo': ['#', 'Char', 'ly', 'He', 'b', 'do'],
#  '#StayWoke': ['#', 'Stay', 'Woke'],
#  '#KevinVickers': ['#', 'Kevin', 'Vick', 'ers'],
#  '#Crowdfunding': ['#', 'Crowd', 'fun', 'ding'],
#  '#charliehedbo': ['#', 'char', 'li', 'eh', 'ed', 'bo'],
#  '#Right': ['#', 'Right'],
#  '#Government': ['#', 'Government'],
#  '#WePray': ['#', 'We', 'Pray'],
#  '#corporateNews': ['#', 'corporate', 'News'],
#  '#MSGTheFilm': ['#', 'MS', 'G', 'The', 'Film'],
#  '#MaryamrajaviI': ['#', 'Mar', 'yam', 'raja', 'v', 'i', 'I'],
#  '#nra': ['#', 'n', 'ra'],
#  '#FergusonPoliceAparthied': ['#', 'Ferguson', 'Police', 'Apart', 'hied'],
#  '#CIA': ['#', 'C', 'I', 'A'],
#  '#EVERYTHING': ['#', 'EVERYTHING'],
#  '#FR': ['#', 'F', 'R'],
#  '#GermanWings': ['#', 'German', 'Wings'],
#  '#policestate': ['#', 'po', 'li', 'c', 'estate'],
#  '#Israeli': ['#', 'Israeli'],
#  '#MyPeopleMyPeople': ['#', 'My', 'People', 'My', 'People'],
#  '#WayToGoFerguson': ['#', 'Way', 'To', 'Go', 'Ferguson'],
#  '#Anarchy': ['#', 'Anarchy'],
#  '#Smallbiz': ['#', 'Small', 'biz'],
#  "#Obama's": ['#', 'O', 'b', 'ama', "'", 's'],
#  '#NYPD': ['#', 'N', 'Y', 'P', 'D'],
#  '#WhiteMuslims': ['#', 'Whit', 'eMus', 'li', 'ms'],
#  '#fact': ['#', 'fact'],
#  '#tank': ['#', 'tank'],
#  '#ceasefire': ['#', 'cease', 'fire'],
#  '#Israel': ['#', 'Israel'],
#  '#Rotherham': ['#', 'Rother', 'ham'],
#  '#charliehebdo': ['#', 'charlie', 'he', 'b', 'do'],
#  '#WonderWoman': ['#', 'Wonder', 'Woman'],
#  '#Kargil': ['#', 'K', 'argil'],
#  '#Rednecks': ['#', 'Red', 'necks'],
#  '#FalseFlag': ['#', 'False', 'Flag'],
#  '#reparations': ['#', 'reparations'],
#  '#ProbablyNot': ['#', 'Probably', 'Not'],
#  '#Barbarism': ['#', 'Barbarism'],
#  '#kiteintheoldcity': ['#', 'kite', 'in', 'the', 'old', 'city'],
#  '#ffrf': ['#', 'f', 'f', 'r', 'f'],
#  '#toodumbtobedumb': ['#', 'too', 'dumb', 'to', 'bedumb'],
#  '#SCOTTBROWN': ['#', 'SCOTT', 'BROWN'],
#  '#Revenge': ['#', 'Revenge'],
#  '#BostonStrong': ['#', 'Boston', 'Strong'],
#  '#God': ['#', 'God'],
#  '#charlie_hebdo': ['#', 'charlie', '_', 'he', 'b', 'do'],
#  '#HandsUpDontRobMe': ['#', 'Hand', 'sUp', 'Dont', 'Rob', 'Me'],
#  '#muricalogic': ['#', 'm', 'uri', 'ca', 'logic'],
#  '#USAID': ['#', 'U', 'SAID'],
#  '#OccupyFerguson': ['#', 'Occupy', 'Ferguson'],
#  '#Paris': ['#', 'Paris'],
#  '#religionofpeace': ['#', 'religion', 'of', 'peace'],
#  '#Attack': ['#', 'Attack'],
#  '#truenorthstrongandfree': ['#', 'true', 'north', 'strong', 'and', 'free'],
#  '#VancouverCanada': ['#', 'Van', 'c', 'o', 'u', 'v', 'er', 'Canada'],
#  '#PrioritiesMessedUp': ['#', 'Priorities', 'Messe', 'dUp'],
#  '#sadinns': ['#', 'sad', 'inns'],
#  '#nudity_bitterly_cold': ['#', 'nudity', '_', 'bitterly', '_', 'cold'],
#  '#2UnarmedBLACKS': ['#', '2', 'Unarmed', 'BLACKS'],
#  '#PrayForParis': ['#', 'Pray', 'For', 'Paris'],
#  '#CharlieHebdoFalseFlag': ['#', 'Charlie', 'He', 'b', 'do', 'False', 'Flag'],
#  '#VoterPlantation': ['#', 'Voter', 'Plantation'],
#  '#Black': ['#', 'Black'],
#  '#phony': ['#', 'phony'],
#  '#repeated': ['#', 'repeated'],
#  '#asshole': ['#', 'as', 'shole'],
#  '#heavyheart': ['#', 'heavy', 'heart'],
#  '#whatever': ['#', 'whatever'],
#  '#patience': ['#', 'patience'],
#  '#blackgirlsrock': ['#', 'black', 'girls', 'rock'],
#  '#ivegotyourback911': ['#',
#   'i',
#   'v',
#   'e',
#   'got',
#   'your',
#   'back',
#   '9',
#   '1',
#   '1'],
#  '#siege': ['#', 'siege'],
#  '#CanadaUnderAttack': ['#', 'Canada', 'Under', 'Attack'],
#  '#STL': ['#', 'ST', 'L'],
#  '#StaySafeSydney': ['#', 'Stay', 'Safe', 'Syd', 'n', 'ey'],
#  '#dontshoot': ['#', 'dont', 'shoot'],
#  '#Kudos': ['#', 'Kudos'],
#  '#702sydney': ['#', '7', '0', '2', 'syd', 'n', 'ey'],
#  '#dirtyTruth': ['#', 'dirty', 'Truth'],
#  '#westernsydney': ['#', 'western', 'syd', 'n', 'ey'],
#  '#isisMerda': ['#', 'i', 'sis', 'Mer', 'da'],
#  '#FuckIslam': ['#', 'Fu', 'c', 'k', 'Islam'],
#  '#cbc': ['#', 'c', 'b', 'c'],
#  '#MartialLaw': ['#', 'Martial', 'Law'],
#  '#UsefulImbecile': ['#', 'Useful', 'Imbecile'],
#  '#Canpoli': ['#', 'Can', 'po', 'li'],
#  '#C_vous_avez': ['#', 'C', '_', 'v', 'o', 'us', '_', 'ave', 'z'],
#  '#FirstAmendment': ['#', 'First', 'Amendment'],
#  '#Justice4RameshJadhav': ['#',
#   'Justice',
#   '4',
#   'Ramesh',
#   'J',
#   'a',
#   'dha',
#   'v'],
#  '#CANADA': ['#', 'CANADA'],
#  '#Gaza': ['#', 'Ga', 'za'],
#  '#arms': ['#', 'arms'],
#  "#Ottawa's": ['#', 'Ottawa', "'", 's'],
#  '#heroesinlifenotdeath': ['#', 'he', 'roe', 'sin', 'life', 'not', 'death'],
#  '#Fans': ['#', 'Fans'],
#  '#Hypocrisy': ['#', 'Hypocrisy'],
#  '#MichaelBrown': ['#', 'Michael', 'Brown'],
#  '#CHURCHOFENGLAND': ['#', 'C', 'H', 'UR', 'CHO', 'FEN', 'GLAND'],
#  '#HarNof': ['#', 'HarN', 'of'],
#  '#HamOnt': ['#', 'Ha', 'mOnt'],
#  '#Psychology': ['#', 'Psychology'],
#  '#teamsheike': ['#', 'team', 'she', 'ike'],
#  '#freeexpression': ['#', 'free', 'expression'],
#  '#RoyStewart': ['#', 'Roy', 'Stewart'],
#  '#thug': ['#', 'thug'],
#  '#wtf': ['#', 'w', 't', 'f'],
#  '#ConMen': ['#', 'Con', 'Men'],
#  '#lawabidinggunowner': ['#', 'law', 'abiding', 'gun', 'owner'],
#  '#anarchy': ['#', 'anarchy'],
#  '#Rojava': ['#', 'Ro', 'java'],
#  '#proud': ['#', 'p', 'roud'],
#  '#YourGodsNotRealButMineIs': ['#',
#   'Your',
#   'God',
#   'sNot',
#   'Real',
#   'But',
#   'Mine',
#   'Is'],
#  '#CPC': ['#', 'C', 'P', 'C'],
#  '#parisattack': ['#', 'paris', 'attack'],
#  '#TortureReport': ['#', 'Torture', 'Report'],
#  '#unarmedblackteen': ['#', 'unarmed', 'black', 'teen'],
#  '#edgy': ['#', 'edgy'],
#  '#Mikebrown': ['#', 'Mike', 'brown'],
#  '#Hamilton': ['#', 'Hamilton'],
#  '#Satire': ['#', 'Satire'],
#  '#impressed': ['#', 'i', 'm', 'pressed'],
#  '#bestcityintheworld': ['#', 'best', 'cit', 'yin', 'the', 'world'],
#  '#Germanwing': ['#', 'German', 'wing'],
#  '#cia': ['#', 'c', 'i', 'a'],
#  '#LiberalLogic': ['#', 'Liberal', 'Logic'],
#  '#ParisAttack': ['#', 'Paris', 'Attack'],
#  '#LGBT': ['#', 'L', 'G', 'B', 'T'],
#  '#BlackYouthMatter': ['#', 'Black', 'Youth', 'Matter'],
#  '#onsemoquedenous': ['#', 'on', 'se', 'mo', 'q', 'u', 'e', 'de', 'nous'],
#  '#JESUISCHARLIE': ['#', 'JESU', 'IS', 'CHARLIE'],
#  '#Diversity': ['#', 'Diversity'],
#  '#double': ['#', 'double'],
#  '#HinduMuslimSikhIsai': ['#', 'Hind', 'uMu', 'slim', 'Si', 'k', 'hI', 'sai'],
#  '#moron': ['#', 'moron'],
#  '#roft': ['#', 'r', 'oft'],
#  '#Token': ['#', 'Token'],
#  '#GreenWings': ['#', 'GreenWings'],
#  '#r4today': ['#', 'r', '4', 'today'],
#  '#Networking': ['#', 'Net', 'working'],
#  '#ProtectItOrLoseIt': ['#', 'Pro', 'tec', 'tIt', 'OrLo', 'seIt'],
#  '#islamophobia': ['#', 'i', 'sla', 'moph', 'obi', 'a'],
#  '#islam': ['#', 'islam'],
#  '#NoThanks': ['#', 'No', 'Thanks'],
#  '#MIKEBROWN': ['#', 'MIKE', 'BROWN'],
#  '#fox': ['#', 'fox'],
#  '#152': ['#', '1', '5', '2'],
#  '#weneedallareblacks': ['#', 'we', 'need', 'all', 'are', 'blacks'],
#  '#follow': ['#', 'follow'],
#  '#AllLivesMatter': ['#', 'All', 'Live', 'sMatter'],
#  '#ViveLaFranceViveLaNation': ['#',
#   'V',
#   'i',
#   'veLa',
#   'F',
#   'rance',
#   'V',
#   'i',
#   'veLa',
#   'Nation'],
#  '#Leadership': ['#', 'Leadership'],
#  '#CharieHebdo': ['#', 'Cha', 'rie', 'He', 'b', 'do'],
#  '#AmIRight': ['#', 'AmI', 'Right'],
#  '#137GUNSHOTS': ['#', '1', '3', '7', 'GUNSHOTS'],
#  '#ArtistHelp': ['#', 'Artist', 'Help'],
#  '#PTSD': ['#', 'P', 'TS', 'D'],
#  '#awesome': ['#', 'awesome'],
#  '#ShittyButTrue': ['#', 'S', 'hit', 't', 'y', 'But', 'True'],
#  '#smem': ['#', 's', 'mem'],
#  '#watchyourback': ['#', 'watch', 'your', 'back'],
#  '#Excessive': ['#', 'Excessive'],
#  '#jul': ['#', 'ju', 'l'],
#  '#jesuischarlie': ['#', 'jesu', 'is', 'charlie'],
#  '#FEMA': ['#', 'FE', 'MA'],
#  '#Ignorant': ['#', 'Ignorant'],
#  '#kosher': ['#', 'kosher'],
#  '#world': ['#', 'world'],
#  '#class': ['#', 'class'],
#  '#strawman': ['#', 'strawman'],
#  '#Equality': ['#', 'Equality'],
#  '#PrayersforParis': ['#', 'Prayers', 'for', 'Paris'],
#  '#ISIL': ['#', 'I', 'SIL'],
#  '#MakeInIndia': ['#', 'Make', 'In', 'India'],
#  '#UnitedbyWings': ['#', 'United', 'by', 'Wings'],
#  '#not': ['#', 'not'],
#  '#FergusonShooting': ['#', 'Ferguson', 'Shooting'],
#  '#DONTSHOOT': ['#', 'DONT', 'SHOOT'],
#  '#KeepingItRealRadio': ['#', 'Kee', 'pin', 'gIt', 'Real', 'Radio'],
#  '#SecretService': ['#', 'Secret', 'Service'],
#  '#DeathCult': ['#', 'Death', 'Cult'],
#  '#Drill': ['#', 'Drill'],
#  '#Chinada': ['#', 'Chin', 'ada'],
#  '#CamerasOnCopsNow': ['#', 'Camera', 'sOn', 'Cop', 'sNow'],
#  '#blackvalue': ['#', 'black', 'value'],
#  '#imnotcharlie': ['#', 'i', 'm', 'not', 'charlie'],
#  '#poorjournalism': ['#', 'poor', 'journalism'],
#  '#YES': ['#', 'YES'],
#  '#irony': ['#', 'irony'],
#  '#JeSuisCharlie': ['#', 'JeSu', 'is', 'Charlie'],
#  '#HULK': ['#', 'HULK'],
#  '#militarized': ['#', 'militarized'],
#  '#passiveness': ['#', 'passiveness'],
#  '#Fioptics': ['#', 'Fi', 'optics'],
#  '#FreeMarineA': ['#', 'Free', 'Mari', 'neA'],
#  '#svenskar': ['#', 's', 'v', 'ens', 'k', 'ar'],
#  '#EAGLES': ['#', 'EAGLES'],
#  '#JihadistJoe': ['#', 'Jihad', 'ist', 'Joe'],
#  '#perspective': ['#', 'perspective'],
#  '#sick': ['#', 'sick'],
#  '#journalismisnotacrime': ['#',
#   'jo',
#   'urna',
#   'lis',
#   'mis',
#   'no',
#   'ta',
#   'crime'],
#  '#Sick': ['#', 'Sick'],
#  '#zionismiswrong': ['#', 'z', 'io', 'nis', 'mis', 'wrong'],
#  '#endreligionnow': ['#', 'end', 'religion', 'now'],
#  '#israelchildrenkiller': ['#', 'israel', 'children', 'killer'],
#  '#11': ['#', '1', '1'],
#  '#Breaking': ['#', 'Breaking'],
#  '#Sydneycafeseige': ['#', 'Syd', 'n', 'ey', 'ca', 'fe', 'se', 'i', 'ge'],
#  '#syndeysiege': ['#', 's', 'yn', 'dey', 'siege'],
#  '#HDL': ['#', 'H', 'D', 'L'],
#  '#ImpactOnFlying': ['#', 'Imp', 'actOn', 'Flying'],
#  '#StaySafeOttawa': ['#', 'Stay', 'Safe', 'Ottawa'],
#  '#standards': ['#', 'standards'],
#  '#standwithisrael': ['#', 'stand', 'with', 'israel'],
#  '#CleanIndia': ['#', 'Clean', 'India'],
#  '#Auspol': ['#', 'A', 'us', 'pol'],
#  '#notallamericans': ['#', 'no', 'tall', 'americans'],
#  '#policebrutality': ['#', 'police', 'brutality'],
#  '#CrushTheTerror': ['#', 'Crush', 'The', 'Terror'],
#  '#HUalum': ['#', 'HU', 'alum'],
#  '#NotGunnaHappen': ['#', 'Not', 'Gun', 'na', 'Happen'],
#  '#mightaswellbeCubaorChina': ['#',
#   'might',
#   'aswell',
#   'be',
#   'Cuba',
#   'or',
#   'China'],
#  '#NAACPBombing': ['#', 'NAA', 'C', 'P', 'Bom', 'bing'],
#  '#openminds': ['#', 'open', 'minds'],
#  '#DIY': ['#', 'DI', 'Y'],
#  '#14Words': ['#', '1', '4', 'Words'],
#  '#LETSDOFURY': ['#', 'LETS', 'DO', 'FURY'],
#  '#hockey': ['#', 'hockey'],
#  '#senseless': ['#', 'senseless'],
#  '#Those': ['#', 'Those'],
#  '#India': ['#', 'India'],
#  '#ReligionofPeace': ['#', 'Religion', 'of', 'Peace'],
#  '#Patriots': ['#', 'Patriots'],
#  '#rop': ['#', 'ro', 'p'],
#  '#UKnowWhat': ['#', 'U', 'Know', 'What'],
#  '#CanadaStrong': ['#', 'Canada', 'Strong'],
#  '#wth': ['#', 'w', 'th'],
#  '#NBP': ['#', 'N', 'B', 'P'],
#  '#theyluvit': ['#', 'they', 'lu', 'v', 'it'],
#  '#StLouisShooting': ['#', 'St', 'Louis', 'Shooting'],
#  '#America': ['#', 'America'],
#  '#outlawIslam': ['#', 'outlaw', 'Islam'],
#  '#oklahomabeheading': ['#', 'ok', 'l', 'ahom', 'abe', 'heading'],
#  '#13RACISTCOPS': ['#', '1', '3', 'RACIST', 'COPS'],
#  '#трагедия': ['#', 'т', 'р', 'а', 'г', 'е', 'д', 'и', 'я'],
#  '#Digne': ['#', 'Dig', 'ne'],
#  '#coverup': ['#', 'cover', 'up'],
#  '#thedayIunfollowedwikileaks': ['#',
#   'the',
#   'day',
#   'I',
#   'unfollowed',
#   'wi',
#   'k',
#   'i',
#   'leaks'],
#  '#foxnews': ['#', 'fox', 'news'],
#  '#building7': ['#', 'building', '7'],
#  '#Isis-style': ['#', 'I', 'sis', '-', 'style'],
#  '#parisisburning': ['#', 'parisis', 'burning'],
#  '#JewsForScalise': ['#', 'Jews', 'F', 'orS', 'ca', 'lise'],
#  '#depression': ['#', 'depression'],
#  '#brand': ['#', 'brand'],
#  '#FALSEFLAG': ['#', 'FALSE', 'FLAG'],
#  '#METHODISTCONF': ['#', 'METHODIST', 'CON', 'F'],
#  '#Sept11': ['#', 'Sept', '1', '1'],
#  '#echr': ['#', 'e', 'c', 'h', 'r'],
#  '#unnamed': ['#', 'unnamed'],
#  '#KeyStoner': ['#', 'KeyStoner'],
#  '#PewChurchAttack': ['#', 'Pew', 'Church', 'Attack'],
#  '#developing': ['#', 'developing'],
#  '#FoxNews': ['#', 'Fox', 'News'],
#  '#agenda': ['#', 'agenda'],
#  '#Liberal': ['#', 'Liberal'],
#  '#GoJaysGo': ['#', 'Go', 'Jays', 'Go'],
#  '#weak': ['#', 'weak'],
#  '#Repent': ['#', 'Repent'],
#  '#StLouisCountyPD': ['#', 'St', 'Louis', 'County', 'P', 'D'],
#  '#FixFlying': ['#', 'Fix', 'Flying'],
#  '#TwitterKurds': ['#', 'Twitter', 'Kurds'],
#  '#September11': ['#', 'September', '1', '1'],
#  '#4U2521': ['#', '4', 'U', '2', '5', '2', '1'],
#  '#CharlieHedbo': ['#', 'Char', 'li', 'eH', 'ed', 'bo'],
#  "#I'llridewithyou": ['#', 'I', "'", 'l', 'l', 'ride', 'with', 'you'],
#  '#stopfuelingfire': ['#', 'stop', 'fueling', 'fire'],
#  '#Sickening': ['#', 'Sickening'],
#  '#NUJ': ['#', 'NU', 'J'],
#  '#sydney': ['#', 'syd', 'n', 'ey'],
#  '#ACAB': ['#', 'A', 'CAB'],
#  '#islamophobe': ['#', 'i', 'sla', 'moph', 'obe'],
#  '#nothing': ['#', 'nothing'],
#  '#raceriot': ['#', 'race', 'riot'],
#  '#nonMuslimlivesmatter': ['#', 'non', 'Mu', 'slim', 'live', 'smatter'],
#  '#guncontrol': ['#', 'g', 'uncontrol'],
#  '#WeAreJewish': ['#', 'We', 'Are', 'Jewish'],
#  '#SydneyCafe': ['#', 'Syd', 'n', 'ey', 'Ca', 'fe'],
#  '#execute': ['#', 'execute'],
#  '#LoveUSydney': ['#', 'Lo', 'v', 'eU', 'Syd', 'n', 'ey'],
#  '#Новороссия': ['#', 'Н', 'о', 'в', 'о', 'р', 'о', 'с', 'с', 'и', 'я'],
#  '#discription': ['#', 'di', 'scription'],
#  '#Cdnpoli': ['#', 'C', 'd', 'n', 'po', 'li'],
#  '#notATypo': ['#', 'no', 'tA', 'Typo'],
#  '#Sydneyseige': ['#', 'Syd', 'n', 'ey', 'se', 'i', 'ge'],
#  '#Calgary': ['#', 'Cal', 'gary'],
#  '#Sotlof': ['#', 'Sot', 'lof'],
#  '#muslims': ['#', 'mus', 'li', 'ms'],
#  '#news': ['#', 'news'],
#  '#OTTAWA': ['#', 'OTTAWA'],
#  '#ParisShooting': ['#', 'Paris', 'Shooting'],
#  '#Spirituality': ['#', 'Spirituality'],
#  '#HuffPost': ['#', 'Huff', 'Post'],
#  '#DoorKnob': ['#', 'DoorKnob'],
#  "#I'llReadWithYou": ['#', 'I', "'", 'l', 'l', 'Read', 'With', 'You'],
#  '#ReligionOfPeace': ['#', 'Religion', 'Of', 'Peace'],
#  '#judi': ['#', 'j', 'udi'],
#  '#новости': ['#', 'н', 'о', 'в', 'о', 'с', 'т', 'и'],
#  '#nopeace': ['#', 'no', 'peace'],
#  '#FB': ['#', 'F', 'B'],
#  '#MH17': ['#', 'M', 'H', '1', '7'],
#  '#LeftistLuzer': ['#', 'Leftist', 'Lu', 'zer'],
#  '#Bands': ['#', 'Bands'],
#  '#Haines': ['#', 'H', 'ai', 'nes'],
#  '#FortHood': ['#', 'Fort', 'Hood'],
#  '#besafe': ['#', 'be', 'safe'],
#  '#American_values': ['#', 'American', '_', 'values'],
#  '#SportsCentre': ['#', 'Sport', 'sCent', 're'],
#  '#FreeSpeech': ['#', 'Free', 'Speech'],
#  '#ONUS': ['#', 'ONUS'],
#  '#StLootus': ['#', 'St', 'Lo', 'otus'],
#  '#JanDhanYojana': ['#', 'Jan', 'Dhan', 'Yojana'],
#  '#Organized': ['#', 'Organized'],
#  '#FilthyCanadaUnderSiege': ['#', 'Filthy', 'Canada', 'Under', 'Siege'],
#  '#FergusonPolice': ['#', 'Ferguson', 'Police'],
#  '#uspoli': ['#', 'us', 'po', 'li'],
#  '#UnitedByWings': ['#', 'United', 'By', 'Wings'],
#  '#ATerroristCannotBeARealMuslim': ['#',
#   'A',
#   'Terrorist',
#   'Cannot',
#   'Be',
#   'AReal',
#   'Mu',
#   'slim'],
#  '#RACIST': ['#', 'RACIST'],
#  '#ccot': ['#', 'c', 'cot'],
#  '#Iloveasuburnedcountry': ['#',
#   'I',
#   'lo',
#   'v',
#   'eas',
#   'u',
#   'burned',
#   'country'],
#  '#DarrenWilson': ['#', 'Darren', 'Wilson'],
#  '#hit': ['#', 'hit'],
#  '#confused': ['#', 'confused'],
#  '#Benghazi': ['#', 'Ben', 'ghazi'],
#  '#youidjit': ['#', 'you', 'id', 'j', 'it'],
#  '#faze': ['#', 'faze'],
#  '#Veterans': ['#', 'Veterans'],
#  '#Murder': ['#', 'Murder'],
#  '#enemy': ['#', 'enemy'],
#  '#Shooter': ['#', 'Shooter'],
#  '#FergusonCoverUp': ['#', 'Ferguson', 'Cover', 'Up'],
#  '#ciaunderbus': ['#', 'c', 'i', 'a', 'under', 'bus'],
#  '#MakeBacon': ['#', 'Make', 'Bacon'],
#  '#refugee': ['#', 'refugee'],
#  '#HANDSUPdontshoot': ['#', 'HAND', 'SUP', 'dont', 'shoot'],
#  '#press': ['#', 'press'],
#  '#Islaimcterror': ['#', 'Is', 'l', 'aim', 'c', 'terror'],
#  '#IWontReadYou': ['#', 'I', 'Won', 'tRead', 'You'],
#  '#snipertime': ['#', 'sniper', 'time'],
#  '#mindless': ['#', 'mindless'],
#  '#iamcharlie': ['#', 'i', 'am', 'charlie'],
#  '#MuslimConvert': ['#', 'Mu', 'slim', 'Convert'],
#  '#usa': ['#', 'u', 'sa'],
#  '#MackBraaoown': ['#', 'Mack', 'Bra', 'ao', 'own'],
#  '#mooi': ['#', 'moo', 'i'],
#  '#DammartinEnGoele': ['#', 'Dam', 'martin', 'En', 'Goel', 'e'],
#  '#PerpetualRecomplicationStrategy': ['#',
#   'Perpetual',
#   'Recomplication',
#   'Strategy'],
#  '#AccidenteAvionARV': ['#',
#   'A',
#   'c',
#   'c',
#   'i',
#   'den',
#   'teA',
#   'v',
#   'io',
#   'nAR',
#   'V'],
#  '#cartoonists': ['#', 'cartoonists'],
#  '#thoughtsandprayers': ['#', 'thought', 'sand', 'prayers'],
#  '#Classy': ['#', 'Classy'],
#  '#UNFOLLOW': ['#', 'UN', 'FOLLOW'],
#  '#pressfreedom': ['#', 'press', 'freedom'],
#  '#WeOweIt2EachOther': ['#', 'We', 'Owe', 'It', '2', 'Each', 'Other'],
#  '#NotCHARGED': ['#', 'Not', 'CHARGED'],
#  '#CRIMINAL': ['#', 'CRIMINAL'],
#  '#wikileaks': ['#', 'wi', 'k', 'i', 'leaks'],
#  '#foodforthought': ['#', 'food', 'for', 'thought'],
#  '#JustinBieber': ['#', 'Justin', 'B', 'ie', 'ber'],
#  "#ICan'tBreathe": ['#', 'I', 'Can', "'", 't', 'Breathe'],
#  '#truecount': ['#', 'true', 'count'],
#  '#prt': ['#', 'p', 'r', 't'],
#  '#NOW': ['#', 'NOW'],
#  '#WeAreONE': ['#', 'We', 'Are', 'ONE'],
#  '#DrEd': ['#', 'D', 'rEd'],
#  '#parliamentsquare': ['#', 'parliament', 'square'],
#  '#aerotoxic': ['#', 'aero', 'toxic'],
#  '#wow': ['#', 'wow'],
#  '#Malala': ['#', 'M', 'alala'],
#  '#ChokeHold': ['#', 'Choke', 'Hold'],
#  '#LiberteDelaPresse': ['#', 'Liber', 'te', 'De', 'laP', 'res', 'se'],
#  '#yeg': ['#', 'ye', 'g'],
#  '#Sumpmwrong': ['#', 'Sump', 'm', 'wrong'],
#  '#ProofPlease': ['#', 'Proof', 'Please'],
#  '#facts': ['#', 'facts'],
#  '#WeLoveYouCanada': ['#', 'We', 'Love', 'You', 'Canada'],
#  '#hostage': ['#', 'hostage'],
#  '#Fail': ['#', 'Fail'],
#  '#dearyme': ['#', 'd', 'ea', 'ryme'],
#  '#ottawastrong': ['#', 'ottawa', 'strong'],
#  '#racist': ['#', 'racist'],
#  '#blockedbybishop': ['#', 'blocked', 'by', 'bishop'],
#  '#good': ['#', 'good'],
#  '#LetThatSinkIn': ['#', 'Let', 'That', 'Sin', 'kIn'],
#  '#LikeLondon': ['#', 'Li', 'k', 'eLon', 'don'],
#  '#Manly': ['#', 'Manly'],
#  '#welcometoSTL': ['#', 'welcome', 'toST', 'L'],
#  '#Tiananmen': ['#', 'Ti', 'anan', 'men'],
#  '#KeepingItReal': ['#', 'Kee', 'pin', 'gIt', 'Real'],
#  '#PeacefulProtest': ['#', 'Peaceful', 'Protest'],
#  '#waterboard': ['#', 'waterboard'],
#  '#Merkel': ['#', 'Merk', 'el'],
#  '#TerrorHasNoReligion': ['#', 'Terror', 'Has', 'No', 'Religion'],
#  '#ISRAEL': ['#', 'ISRAEL'],
#  '#victimcard': ['#', 'victim', 'card'],
#  '#WarOnWomen': ['#', 'Wa', 'rOn', 'Women'],
#  '#ParliamentHill': ['#', 'Par', 'li', 'amen', 'tHill'],
#  '#professionals': ['#', 'professionals'],
#  '#PrayForAustralia': ['#', 'Pray', 'For', 'Australia'],
#  '#GermanyWings': ['#', 'Ger', 'many', 'Wings'],
#  '#ottawa': ['#', 'ottawa'],
#  '#ABCbudgetcutsfuckyeah': ['#',
#   'AB',
#   'C',
#   'budget',
#   'cuts',
#   'fu',
#   'c',
#   'k',
#   'yeah'],
#  '#blowback': ['#', 'blowback'],
#  '#CactusJack': ['#', 'Cactus', 'Jack'],
#  '#Netanayahu': ['#', 'Net', 'anay', 'ahu'],
#  '#Jerusalem': ['#', 'Jerusalem'],
#  '#Saudi': ['#', 'Sa', 'udi'],
#  '#Penrith': ['#', 'Pen', 'r', 'i', 'th'],
#  '#cbcOTT': ['#', 'c', 'b', 'cOT', 'T'],
#  '#Assange': ['#', 'As', 'san', 'ge'],
#  '#OttawaToBoston': ['#', 'Ottawa', 'To', 'Boston'],
#  '#Montrouge': ['#', 'Mont', 'rouge'],
#  '#different': ['#', 'different'],
#  '#YourRacismIsShowing': ['#', 'Your', 'R', 'acis', 'mIs', 'Showing'],
#  '#jackass': ['#', 'jackass'],
#  '#tracking': ['#', 'tracking'],
#  '#Terrorist': ['#', 'Terrorist'],
#  '#lulz': ['#', 'lu', 'l', 'z'],
#  '#LindtCafeSiege': ['#', 'L', 'ind', 't', 'Ca', 'fe', 'Siege'],
#  '#apartheidstlouis': ['#', 'apartheid', 'st', 'louis'],
#  '#kellyfile': ['#', 'kelly', 'file'],
#  '#MEXICO': ['#', 'ME', 'XI', 'C', 'O'],
#  '#cowards': ['#', 'cowards'],
#  '#alqaeda': ['#', 'al', 'q', 'ae', 'da'],
#  '#dipshit': ['#', 'dips', 'hit'],
#  '#der': ['#', 'd', 'er'],
#  '#VoteForNesha': ['#', 'Vote', 'For', 'Ne', 'sha'],
#  '#TeinemanSquare': ['#', 'Te', 'i', 'ne', 'man', 'Square'],
#  '#AmazonPrime': ['#', 'Amazon', 'Prime'],
#  '#properganda': ['#', 'proper', 'ganda'],
#  '#MM330': ['#', 'M', 'M', '3', '3', '0'],
#  '#FactsonFactsonFacts': ['#', 'Fact', 'son', 'Fact', 'son', 'Facts'],
#  '#dhimmis': ['#', 'd', 'him', 'mis'],
#  '#mnwild': ['#', 'm', 'n', 'wild'],
#  '#EaglesNation': ['#', 'Eagles', 'Nation'],
#  '#Boston': ['#', 'Boston'],
#  '#Wikileaks': ['#', 'Wi', 'k', 'i', 'leaks'],
#  '#Foley': ['#', 'Fo', 'ley'],
#  '#foolsnotmartyrs': ['#', 'fool', 'snot', 'martyrs'],
#  '#AlpsCrash': ['#', 'Alps', 'Crash'],
#  '#conservativeasiankid': ['#', 'conservative', 'asian', 'k', 'id'],
#  '#OpenCarry': ['#', 'Open', 'Carry'],
#  '#heroes': ['#', 'heroes'],
#  '#9News': ['#', '9', 'News'],
#  '#Eagles': ['#', 'Eagles'],
#  '#real': ['#', 'real'],
#  '#occult': ['#', 'occult'],
#  '#IDIOTSERVANTS': ['#', 'IDIOT', 'SERVANTS'],
#  '#noshit': ['#', 'nos', 'hit'],
#  '#Favorite': ['#', 'Favorite'],
#  '#OCanada': ['#', 'O', 'Canada'],
#  '#RIGHTNOW': ['#', 'RIGHT', 'NOW'],
#  '#interesting': ['#', 'interesting'],
#  '#AlQaida': ['#', 'Al', 'Q', 'a', 'ida'],
#  '#MLB': ['#', 'M', 'L', 'B'],
#  '#DUHHH': ['#', 'D', 'U', 'H', 'H', 'H'],
#  '#KMOV': ['#', 'K', 'MO', 'V'],
#  '#911': ['#', '9', '1', '1'],
#  '#FactCheck': ['#', 'Fact', 'Check'],
#  '#peshwarattack': ['#', 'p', 'e', 'sh', 'war', 'attack'],
#  '#Iraq': ['#', 'Iraq'],
#  '#DEMOCRACY': ['#', 'DEMOCRACY'],
#  '#notwhatimseeing': ['#', 'not', 'wha', 'tim', 'seeing'],
#  '#ILLSHOPWITHJEW': ['#', 'ILL', 'SHOP', 'WITH', 'JEW'],
#  '#ClivenBundy': ['#', 'C', 'liven', 'Bundy'],
#  '#TeaNuts': ['#', 'Tea', 'Nuts'],
#  '#thankyou': ['#', 'thank', 'you'],
#  '#standwithterrorvictims': ['#', 'stand', 'with', 'terror', 'victims'],
#  '#TonyAbbott': ['#', 'Tony', 'Ab', 'bott'],
#  '#trauma': ['#', 'trauma'],
#  '#Earth': ['#', 'Earth'],
#  '#SMH': ['#', 'S', 'M', 'H'],
#  '#PeshawarAttack': ['#', 'P', 'e', 'sha', 'war', 'Attack'],
#  '#FilmThePolice': ['#', 'Film', 'The', 'Police'],
#  '#Veteran': ['#', 'Veteran'],
#  '#PrayForOttawa': ['#', 'Pray', 'For', 'Ottawa'],
#  '#pissoff': ['#', 'piss', 'off'],
#  '#stopthehate': ['#', 'stop', 'the', 'hate'],
#  '#copsaretops': ['#', 'cop', 'sare', 'tops'],
#  '#frustration': ['#', 'frustration'],
#  '#proudcanadian': ['#', 'p', 'roud', 'canadian'],
#  '#StreisandEffect': ['#', 'Stre', 'i', 'sand', 'Effect'],
#  '#Ottawa': ['#', 'Ottawa'],
#  '#MediaWatch': ['#', 'Me', 'di', 'aWatch'],
#  '#onpoli': ['#', 'on', 'po', 'li'],
#  '#HidingWontHelp': ['#', 'Hi', 'ding', 'Wont', 'Help'],
#  '#CharliHebdo': ['#', 'Char', 'li', 'He', 'b', 'do'],
#  '#defend': ['#', 'defend'],
#  '#Canadiancitizen': ['#', 'Canadian', 'citizen'],
#  '#owned': ['#', 'owned'],
#  '#Mindblowing': ['#', 'Mind', 'blowing'],
#  '#ато': ['#', 'а', 'т', 'о'],
#  '#rusian': ['#', 'r', 'us', 'ian'],
#  '#1A': ['#', '1', 'A'],
#  '#assange': ['#', 'as', 'san', 'ge'],
#  '#Pray': ['#', 'Pray'],
#  '#Apartheid': ['#', 'Apartheid'],
#  '#dontgiveupthefight': ['#', 'dont', 'give', 'up', 'the', 'fight'],
#  '#murica': ['#', 'm', 'uri', 'ca'],
#  '#AccidenteAereo': ['#', 'A', 'c', 'c', 'i', 'den', 'teA', 'ere', 'o'],
#  '#DieHard': ['#', 'DieHard'],
#  '#prayforparise': ['#', 'pray', 'for', 'p', 'arise'],
#  '#Blocked': ['#', 'Blocked'],
#  '#Cameron': ['#', 'Came', 'ron'],
#  '#Lindt': ['#', 'L', 'ind', 't'],
#  '#Blair': ['#', 'Blair'],
#  '#kmov': ['#', 'k', 'mo', 'v'],
#  '#MO': ['#', 'MO'],
#  '#aweshit': ['#', 'awes', 'hit'],
#  '#ottnews': ['#', 'o', 't', 't', 'news'],
#  '#MH370': ['#', 'M', 'H', '3', '7', '0'],
#  '#LiveInLove': ['#', 'Li', 'veIn', 'Love'],
#  '#FascistPolice': ['#', 'Fascist', 'Police'],
#  '#sydneycafesiege': ['#', 'syd', 'n', 'ey', 'ca', 'fe', 'siege'],
#  '#clayton': ['#', 'clayton'],
#  '#Quran': ['#', 'Q', 'uran'],
#  '#KeepPhilSafe': ['#', 'Keep', 'Phil', 'Safe'],
#  '#ProudlyFree': ['#', 'Proudly', 'Free'],
#  '#incredulous': ['#', 'incredulous'],
#  '#coady55': ['#', 'c', 'o', 'ady', '5', '5'],
#  '#justiceformikebrown': ['#', 'justice', 'for', 'mike', 'brown'],
#  '#WakeUpAmerica': ['#', 'Wa', 'keUp', 'America'],
#  '#Parisians': ['#', 'Parisians'],
#  '#4u9525': ['#', '4', 'u', '9', '5', '2', '5'],
#  '#divideandrule': ['#', 'divide', 'and', 'rule'],
#  '#MaryamRajavi': ['#', 'Mar', 'yam', 'Raja', 'v', 'i'],
#  '#atheism': ['#', 'atheism'],
#  '#weWontRideWithYou': ['#', 'we', 'Wont', 'Ride', 'With', 'You'],
#  '#ParisShootings': ['#', 'Paris', 'Shootings'],
#  '#pen_gun': ['#', 'pen', '_', 'gun'],
#  '#SebabSuntuk': ['#', 'Se', 'bab', 'Sun', 'tu', 'k'],
#  '#MuslimTerrorists': ['#', 'Mu', 'slim', 'Terrorists'],
#  '#junta': ['#', 'junta'],
#  "#Isis's": ['#', 'I', 'sis', "'", 's'],
#  '#brokenrecords': ['#', 'broken', 'records'],
#  '#chills': ['#', 'chills'],
#  '#Idiots': ['#', 'Idiots'],
#  '#no': ['#', 'no'],
#  '#2A': ['#', '2', 'A'],
#  '#hometown': ['#', 'home', 'town'],
#  '#Oklahoma': ['#', 'Oklahoma'],
#  '#BanuQuraizah': ['#', 'Ba', 'nu', 'Q', 'ur', 'ai', 'z', 'ah'],
#  '#wedpnotnegotiatewithterrorists': ['#',
#   'wed',
#   'p',
#   'not',
#   'negotiate',
#   'with',
#   'terrorists'],
#  '#scram': ['#', 'scram'],
#  '#FF': ['#', 'F', 'F'],
#  '#fucktard': ['#', 'fu', 'c', 'k', 'tar', 'd'],
#  '#KKK': ['#', 'K', 'K', 'K'],
#  '#ALLlivesMatter': ['#', 'ALL', 'live', 'sMatter'],
#  '#excitoes': ['#', 'ex', 'c', 'i', 'toes'],
#  '#maintainrights': ['#', 'maintain', 'rights'],
#  '#uneducatedpeopleproblems': ['#', 'uneducated', 'people', 'problems'],
#  '#fergusonanimals': ['#', 'ferguson', 'animals'],
#  '#WeStandWithYouParis': ['#', 'We', 'Stand', 'With', 'You', 'Paris'],
#  '#BusTourMovement': ['#', 'Bu', 'sTour', 'Movement'],
#  '#partoftheproblem': ['#', 'part', 'of', 'the', 'problem'],
#  '#isis': ['#', 'i', 'sis'],
#  '#RogueCops': ['#', 'Rogue', 'Cops'],
#  '#terrorsim': ['#', 'terror', 'sim'],
#  '#ICC4Israel': ['#', 'I', 'C', 'C', '4', 'Israel'],
#  '#proudaussie': ['#', 'p', 'roud', 'aussie'],
#  '#hope': ['#', 'hope'],
#  '#CanadianDucks': ['#', 'Canadian', 'Ducks'],
#  '#JeNeSuisPasCharlie': ['#', 'J', 'e', 'Ne', 'Sui', 'sPas', 'Charlie'],
#  '#peace': ['#', 'peace'],
#  '#inhumane': ['#', 'inhumane'],
#  '#SydneySiege': ['#', 'Syd', 'n', 'ey', 'Siege'],
#  '#AggressiveContact': ['#', 'Aggressive', 'Contact'],
#  '#AntiAmerican': ['#', 'Anti', 'American'],
#  '#BFFs': ['#', 'B', 'F', 'Fs'],
#  '#trytokeepup': ['#', 'tryt', 'okee', 'pup'],
#  '#ETDISCLOSURE': ['#', 'E', 'T', 'DISCLOSURE'],
#  '#AKP': ['#', 'AK', 'P'],
#  '#FreePalestine': ['#', 'Free', 'Pale', 'stine'],
#  '#fuckthepolice': ['#', 'fu', 'c', 'k', 'the', 'police'],
#  '#gunfail': ['#', 'gun', 'fail'],
#  '#Redlake': ['#', 'Red', 'lake'],
#  '#Muslim': ['#', 'Mu', 'slim'],
#  '#GetARope': ['#', 'GetA', 'Rope'],
#  '#Belgium': ['#', 'Bel', 'gi', 'um'],
#  '#BRILLIANT': ['#', 'BRILLIANT'],
#  '#Norighttobeoffended': ['#', 'No', 'right', 'tobe', 'offended'],
#  '#Sweden': ['#', 'S', 'w', 'eden'],
#  '#canadastrong': ['#', 'canada', 'strong'],
#  '#very': ['#', 'very'],
#  '#WARONBLACKMALES': ['#', 'WA', 'RON', 'BLACK', 'MALES'],
#  '#medicine_food': ['#', 'medicine', '_', 'food'],
#  '#BuyingTime': ['#', 'Buy', 'ing', 'Time'],
#  '#BlackLifeMatters': ['#', 'Black', 'Life', 'Matters'],
#  '#nonviolence': ['#', 'nonviolence'],
#  '#Bokoharam': ['#', 'Bo', 'ko', 'ha', 'ram'],
#  '#banksy': ['#', 'banks', 'y'],
#  '#SYDNEY': ['#', 'SYD', 'N', 'EY'],
#  '#doubletap': ['#', 'double', 'tap'],
#  '#overkill': ['#', 'over', 'kill'],
#  '#despicalbe': ['#', 'des', 'pic', 'albe'],
#  '#lindtcafe': ['#', 'l', 'ind', 't', 'ca', 'fe'],
#  '#workplaceviolence': ['#', 'workplace', 'violence'],
#  '#Fergusen': ['#', 'F', 'erg', 'u', 'sen'],
#  '#pureevil': ['#', 'pure', 'evil'],
#  '#AlSharpton': ['#', 'Al', 'Sharp', 'ton'],
#  '#Uganda': ['#', 'U', 'ganda'],
#  '#provocative': ['#', 'provocative'],
#  '#israeli': ['#', 'israeli'],
#  '#RT': ['#', 'R', 'T'],
#  '#pigsofafeatherflocktogether': ['#',
#   'pig',
#   'sofa',
#   'feather',
#   'flock',
#   'together'],
#  '###ards': ['#', '#', '#', 'ar', 'ds'],
#  '#FOUR': ['#', 'FOUR'],
#  '#JEDIS': ['#', 'J', 'E', 'DIS'],
#  '#media': ['#', 'media'],
#  '#GodBlessCanada': ['#', 'God', 'Bless', 'Canada'],
#  '#alive': ['#', 'alive'],
#  '#imams': ['#', 'imams'],
#  '#autodafe': ['#', 'a', 'u', 'toda', 'fe'],
#  '#GetReal': ['#', 'Get', 'Real'],
#  '#power': ['#', 'power'],
#  '#HandsOffMyGun': ['#', 'Hands', 'Off', 'My', 'Gun'],
#  '#OpFerguson': ['#', 'O', 'p', 'Ferguson'],
#  '#lies': ['#', 'lies'],
#  '#Really': ['#', 'Really'],
#  '#specialkindofstupid': ['#', 'special', 'kind', 'of', 'stupid'],
#  '#SWAT': ['#', 'SWAT'],
#  '#unionsquareevictiontheaterrainynightmemory': ['#',
#   'union',
#   'square',
#   'eviction',
#   'theater',
#   'rainy',
#   'night',
#   'memory'],
#  '#Palestine': ['#', 'Pale', 'stine'],
#  '#Justsaying': ['#', 'Just', 'saying'],
#  '#copaganda': ['#', 'copa', 'ganda'],
#  '#Islam': ['#', 'Islam'],
#  '#sydn': ['#', 'syd', 'n'],
#  '#stlouis': ['#', 'st', 'louis'],
#  '#cantread': ['#', 'can', 'tread'],
#  '#VetoDemocrático': ['#', 'V', 'e', 'toDe', 'mo', 'c', 'r', 'á', 'tic', 'o'],
#  '#rip': ['#', 'rip'],
#  '#cadet': ['#', 'cadet'],
#  '#respectforfamily': ['#', 'respect', 'for', 'family'],
#  '#illstandwithyou': ['#', 'ill', 'stand', 'with', 'you'],
#  ...}

# %% [markdown]
# **For your testing:**

# %%
assert(len(tokenized_hashtags) == len(hashtags))

# %% [markdown]
# ### Question 4 (1.0 mark)
#
# **Instructions**: Now that we have the tokenized hashtags, we need to go back and update the bag-of-words representation for each event.
#
# **Task**: Complete the ``update_event_bow(events)`` function. The function takes **a list of preprocessed events**, and for each event, it looks for every hashtag it has and updates the bag-of-words dictionary with the tokenized hashtag tokens. Note: you do not need to delete the counts of the original hashtags when updating the bag-of-words (e.g., if a document has "#speakup":2 in its bag-of-words representation, you do not need to delete this hashtag and its counts).

# %%
def update_event_bow(events):
    ###
    # Your answer BEGINS HERE
    ###
    for index, event in enumerate(events):
        for word in list(event):
            if word.startswith("#"):
                for token in tokenized_hashtags[word]:
                    event[token] += event[word] # update the list with new tokens
        events[index] = event
    ###
    # Your answer ENDS HERE
    ###
            
update_event_bow(preprocessed_rumour_events)
update_event_bow(preprocessed_nonrumour_events)

print("Number of preprocessed rumour events =", len(preprocessed_rumour_events))
print("Number of preprocessed non-rumour events =", len(preprocessed_nonrumour_events))
# Out:
# Number of preprocessed rumour events = 500
# Number of preprocessed non-rumour events = 1000

# %%
preprocessed_rumour_events
# Out:
# [Counter({'Michael': 2,
#           'Brown': 2,
#           '17': 4,
#           'yr': 2,
#           'old': 4,
#           'boy': 5,
#           'shot': 7,
#           '10x': 2,
#           '&': 4,
#           'killed': 2,
#           'police': 10,
#           '#Ferguson': 3,
#           'today': 2,
#           '.': 47,
#           'Media': 2,
#           'reports': 2,
#           '"': 22,
#           'shoot': 2,
#           'man': 3,
#           '#blackboysonly': 2,
#           '@AmeenaGK': 38,
#           '@jaythenerdkid': 3,
#           'And': 1,
#           'long': 1,
#           'conservative': 1,
#           'pundit': 1,
#           'finds': 1,
#           'pic': 1,
#           'messing': 1,
#           'around': 2,
#           'friends': 1,
#           'ID': 1,
#           '@d_m_elms': 2,
#           "they'll": 1,
#           'drag': 1,
#           'entire': 1,
#           'history': 1,
#           'every': 2,
#           'stolen': 1,
#           'sip': 1,
#           "dad's": 1,
#           'beer': 1,
#           ',': 17,
#           'second-hand': 1,
#           'tendril': 1,
#           'pot': 1,
#           'smoke': 1,
#           'watch': 1,
#           'traces': 1,
#           'back': 6,
#           'bogus': 1,
#           'allegations': 1,
#           'something': 1,
#           'kindergarten': 1,
#           'All': 2,
#           'justify': 1,
#           'dangerous': 1,
#           'CHILD': 1,
#           'KILLED': 1,
#           'TO': 1,
#           'PROTECT': 1,
#           'CANDY': 1,
#           'headline': 1,
#           '@CyMadD0x': 6,
#           'An': 1,
#           'unarmed': 1,
#           'black': 8,
#           'year': 2,
#           'cops': 2,
#           'instead': 1,
#           'fellow': 1,
#           'blacks': 1,
#           '...': 2,
#           'Better': 1,
#           'make': 2,
#           'national': 1,
#           'news': 1,
#           'You': 2,
#           'know': 2,
#           'right': 2,
#           '?': 15,
#           'Also': 1,
#           'libertarian': 1,
#           'siding': 1,
#           'pigs': 1,
#           '@PsychicDogTalk': 6,
#           'pointing': 1,
#           'double': 1,
#           'Standard': 1,
#           'violence': 3,
#           'barely': 1,
#           'reported': 2,
#           "I'm": 1,
#           'screaming': 1,
#           'racism': 2,
#           'The': 2,
#           'reason': 1,
#           'nobody': 1,
#           'gives': 1,
#           'shit': 1,
#           'poor': 1,
#           'people': 3,
#           'kill': 1,
#           "It's": 1,
#           'leftist': 1,
#           'conspiracy': 1,
#           'seem': 2,
#           'less': 1,
#           'violent': 1,
#           '#tinfoilin': 1,
#           '=p': 1,
#           'democrats': 1,
#           'run': 1,
#           'days': 2,
#           '#racism': 1,
#           'sexism': 1,
#           'communism': 1,
#           'I': 5,
#           'hope': 1,
#           'incident': 1,
#           'captured': 1,
#           'camera': 1,
#           '#Trayvon': 1,
#           'tru': 1,
#           'marginlized': 1,
#           'grps': 1,
#           'nyc': 1,
#           'try': 1,
#           'reporting': 1,
#           'gay': 1,
#           'domestic': 1,
#           'bed': 1,
#           'stuy': 1,
#           'meant': 1,
#           'MSM': 1,
#           'report': 2,
#           'NYPD': 1,
#           'point': 1,
#           'taken': 1,
#           '@justinstoned': 1,
#           'msm': 1,
#           "that's": 1,
#           'cable': 1,
#           '@RaavynnDigitaL': 2,
#           'quaint': 1,
#           'men': 3,
#           'boys': 1,
#           'saying': 1,
#           'would': 2,
#           'get': 1,
#           'trouble': 1,
#           "they're": 1,
#           'thugs': 1,
#           'fucking': 1,
#           'joke': 1,
#           '@retrocombine': 16,
#           'Was': 1,
#           'six': 1,
#           'feet': 1,
#           '200lbs': 1,
#           '@kevinwmiller': 12,
#           "i'm": 1,
#           'sure': 1,
#           'matters': 2,
#           "he's": 2,
#           'still': 2,
#           'underage': 1,
#           "He's": 1,
#           'young': 1,
#           '@TrueNameBrand': 1,
#           'must': 1,
#           'racist': 1,
#           'notice': 1,
#           '#WarOnWomen': 1,
#           'stopping': 1,
#           'us': 1,
#           'getting': 1,
#           'equal': 1,
#           'pay': 1,
#           'Does': 1,
#           'excuse': 1,
#           'ten': 1,
#           'times': 1,
#           'Ten': 1,
#           'To': 1,
#           'protect': 1,
#           'candy': 1,
#           'Boy': 1,
#           'Racist': 1,
#           '18': 1,
#           'assaulted': 1,
#           'officer': 2,
#           'Even': 1,
#           'case': 3,
#           'warrant': 1,
#           '8': 1,
#           'bullets': 2,
#           'agree': 2,
#           'consider': 1,
#           'excessive': 1,
#           'force': 1,
#           'Yeah': 1,
#           'Just': 1,
#           'sit': 1,
#           'wait': 1,
#           'facts': 1,
#           'See': 1,
#           'really': 1,
#           'happened': 4,
#           'may': 2,
#           'resolve': 1,
#           'one': 1,
#           "there's": 3,
#           'larger': 2,
#           'problem': 3,
#           'needs': 1,
#           'addressed': 1,
#           'According': 1,
#           'CBS': 1,
#           'http://t.co/Joj9cniAE4': 1,
#           'Two': 2,
#           'struggled': 1,
#           'pushes': 1,
#           'went': 2,
#           'sidearm': 1,
#           'Weapon': 1,
#           'fired': 3,
#           'inside': 2,
#           'car': 4,
#           'shots': 1,
#           'outside': 1,
#           'Where': 1,
#           'eight': 1,
#           "That's": 2,
#           'mother': 1,
#           'says': 1,
#           ';': 1,
#           'even': 1,
#           'chief': 1,
#           'said': 1,
#           'couple': 1,
#           'http://t.co/iUTZSW8ZgE': 1,
#           'understand': 1,
#           'jumping': 1,
#           'conclusions': 1,
#           'turning': 1,
#           'everything': 1,
#           'race': 4,
#           'war': 2,
#           'Of': 1,
#           'course': 1,
#           'upset': 1,
#           'son': 1,
#           'dead': 1,
#           'It': 2,
#           'matter': 1,
#           'fault': 1,
#           'regardless': 1,
#           'whether': 1,
#           "something's": 1,
#           'serious': 1,
#           'racial': 1,
#           'issues': 2,
#           'US': 1,
#           'bring': 1,
#           'major': 1,
#           'This': 1,
#           'racially': 1,
#           'motivated': 2,
#           'seemed': 1,
#           'like': 1,
#           'criminal': 1,
#           'trying': 1,
#           'take': 1,
#           'officers': 1,
#           'gun': 2,
#           'got': 2,
#           'If': 3,
#           'pushed': 2,
#           'cop': 2,
#           "I'd": 2,
#           'assume': 1,
#           'Me': 1,
#           'white': 1,
#           'reaction': 1,
#           'brought': 1,
#           'lot': 1,
#           'racially-motivated': 1,
#           'events': 1,
#           'light': 1,
#           'idea': 1,
#           'deal': 1,
#           'specific': 1,
#           'much': 1,
#           'What': 1,
#           'BEFORE': 1,
#           'story': 1,
#           'How': 1,
#           'else': 1,
#           '#': 9,
#           'Ferguson': 3,
#           'blackboy': 2,
#           'sonly': 2,
#           'tin': 1,
#           'fo': 1,
#           'i': 1,
#           'lin': 1,
#           'Tray': 1,
#           'v': 1,
#           'on': 1,
#           'Wa': 1,
#           'rOn': 1,
#           'Women': 1}),
#  Counter({'17': 3,
#           'year': 3,
#           'old': 3,
#           'unarmed': 3,
#           'kid': 3,
#           'shot': 3,
#           'ten': 4,
#           'times': 4,
#           'police': 5,
#           'stealing': 6,
#           'candy': 9,
#           '.': 28,
#           'I': 7,
#           'know': 4,
#           'punishable': 5,
#           'death': 5,
#           '(': 3,
#           'read': 3,
#           '#ferguson': 4,
#           'tag': 3,
#           ')': 3,
#           'No': 1,
#           'excuse': 2,
#           '“': 1,
#           '@inthefade': 18,
#           ':': 1,
#           '@AnneMarieFlynn2': 2,
#           '@adam_zander': 1,
#           'This': 3,
#           'unbelievable': 1,
#           ',': 8,
#           "there's": 1,
#           '@divineem': 1,
#           'It': 2,
#           'applies': 1,
#           'Black': 1,
#           'people': 1,
#           'story': 2,
#           'makes': 1,
#           'physically': 1,
#           'sick': 1,
#           '@marieann66': 1,
#           'http://t.co/PDo2pakAln': 1,
#           '@Alllwftopic': 1,
#           'Agreed': 1,
#           '!': 4,
#           'Should': 1,
#           'charged': 1,
#           'w': 1,
#           '/': 1,
#           'murder': 1,
#           '@Alasscan_': 3,
#           'apparently': 1,
#           '@JackieWillard2': 1,
#           'These': 1,
#           'days': 1,
#           'anything': 1,
#           'especially': 1,
#           'Stand': 1,
#           'Your': 1,
#           'Ground': 1,
#           'even': 2,
#           'sneeze': 1,
#           'true': 1,
#           "It's": 1,
#           'not-unless': 1,
#           'happen': 1,
#           'black': 3,
#           'male': 1,
#           'apparently.We': 1,
#           'make': 1,
#           'far': 1,
#           'accountable': 1,
#           "can't": 1,
#           'go': 1,
#           'We': 1,
#           'stole': 2,
#           'proof': 1,
#           'guess': 1,
#           'skittles': 1,
#           'become': 1,
#           'reason': 1,
#           'kill': 1,
#           'teens': 1,
#           '@pjhnsn8': 1,
#           'going': 1,
#           'early': 1,
#           'last': 1,
#           'night': 1,
#           "Wasn't": 1,
#           'real': 1,
#           'news': 1,
#           'point': 1,
#           'understand': 1,
#           'changed': 1,
#           'cigs': 1,
#           'tussle': 1,
#           'car': 1,
#           'saggy': 1,
#           'pants': 1,
#           'maybe': 1,
#           'never': 1,
#           'truthful': 1,
#           '#Shot': 1,
#           '?': 1,
#           'God': 1,
#           'mercy': 1,
#           '@Smilingl8dy': 1,
#           'say': 1,
#           '"': 2,
#           'allegedly': 1,
#           'Also': 1,
#           'stmt': 1,
#           'mention': 1,
#           'cause': 1,
#           'someone': 1,
#           'starts': 1,
#           'assaulting': 1,
#           'officer': 1,
#           'He': 2,
#           '18': 1,
#           'Nothing': 1,
#           'walking': 1,
#           'street': 1,
#           'Horrible': 1,
#           'situation': 1,
#           'But': 1,
#           'stop': 1,
#           'spreading': 1,
#           'false': 1,
#           'facts': 1,
#           '@klemosy': 1,
#           'Anything': 1,
#           'youth': 1,
#           '#': 5,
#           'ferguson': 4,
#           'Shot': 1}),
#  Counter({'White': 1,
#           'man': 1,
#           'aiming': 1,
#           'police': 1,
#           '...': 1,
#           'nothing': 1,
#           'happens': 1,
#           '.': 2,
#           'Unarmed': 1,
#           'black': 1,
#           'kid': 1,
#           'walking': 1,
#           'back': 1,
#           'store': 1,
#           'shot': 1,
#           '10': 1,
#           'times': 1,
#           '#Ferguson': 1,
#           'http://t.co/48EcUF2Bwa': 1,
#           '#': 1,
#           'Ferguson': 1}),
#  Counter({'Teenager': 2,
#           '#MikeBrown': 3,
#           'start': 3,
#           'college': 3,
#           'Monday': 3,
#           'shot': 4,
#           'ten': 4,
#           'times': 5,
#           '#Ferguson': 4,
#           'police': 7,
#           'officer': 3,
#           '.': 29,
#           'http://t.co/B4hWevO7l9': 2,
#           '@YourAnonGlobal': 22,
#           'What': 2,
#           'Mike': 5,
#           '?': 12,
#           '@ArmyBulldog20': 2,
#           'walking': 2,
#           'black': 3,
#           '@YourAnonNews': 10,
#           'Can': 1,
#           'give': 1,
#           'link': 2,
#           'I': 9,
#           'read': 3,
#           'please': 1,
#           '@TefPoe': 1,
#           'WTF': 1,
#           'Is': 1,
#           'real': 1,
#           '@sweden': 7,
#           'St': 1,
#           'Louis': 1,
#           'Post': 1,
#           'Dispatch': 1,
#           'story': 4,
#           ':': 2,
#           'http://t.co/I6hatQKNWI': 1,
#           'Apparently': 1,
#           'shoplifted': 1,
#           'candy': 1,
#           'bar': 1,
#           'Eyewitness': 1,
#           'report': 1,
#           'Post-Dispatch': 1,
#           'says': 1,
#           'Brown': 4,
#           'fled': 1,
#           'put': 1,
#           'car': 1,
#           '>': 1,
#           'Which': 1,
#           'probably': 1,
#           'good': 1,
#           'idea': 1,
#           ',': 6,
#           'way': 1,
#           'deserve': 1,
#           'getting': 1,
#           'killed': 1,
#           '@RedwoodGirl': 4,
#           'Oh': 1,
#           'god': 1,
#           'For': 1,
#           'shoplifting': 1,
#           'This': 1,
#           'awful': 2,
#           '!': 2,
#           'Thank': 1,
#           'Yes': 1,
#           'event': 1,
#           'Check': 1,
#           'hashtag': 1,
#           'lots': 1,
#           'anger': 1,
#           'sadness': 1,
#           "what's": 1,
#           'sad': 1,
#           'posting': 1,
#           'picture': 1,
#           'poor': 1,
#           'kid': 1,
#           'dead': 2,
#           'means': 1,
#           'nothing': 1,
#           'Thanks': 2,
#           'help': 2,
#           'Glad': 1,
#           'could': 1,
#           'Are': 1,
#           'really': 1,
#           'Sweden': 1,
#           'The': 1,
#           'US': 1,
#           'must': 1,
#           'seem': 1,
#           'barbaric': 1,
#           'Europeans': 1,
#           'stories': 1,
#           'like': 2,
#           ':(': 1,
#           'Well': 1,
#           'things': 2,
#           'bad': 2,
#           'But': 1,
#           'much': 2,
#           '@Renemies': 1,
#           'http://t.co/W1n9bYASlc': 1,
#           '@youranonglobal': 1,
#           '@youranonnews': 1,
#           'http://t.co/cFWVhcZMx1': 2,
#           '@armybulldog20': 2,
#           'Ten': 1,
#           'many': 1,
#           '“': 1,
#           'http://t.co/FABNrZ9iCQ': 1,
#           '”': 1,
#           '@2squig': 2,
#           'holy': 1,
#           'crap': 1,
#           '...': 1,
#           'teen': 1,
#           '"': 2,
#           'Black': 1,
#           'Like': 1,
#           'Me': 1,
#           'progressed': 1,
#           '@billthenewguy': 1,
#           'Racism': 1,
#           'dumb': 1,
#           'gets': 1,
#           "We're": 1,
#           'race': 1,
#           '(': 1,
#           'human': 1,
#           ')': 1,
#           '@7um9_': 2,
#           'Should': 1,
#           'thank': 1,
#           'worries': 1,
#           '@cannotthinkwhy': 1,
#           '10': 1,
#           'bloody': 1,
#           'shots': 1,
#           'someone': 1,
#           'Bionic': 1,
#           'man': 2,
#           'Or': 1,
#           'overkill': 1,
#           '@TonyMoule47': 1,
#           'Looks': 1,
#           'cops': 1,
#           'feel': 1,
#           'free': 1,
#           'shoot': 1,
#           'kill': 1,
#           'target': 1,
#           'doubt': 1,
#           "we'll": 1,
#           'see': 1,
#           'cop': 1,
#           'jailed': 1,
#           'Same': 1,
#           'age': 1,
#           'son': 1,
#           '@I_hate_it_here_': 1,
#           'everybody': 1,
#           'knows': 1,
#           "'": 2,
#           'serious': 1,
#           'crime': 1,
#           'racist': 1,
#           'Obvs': 1,
#           '&': 1,
#           'UK': 1,
#           'Home': 1,
#           'Office': 1,
#           'relaxed': 1,
#           'routinely': 1,
#           'arming': 1,
#           'definitely': 1,
#           'think': 1,
#           '@robert_veres': 1,
#           "Brown's": 1,
#           'family': 1,
#           'wish': 1,
#           'post': 1,
#           'pictures': 1,
#           'body': 1,
#           'thx': 1,
#           '@cosmiclandmine': 1,
#           'There': 1,
#           'may': 1,
#           'little': 1,
#           "I'll": 1,
#           'wait': 1,
#           'pass': 1,
#           'judgement': 1,
#           'It': 1,
#           'always': 1,
#           'person': 1,
#           'dies': 1,
#           '#': 7,
#           'Ferguson': 4}),
#  Counter({'Supposedly': 1,
#           'might': 1,
#           'one': 1,
#           'two': 1,
#           'witnesses': 1,
#           'shooting': 2,
#           'part': 1,
#           'recorded': 1,
#           'phones': 1,
#           '.': 1,
#           '#Ferguson': 1,
#           '#': 1,
#           'Ferguson': 1}),
#  Counter({'St': 1,
#           '.': 1,
#           'Louis': 1,
#           ':': 1,
#           'Unarmed': 1,
#           'teenager': 1,
#           '#MikeBrown': 1,
#           'shot': 1,
#           'ten': 1,
#           'times': 1,
#           '#Ferguson': 1,
#           'police': 1,
#           'officer': 1,
#           'accusation': 1,
#           'shoplifting': 1,
#           'http://t.co/cmaG8mnMiP': 1,
#           '#': 2,
#           'Mike': 1,
#           'Brown': 1,
#           'Ferguson': 1}),
#  Counter({'Witness': 3,
#           ':': 4,
#           'Police': 5,
#           'allegedly': 3,
#           'stopped': 3,
#           'Mike': 3,
#           'Brown': 3,
#           'yelling': 3,
#           'walk': 4,
#           'sidewalk': 3,
#           '.': 15,
#           '#Ferguson': 3,
#           'http://t.co/XG00R6w0k6': 2,
#           '@MichaelSkolnik': 21,
#           'cool': 1,
#           '!': 11,
#           'Darkskinned': 1,
#           'man': 1,
#           'crime': 1,
#           'element': 1,
#           'village': 2,
#           '?': 10,
#           'So': 1,
#           ',': 9,
#           '#obama': 1,
#           'alive': 1,
#           'yet': 1,
#           'Another': 1,
#           'win': 1,
#           'gene': 1,
#           'pool': 1,
#           '@Agent_Kindi': 6,
#           '@Supreme___Power': 6,
#           'These': 1,
#           'responses': 1,
#           'explain': 1,
#           'thiskeeps': 1,
#           'happening': 1,
#           'Too': 1,
#           'many': 3,
#           'white': 3,
#           'men': 2,
#           'hate': 1,
#           'black': 2,
#           'Sad': 1,
#           '@TimmyTurnUp': 5,
#           'fuck': 1,
#           'Is': 4,
#           'anyone': 1,
#           'streets': 1,
#           'knife': 1,
#           'gun': 1,
#           'U': 2,
#           'want': 1,
#           'say': 1,
#           '"': 2,
#           'guilty': 1,
#           'In': 3,
#           'Moscow': 1,
#           'guys': 2,
#           'sold': 1,
#           'drugs': 1,
#           '...': 1,
#           '@AC_BOwen': 6,
#           '#Cleveland': 6,
#           'Any': 1,
#           'Excuse': 1,
#           'Will': 1,
#           'Do': 1,
#           'A': 4,
#           'Chase': 1,
#           '11-29-': 2,
#           '12': 4,
#           '~': 10,
#           '#2UnarmedBLACKS': 1,
#           '#MURDERED': 3,
#           'By': 1,
#           '#13RACISTCOPS': 1,
#           '#137GUNSHOTS': 1,
#           '@CivilRights': 2,
#           '#MalissaWilliamsAndTimothyRussell': 2,
#           'Were': 1,
#           'Shot': 2,
#           'Up': 2,
#           '#UNARMED': 1,
#           'Of': 2,
#           '#13RacistCops': 2,
#           '#NotCHARGED': 2,
#           '#GOOGLE': 1,
#           'Shoot': 1,
#           '137': 1,
#           'Times': 1,
#           '<': 10,
#           '#MURDERING': 1,
#           '#2UNARMEDBLACKS': 2,
#           'They': 1,
#           'Have': 1,
#           'Many': 1,
#           '#UNARMEDBLACKS': 2,
#           'The': 5,
#           'Case': 1,
#           'Was': 2,
#           'Being': 1,
#           'Covered': 1,
#           'Mayor': 1,
#           'On': 1,
#           'Cops': 3,
#           'Sides': 1,
#           'Got': 1,
#           'No': 1,
#           '#Justice': 1,
#           '#BlackLifeMatters': 1,
#           'Cop': 2,
#           '19yr': 1,
#           'Old': 1,
#           'Head': 1,
#           '#Black': 1,
#           '#Unarmed': 1,
#           '#MomsOnlyChild': 1,
#           'Said': 1,
#           'He': 3,
#           '#THOUGHT': 1,
#           'Saw': 1,
#           'Gun': 1,
#           '@SecretService': 2,
#           'I': 1,
#           "Don't": 1,
#           'Like': 3,
#           'His': 1,
#           'Tweet': 1,
#           'Asking': 1,
#           'Why': 2,
#           '#Obama': 3,
#           'Alive': 2,
#           'Yet': 1,
#           '#WePray': 1,
#           '#SecretService': 2,
#           'Protects': 1,
#           '#PresidentObama': 1,
#           "Get's": 1,
#           'Threats': 1,
#           'All': 1,
#           'Time': 1,
#           'It': 1,
#           'People': 1,
#           'You': 3,
#           'That': 1,
#           '#MURDER': 1,
#           'Ask': 1,
#           'Still': 1,
#           '#RACIST': 1,
#           '#KKK': 1,
#           '#SMH': 1,
#           '@Progress4Ohio': 2,
#           "I'm": 2,
#           'glad': 1,
#           'amigo': 1,
#           'love': 1,
#           'president': 1,
#           'kills': 1,
#           'children': 1,
#           'Ukrain': 1,
#           'Gaza': 1,
#           'places': 1,
#           ';-)': 2,
#           'RACIST': 3,
#           'We': 2,
#           'live': 1,
#           'together': 1,
#           '200': 1,
#           'nations': 1,
#           'Russia': 1,
#           'And': 1,
#           'go': 1,
#           'words': 1,
#           'mucacho': 1,
#           '“': 1,
#           'http://t.co/TYdMSNxGlo': 1,
#           '”': 1,
#           'edgy': 1,
#           'If': 1,
#           'u': 1,
#           'think': 1,
#           'something': 1,
#           'another': 1,
#           'says': 1,
#           'somehow': 1,
#           'hold': 1,
#           'back': 1,
#           'loser': 1,
#           '&': 1,
#           'deserve': 1,
#           'failure': 1,
#           'White': 2,
#           'jealous': 1,
#           '@ValMackinnon': 1,
#           'perfect': 1,
#           ')': 2,
#           'Daniel': 1,
#           'Craig': 1,
#           'throw': 1,
#           'GF': 1,
#           'window': 1,
#           'girls': 1,
#           'smart': 1,
#           '#': 46,
#           'Ferguson': 3,
#           'o': 1,
#           'b': 5,
#           'ama': 5,
#           'C': 6,
#           'lev': 6,
#           'eland': 6,
#           '2': 3,
#           'Unarmed': 2,
#           'BLACKS': 5,
#           'MURDERED': 3,
#           '1': 4,
#           '3': 4,
#           'COPS': 1,
#           '7': 1,
#           'GUNSHOTS': 1,
#           'Malis': 2,
#           'sa': 2,
#           'William': 2,
#           'sAnd': 2,
#           'Timothy': 2,
#           'Russell': 2,
#           'UNARMED': 5,
#           'Racist': 2,
#           'Not': 2,
#           'CHARGED': 2,
#           'GO': 1,
#           'OGLE': 1,
#           'MURDERING': 1,
#           'Justice': 1,
#           'Black': 2,
#           'Life': 1,
#           'Matters': 1,
#           'M': 2,
#           'om': 1,
#           'sOnly': 1,
#           'Child': 1,
#           'THOUGHT': 1,
#           'O': 3,
#           'Pray': 1,
#           'Secret': 2,
#           'Service': 2,
#           'P': 1,
#           're': 1,
#           'si': 1,
#           'den': 1,
#           'tO': 1,
#           'MURDER': 1,
#           'K': 3,
#           'S': 1,
#           'H': 1}),
#  Counter({'.': 34,
#           '@NBCNews': 19,
#           'I': 6,
#           'demand': 2,
#           'retract': 2,
#           'lie': 2,
#           '#Ferguson': 2,
#           'people': 2,
#           'shouting': 2,
#           '"': 14,
#           'Kill': 2,
#           'police': 2,
#           'Reporters': 2,
#           'scene': 3,
#           'refuted': 2,
#           '@QuadCityPat': 23,
#           'Yes': 1,
#           ',': 10,
#           'tell': 1,
#           '@AP': 4,
#           '&': 1,
#           '@blackvoices': 4,
#           '!': 12,
#           'It': 2,
#           'divisive': 1,
#           'propaganda': 1,
#           'Oh': 1,
#           'ISH': 1,
#           'So': 1,
#           '@NBC': 1,
#           'lied': 1,
#           '?': 7,
#           'The': 1,
#           'media': 1,
#           'must': 1,
#           'narrative': 1,
#           'Unarmed': 1,
#           'blk': 1,
#           'boy': 1,
#           'shot': 1,
#           '10': 1,
#           'times': 1,
#           'cut': 1,
#           '4': 2,
#           '@KMBTweets': 3,
#           'AP': 1,
#           'conservative': 1,
#           'bias': 1,
#           '#liberalmediamyfoot': 1,
#           'link': 1,
#           'local': 2,
#           'reporters': 2,
#           'refuting': 1,
#           "I'm": 1,
#           'working': 1,
#           'piece': 1,
#           'would': 1,
#           'like': 1,
#           'include': 1,
#           'Thanks': 1,
#           '@kileykroh': 5,
#           'links': 1,
#           'specific': 1,
#           'looking': 1,
#           'video': 1,
#           'protests.They': 1,
#           'saying': 1,
#           'No': 3,
#           'Justice': 1,
#           'Peace': 1,
#           'And': 1,
#           'Stop': 1,
#           'Killing': 1,
#           'Us': 1,
#           'yeah': 1,
#           'hoping': 1,
#           'find': 1,
#           'something': 1,
#           'someone': 1,
#           'ground': 1,
#           'retweeted': 1,
#           'vine': 1,
#           'shows': 1,
#           'chanting': 1,
#           'Hey': 1,
#           'hey': 1,
#           'ho': 2,
#           'killer': 2,
#           'cops': 3,
#           'got': 1,
#           'go': 1,
#           'thank': 1,
#           'tweet': 1,
#           'God': 1,
#           'bless': 1,
#           'seems': 1,
#           'small': 1,
#           'step': 1,
#           'mishearing': 1,
#           'kill': 1,
#           'For': 1,
#           'worth': 1,
#           '@_MylesHigh': 1,
#           'anything': 1,
#           'promote': 1,
#           'fear': 1,
#           'huh': 1,
#           '#Sad': 1,
#           '“': 1,
#           'Get': 1,
#           'Out': 1,
#           'Town': 1,
#           'Cracker': 1,
#           '”': 1,
#           'sprayed': 1,
#           'white': 1,
#           'man': 1,
#           '’': 1,
#           'burnt-down': 1,
#           'house': 1,
#           'March': 1,
#           '28': 1,
#           '2014': 2,
#           'CRIME': 2,
#           '/': 3,
#           'IS': 2,
#           '..': 3,
#           'REGARDLESS': 1,
#           '@Donna_West': 1,
#           ':': 2,
#           "That's": 1,
#           'LYING': 1,
#           'ASS': 1,
#           'MEDIA': 1,
#           'ya': 1,
#           'Blacks': 1,
#           'beat': 1,
#           'Matthew': 1,
#           'Boorujuy': 1,
#           'death': 2,
#           'calling': 1,
#           'cracker': 1,
#           'May': 1,
#           'NO': 1,
#           'KILLING': 1,
#           'RIGHT': 1,
#           'W': 1,
#           'BLACK.BLK/WHITE': 1,
#           '@Conservativrulz': 6,
#           'fuck': 2,
#           'outta': 1,
#           'troll': 1,
#           '#scram': 1,
#           'Parity': 1,
#           'HOW': 1,
#           'THE': 2,
#           'FUCK': 1,
#           'DOES': 1,
#           'IT': 2,
#           'WORK': 1,
#           '#moron': 1,
#           'Heh': 1,
#           'She': 1,
#           'shares': 1,
#           'name': 1,
#           'birth': 1,
#           'control': 1,
#           'pill': 1,
#           'AH': 1,
#           'SHARPTON': 1,
#           'field': 1,
#           'day': 1,
#           "He's": 1,
#           'biggest': 1,
#           'racists': 1,
#           'planet': 2,
#           '...': 1,
#           '@SharonMelendes': 1,
#           'ignorance': 1,
#           '>': 4,
#           'JUST': 1,
#           'CONSERVATIVES': 1,
#           'KILL': 1,
#           'PEOPLE': 1,
#           'GEEESH': 1,
#           'YEP': 1,
#           'BUSH': 1,
#           'DID': 1,
#           '@3ChicsPolitico': 1,
#           '@nbc': 1,
#           'George': 1,
#           'Bush': 1,
#           'Of': 1,
#           'course': 1,
#           'LORD': 1,
#           'IGNORANCE': 1,
#           'Ok': 1,
#           'idiot': 2,
#           'compare': 1,
#           'vandalism': 2,
#           'shooting': 1,
#           'gets': 1,
#           'vote': 1,
#           "You're": 1,
#           'comparing': 1,
#           'murder': 1,
#           'Eff': 1,
#           'life': 1,
#           'Media': 1,
#           'always': 1,
#           'falsely': 1,
#           'reported': 1,
#           'racial': 1,
#           'issues': 1,
#           'keep': 1,
#           'races': 1,
#           'America': 1,
#           'divided': 1,
#           'Division': 1,
#           'wks': 1,
#           '1': 1,
#           '%': 1,
#           '@adbridgeforth': 1,
#           'Exactly': 1,
#           'justice': 1,
#           'peace': 1,
#           '@daiconrad': 1,
#           'thanks': 1,
#           'included': 1,
#           'http://t.co/hUi26I5oZZ': 1,
#           '#': 6,
#           'Ferguson': 2,
#           'liber': 1,
#           'alme': 1,
#           'di': 1,
#           'amy': 1,
#           'foot': 1,
#           'Sad': 1,
#           'scram': 1,
#           'moron': 1}),
#  Counter({'So': 2,
#           'last': 2,
#           'week': 2,
#           'NYPD': 2,
#           'tried': 2,
#           'tell': 2,
#           'us': 5,
#           '#EricGarner': 2,
#           'chokehold': 2,
#           ',': 3,
#           '#Ferguson': 2,
#           'police': 2,
#           'telling': 3,
#           '#MikeBrown': 3,
#           'assaulted': 2,
#           'officer': 2,
#           '@SoulRevision': 2,
#           'Even': 1,
#           'true': 1,
#           '(': 1,
#           'almost': 1,
#           'definitely': 1,
#           ')': 1,
#           "that's": 1,
#           'excuse': 1,
#           'execute': 1,
#           'street': 1,
#           '.': 1,
#           '@zellieimani': 1,
#           'They': 1,
#           'lies': 1,
#           'Sunday': 1,
#           '#': 7,
#           'Eric': 2,
#           'Garner': 2,
#           'Ferguson': 2,
#           'Mike': 3,
#           'Brown': 3}),
#  Counter({'So': 3,
#           '#Ferguson': 2,
#           'Police': 2,
#           'afford': 7,
#           'machine': 3,
#           'guns': 3,
#           "can't": 3,
#           'dash': 2,
#           'cameras': 3,
#           'squad': 2,
#           'cars': 3,
#           '?': 5,
#           '#interesting': 2,
#           '#MikeBrown': 3,
#           '@unpreachedtruth': 14,
#           '@TheAnonMessage': 8,
#           "they're": 1,
#           'still': 2,
#           'boxes': 2,
#           'chief': 1,
#           'police': 1,
#           'said': 1,
#           'last': 1,
#           'night': 1,
#           'got': 1,
#           '.': 17,
#           "that's": 1,
#           'important': 1,
#           'ready': 1,
#           'slaughter': 1,
#           'people': 1,
#           'think': 1,
#           'rights': 1,
#           'That': 1,
#           'proves': 1,
#           'never': 2,
#           'thought': 1,
#           'purchased': 1,
#           'installed': 3,
#           '@norwind': 2,
#           'huh': 1,
#           '@BallerinaX': 1,
#           '1033': 1,
#           'program': 1,
#           ',': 6,
#           'rifles': 1,
#           'probably': 1,
#           'cost': 1,
#           'less': 1,
#           'body': 1,
#           'cams': 1,
#           '@Wanderer19': 3,
#           'Protecting': 1,
#           'serving': 2,
#           'right': 1,
#           '@vdogg9': 1,
#           'open': 2,
#           '@runsammrun': 2,
#           'smh': 1,
#           'install': 1,
#           'sure': 1,
#           'I': 2,
#           'read': 2,
#           'matter': 1,
#           'laziness': 1,
#           '/': 4,
#           'disorganization': 1,
#           'carelessness': 1,
#           '@DaleGunn3': 1,
#           'They': 3,
#           'protecting': 1,
#           'Clearly': 1,
#           '#smh': 1,
#           "That's": 1,
#           'crazy': 1,
#           'seem': 1,
#           'disorganized': 1,
#           'came': 1,
#           'preparing': 1,
#           'riots': 1,
#           'ha': 1,
#           'stakes': 1,
#           'higher': 1,
#           '@rockermom53': 2,
#           '|': 2,
#           'video': 2,
#           'patrol': 1,
#           'make': 1,
#           '&': 3,
#           'audio': 1,
#           'recording': 1,
#           'contact': 1,
#           'public': 1,
#           'suspect': 1,
#           'But': 1,
#           'LOT': 1,
#           'fire': 1,
#           'power': 1,
#           'small': 1,
#           'city': 1,
#           'Agree': 1,
#           'plenty': 1,
#           'war-hardware': 1,
#           'need': 1,
#           'focus': 1,
#           'ppl': 1,
#           'skills': 1,
#           'train': 1,
#           'serve': 1,
#           'protect': 1,
#           'Like': 1,
#           'pro-gunners': 1,
#           'find': 1,
#           '$': 1,
#           'AR': 1,
#           '-': 1,
#           '15s': 1,
#           'claim': 1,
#           'mandatory': 1,
#           'gun': 1,
#           'insurance': 1,
#           'would': 1,
#           'financial': 1,
#           'hardship': 1,
#           '@deBeauxOs1': 1,
#           'well': 1,
#           'least': 1,
#           'bothered': 1,
#           'take': 1,
#           'box': 1,
#           '#': 8,
#           'Ferguson': 2,
#           'interesting': 2,
#           'Mike': 3,
#           'Brown': 3,
#           's': 1,
#           'm': 1,
#           'h': 1}),
#  Counter({'Line': 1,
#           'police': 1,
#           'cars': 1,
#           'high': 1,
#           'beams': 1,
#           'greets': 1,
#           'anyone': 1,
#           'trying': 1,
#           'enter': 1,
#           '#Ferguson': 2,
#           '.': 14,
#           "It's": 1,
#           'shut': 1,
#           'No': 1,
#           'media': 1,
#           'allowed': 1,
#           'http://t.co/bk6jFFM7jj': 1,
#           '@AnonymousPress': 14,
#           "that's": 1,
#           'last': 2,
#           'night': 2,
#           'Not': 1,
#           'tonight': 1,
#           'Yeah': 1,
#           'Land': 1,
#           'Free': 1,
#           'My': 1,
#           'A': 1,
#           '%': 1,
#           '&': 1,
#           'Why': 1,
#           'I': 1,
#           'reminded': 1,
#           'Tienanmen': 1,
#           'Square': 1,
#           'These': 1,
#           'pigs': 1,
#           'need': 1,
#           'taken': 1,
#           '!': 3,
#           '@CFormigoni5': 1,
#           'Chef': 1,
#           'board': 1,
#           'photo': 1,
#           '?': 6,
#           'Please': 1,
#           'clarify': 1,
#           'using': 1,
#           'present': 1,
#           'tense': 1,
#           'cop': 1,
#           'shoots': 1,
#           'unarmed': 1,
#           'black': 1,
#           'man': 2,
#           ',': 3,
#           'citizens': 1,
#           'start': 1,
#           'looting': 1,
#           'burning': 1,
#           'community.is': 1,
#           'make': 1,
#           'sense': 1,
#           'Freedom': 1,
#           'press': 1,
#           'ass': 1,
#           'Is': 1,
#           'Ferguson': 3,
#           'joining': 1,
#           'Russia': 1,
#           'China': 1,
#           'communist': 1,
#           'style': 1,
#           'governance': 1,
#           'The': 1,
#           'cops': 1,
#           'calling': 1,
#           'protesters': 1,
#           'animals': 1,
#           'And': 2,
#           'FAA': 1,
#           'declared': 1,
#           'no-fly': 1,
#           'zone': 1,
#           'guys': 1,
#           'boneheads': 1,
#           '~': 1,
#           '>': 1,
#           'Gaza': 1,
#           'Iraq': 1,
#           'Soon': 1,
#           'burst': 1,
#           'homes': 1,
#           'rape': 1,
#           'babies': 1,
#           'force': 1,
#           'mothers': 1,
#           'watch': 1,
#           'tyranny': 1,
#           '...': 1,
#           'Beuller': 1,
#           'fuck': 1,
#           '#': 2}),
#  Counter({'Before': 9,
#           'death': 9,
#           '#MikeBrown': 9,
#           'told': 10,
#           'mother': 10,
#           ',': 10,
#           '"': 22,
#           'The': 9,
#           'world': 9,
#           'know': 10,
#           '#MichaelBrown': 9,
#           '!': 10,
#           '#Ferguson': 9,
#           '@BridjesONeil': 16,
#           '@AntonioFrench': 3,
#           'naaaaaaawwwww': 1,
#           'real': 2,
#           '?': 4,
#           '😞': 2,
#           '“': 6,
#           ':': 7,
#           '”': 6,
#           'Sounds': 1,
#           'like': 2,
#           'something': 1,
#           'someone': 1,
#           'kamikaze': 1,
#           'mission': 1,
#           'would': 1,
#           'say': 1,
#           '.': 11,
#           'sounds': 2,
#           'bullshit': 1,
#           '...': 2,
#           'sigh': 1,
#           '@xbreakingeven': 1,
#           'It': 2,
#           'little': 1,
#           'made': 1,
#           ':(': 1,
#           '@GingePurps': 1,
#           'His': 1,
#           'spoken': 1,
#           'tonight': 1,
#           'Another': 1,
#           'speaker': 1,
#           'shared': 1,
#           'information': 1,
#           "must've": 1,
#           'Seriously': 1,
#           'I': 3,
#           'doubt': 1,
#           'Maybe': 1,
#           'likely': 1,
#           'love': 2,
#           'ya': 1,
#           'momma': 1,
#           '@saramarietweets': 1,
#           'regardless': 1,
#           'We': 2,
#           'always': 1,
#           'known': 1,
#           'child': 1,
#           'another': 1,
#           'morn': 1,
#           '@Donna_West': 2,
#           'gonna': 1,
#           'call': 1,
#           'big': 1,
#           'probably': 1,
#           'one': 1,
#           'meaning': 1,
#           "can't": 1,
#           'imagine': 1,
#           'anyone': 1,
#           'outside': 1,
#           'movie': 1,
#           'saying': 1,
#           'thing': 1,
#           'Speechless': 1,
#           'RT': 1,
#           '@nellbernstein': 1,
#           'heart': 1,
#           'wrenching': 1,
#           'Holy': 1,
#           'Moly': 1,
#           'amazing': 1,
#           'قال': 1,
#           'زو': 1,
#           'الثمانية': 1,
#           'عشر': 1,
#           'لوالدته': 1,
#           'قبل': 1,
#           'مقتله': 1,
#           'بيد': 1,
#           'الشرطي': 1,
#           'الامريكي': 1,
#           'سيعلم': 1,
#           'العالم': 1,
#           'من': 1,
#           'هو': 1,
#           'ً': 1,
#           'ميكي': 1,
#           'براون': 1,
#           '#': 27,
#           'Mike': 9,
#           'Brown': 18,
#           'Michael': 9,
#           'Ferguson': 9}),
#  Counter({'Currently': 3,
#           '#FoxNews': 4,
#           'website': 4,
#           'zero': 3,
#           ',': 19,
#           'repeat': 2,
#           'ZERO': 2,
#           'coverage': 4,
#           '#Ferguson': 3,
#           'protests': 2,
#           'probably': 2,
#           'due': 2,
#           'lack': 3,
#           'cowboy': 2,
#           'hats': 2,
#           '.': 27,
#           '@clydetheslyde': 39,
#           'Shocking': 1,
#           '...': 4,
#           'Earlier': 1,
#           'segment': 1,
#           'TV': 1,
#           'asking': 1,
#           'black': 4,
#           'America': 1,
#           'would': 3,
#           'anything': 1,
#           'stop': 1,
#           'looting': 1,
#           'Ferguson': 5,
#           'They': 2,
#           'obsessed': 1,
#           'Michelle': 2,
#           'Obama': 2,
#           "'": 3,
#           'derrière': 1,
#           '#perverts': 1,
#           'get': 1,
#           '"': 4,
#           'tread': 1,
#           'flags': 1,
#           'fox': 2,
#           'go': 1,
#           'Too': 1,
#           'busy': 1,
#           'bitching': 1,
#           'POTUS': 1,
#           'sure': 1,
#           '“': 1,
#           ':': 4,
#           '/': 2,
#           'three': 1,
#           'wise': 1,
#           'monkeys': 1,
#           'commented': 1,
#           'see': 1,
#           'evil': 3,
#           'hear': 1,
#           'speak': 1,
#           'Na': 1,
#           'many': 3,
#           'people': 3,
#           'care': 2,
#           'There': 1,
#           'plenty': 1,
#           'world': 1,
#           'cover': 2,
#           'instead': 1,
#           'focusing': 1,
#           'one': 2,
#           "woman's": 1,
#           'ass': 1,
#           'assholes': 1,
#           'FOXNEWS': 1,
#           'major': 1,
#           'reason': 1,
#           'stupid': 1,
#           'cops': 1,
#           'give': 1,
#           'damn': 1,
#           'life': 1,
#           'young': 2,
#           'kids': 1,
#           'Thanks': 1,
#           '4': 1,
#           'going': 1,
#           'us': 1,
#           'wonder': 1,
#           '✌': 1,
#           '️': 1,
#           'No': 1,
#           'surprises': 1,
#           'really': 4,
#           'articles': 1,
#           'ran': 1,
#           'car': 1,
#           'fast': 1,
#           '@michael_flinch': 7,
#           'fact': 1,
#           'dig': 1,
#           'find': 1,
#           'problem': 1,
#           'headline': 1,
#           'news': 3,
#           'http://t.co/0LKOR9MyqV': 1,
#           '#Bengazie': 1,
#           "It's": 2,
#           'gots': 1,
#           'loose': 1,
#           'weight': 1,
#           'butt': 1,
#           '#gross': 1,
#           '@smeezi': 6,
#           'turn': 1,
#           'Fox': 6,
#           'News': 5,
#           'yeh': 1,
#           'dont': 1,
#           'want': 2,
#           'watch': 1,
#           'shitty': 1,
#           'programming': 1,
#           'believe': 1,
#           'headlining': 1,
#           'even': 1,
#           'homepage': 1,
#           'foxnews': 2,
#           'tho': 1,
#           'actually': 1,
#           'interesting': 1,
#           'say': 1,
#           '?': 5,
#           'conservative': 1,
#           'taking': 1,
#           'different': 2,
#           'pov': 1,
#           'I': 4,
#           'talking': 1,
#           'Plus': 1,
#           'dude': 1,
#           'joke': 1,
#           'Get': 1,
#           '!': 7,
#           'http://t.co/shgRwLx9Ww': 1,
#           'yikes': 1,
#           'Their': 1,
#           'cameras': 1,
#           "can't": 1,
#           'focus': 1,
#           'brown': 2,
#           'Yikes': 1,
#           'indeed': 1,
#           '@GrooveSDC': 1,
#           'hillbilly': 1,
#           'viewers': 1,
#           'start': 1,
#           'thinking': 1,
#           'race': 2,
#           'war': 1,
#           'finally': 1,
#           'started': 1,
#           'yet': 2,
#           '#FOXNEWS': 1,
#           '@mchenthompson': 1,
#           "Isn't": 1,
#           'truth': 1,
#           'property': 2,
#           'damage': 1,
#           'On': 1,
#           '>': 1,
#           'missing': 1,
#           'pretty': 1,
#           'blonde': 1,
#           'white': 4,
#           'girl': 1,
#           'right': 2,
#           'remain': 1,
#           'silent': 1,
#           'ended': 1,
#           'http://t.co/SErbzckzdX': 1,
#           'My': 1,
#           'column': 1,
#           'AN': 1,
#           'EXECUTION': 1,
#           'IN': 2,
#           'FERGUSON': 1,
#           'http://t.co/bh8fgwu3gZ': 1,
#           '#ferguson': 1,
#           '#michaelbrown': 1,
#           '#policebrutality': 1,
#           '@SacJim2012': 4,
#           'release': 1,
#           'name': 1,
#           'cop': 1,
#           'shooting': 2,
#           '&': 3,
#           'spoke': 1,
#           'witnesses': 1,
#           '..': 11,
#           '#BuyingTime': 1,
#           'already': 1,
#           "f'd": 1,
#           '#different': 1,
#           'accounts': 1,
#           'happened': 1,
#           '#dirtyTruth': 1,
#           'come': 1,
#           'light': 1,
#           '@my2bits4u': 2,
#           '@DMeralles': 1,
#           'http://t.co/u8QxZ0Dv60': 1,
#           '@graceslick77': 3,
#           'Buying': 1,
#           'Time': 2,
#           'Protect': 1,
#           'Racist': 2,
#           'Murdering': 1,
#           'Cop': 1,
#           '#Sick': 2,
#           '#Coward': 1,
#           'know': 2,
#           "that's": 1,
#           'hoping': 1,
#           'god': 1,
#           '#Someone': 1,
#           'captured': 1,
#           'phone': 1,
#           '+': 2,
#           'came': 1,
#           'forward': 1,
#           '-': 1,
#           '(': 1,
#           'video': 1,
#           ')': 1,
#           'If': 1,
#           'Jail': 1,
#           'Rogue': 1,
#           'Cops': 1,
#           'Stop': 1,
#           'Killing': 1,
#           'Unarmed': 1,
#           'Black': 1,
#           'Men': 1,
#           'raised': 1,
#           'hater': 1,
#           ';': 1,
#           'knew': 1,
#           'wrong-always.But': 1,
#           'baffles': 1,
#           'w': 1,
#           '#Diversity': 1,
#           'creation': 1,
#           'ppl': 1,
#           'hate': 1,
#           'rt': 1,
#           '#HatersHate': 1,
#           '#LiarsLie': 1,
#           'tragic': 1,
#           '@mylifeishid': 4,
#           '#MikeBrown': 1,
#           'need': 2,
#           'shot': 1,
#           '#Benghazi': 1,
#           '#foxnews': 1,
#           '@mechphree': 3,
#           'Nicely': 1,
#           'played': 1,
#           'sir': 1,
#           'FOX': 2,
#           'HAS': 1,
#           'BECOME': 1,
#           'A': 1,
#           'REPUBLICAN': 1,
#           'POLITICIANS': 1,
#           'INFOMERCIAL': 1,
#           "ISN'T": 1,
#           'REALLY': 1,
#           'INTERESTED': 1,
#           'REAL': 1,
#           'NEWS': 2,
#           'BOYCOTT': 1,
#           '@moiskd': 1,
#           'Imagine': 1,
#           'folks': 1,
#           'strutting': 1,
#           'around': 1,
#           "AR's": 1,
#           'Think': 1,
#           'Perry': 1,
#           'Hannity': 1,
#           'hunkered': 1,
#           'solidarity': 1,
#           'Your': 1,
#           'tweet': 1,
#           'makes': 1,
#           'page': 1,
#           'stronger': 1,
#           'http://t.co/QNABzh699U': 1,
#           '@Madaza41': 2,
#           'remember': 1,
#           'type': 1,
#           'invaded': 1,
#           'Iraq': 1,
#           'Boots': 2,
#           'ground': 2,
#           'Cont': 1,
#           'Who': 1,
#           'cares': 1,
#           'We': 1,
#           'Brittney': 1,
#           'Spears': 1,
#           'blobs': 1,
#           'Or': 2,
#           'old': 2,
#           'rich': 1,
#           'Senator': 1,
#           'Good': 1,
#           'exactly': 1,
#           'expected': 1,
#           'liar': 1,
#           'http://t.co/CZk1kFS41Q': 1,
#           '#': 27,
#           'perverts': 1,
#           'Ben': 2,
#           'gaz': 1,
#           'ie': 1,
#           'gross': 1,
#           'ferguson': 1,
#           'michael': 1,
#           'police': 1,
#           'brutality': 1,
#           'Buy': 1,
#           'ing': 1,
#           'dirty': 1,
#           'Truth': 1,
#           'Sick': 2,
#           'Coward': 1,
#           'Someone': 1,
#           'Diversity': 1,
#           'Haters': 1,
#           'Hate': 1,
#           'Liars': 1,
#           'Lie': 1,
#           'Mike': 1,
#           'Brown': 1,
#           'ghazi': 1}),
#  Counter({'The': 7,
#           'ferguson': 5,
#           'chief': 4,
#           'says': 3,
#           'feelings': 6,
#           'hurt': 4,
#           'ppl': 6,
#           'consider': 3,
#           'part': 4,
#           'problem': 5,
#           '.': 69,
#           '#ferguson': 2,
#           'http://t.co/VoJGrMOPbZ': 2,
#           '@WyzeChef': 59,
#           'What': 1,
#           'SMOKING': 1,
#           '?': 6,
#           'He': 2,
#           'cannot': 1,
#           'stupid': 1,
#           '“': 3,
#           ':': 1,
#           'http://t.co/HUlpIqjoFL': 1,
#           '”': 2,
#           '-': 2,
#           'lol': 1,
#           '@radicalhearts': 1,
#           'wow': 1,
#           '...': 5,
#           'Making': 1,
#           'feel': 2,
#           'feels': 1,
#           'teen': 1,
#           'murdered': 1,
#           '!': 5,
#           '@AdmireLaniya__': 41,
#           'White': 1,
#           'people': 14,
#           'love': 2,
#           'victim': 3,
#           'card': 2,
#           "They've": 1,
#           'making': 2,
#           'whole': 2,
#           'situation': 2,
#           'focusing': 1,
#           'looting': 3,
#           '@TheBlackVoice': 1,
#           'serious': 1,
#           'They': 3,
#           'oblivious': 1,
#           'damn': 1,
#           'near': 1,
#           'hilarious': 1,
#           '@OberstabKrieger': 2,
#           'I': 23,
#           'think': 2,
#           'effective': 1,
#           'But': 4,
#           "I'm": 2,
#           'going': 2,
#           'judge': 3,
#           'live': 1,
#           'If': 5,
#           'happened': 1,
#           'neighborhood': 1,
#           "can't": 2,
#           'promise': 2,
#           'want': 1,
#           'tear': 1,
#           'something': 1,
#           '@xianb8': 1,
#           'story': 1,
#           'kid': 3,
#           'attacking': 1,
#           'cop': 2,
#           'reason': 1,
#           'way': 1,
#           "grandmother's": 1,
#           'house': 1,
#           'makes': 1,
#           'much': 1,
#           'sense': 1,
#           'Red': 1,
#           'Riding': 1,
#           'Hood': 1,
#           'black': 2,
#           ',': 9,
#           'media': 2,
#           '/': 2,
#           'cops': 2,
#           "would've": 1,
#           'put': 1,
#           'wolf': 2,
#           'paid': 1,
#           'vacation': 1,
#           '&': 1,
#           'talked': 1,
#           'tearz': 1,
#           '@tklowenstein': 1,
#           '#Ferguson': 2,
#           'officially': 1,
#           'favorite': 1,
#           'use': 1,
#           'thinks': 1,
#           'relevant': 1,
#           'job': 1,
#           "that's": 3,
#           'probably': 1,
#           '@Principia': 4,
#           'bummer': 1,
#           '…': 3,
#           'So': 5,
#           'since': 1,
#           'start': 1,
#           'could': 1,
#           'My': 1,
#           'officers': 1,
#           '’': 1,
#           'go': 2,
#           'around': 2,
#           'gratuitously': 2,
#           'shooting': 2,
#           'bragging': 1,
#           'seedy': 1,
#           'paramilitary': 1,
#           'bars': 1,
#           '"': 7,
#           'agonize': 1,
#           'social': 1,
#           'write': 1,
#           'poetry': 1,
#           'Art': 1,
#           'srsly': 1,
#           'Douglas': 1,
#           'Adams': 1,
#           'called': 1,
#           '@ShannonLeeKiss': 26,
#           "That's": 2,
#           'pot': 1,
#           'calling': 1,
#           'kettle': 1,
#           'Please': 1,
#           'thing': 2,
#           'reverse': 2,
#           "It's": 5,
#           'white': 9,
#           ':)': 1,
#           '@LibertyIsALady': 10,
#           'doubt': 1,
#           '♥': 1,
#           'many': 4,
#           'buy': 1,
#           'racism': 2,
#           'farce': 1,
#           '@joshmhump': 17,
#           'see': 2,
#           'young': 1,
#           'man': 1,
#           'know': 2,
#           'one': 2,
#           'Never': 1,
#           'said': 3,
#           'replying': 1,
#           'racist': 2,
#           'comment': 3,
#           'It': 1,
#           'seems': 2,
#           'non': 1,
#           'Black': 1,
#           'focused': 1,
#           'civil': 1,
#           'disturbances': 1,
#           'dead': 1,
# ...
#           'Michael': 1,
#           'Mannheimer': 1,
#           'break': 1,
#           'story': 1,
#           'His': 1,
#           'website': 1,
#           'doesnt': 1,
#           'react': 1,
#           '@th_christine': 1,
#           'claim': 1,
#           'work': 1,
#           'place': 1,
#           'violence': 1,
#           'Obama': 1,
#           'Me': 1,
#           'way': 1,
#           'world': 1,
#           'Leftists': 1,
#           'truth': 1,
#           'NOT': 1,
#           'LIES': 1,
#           'different': 1,
#           'faiths': 1,
#           'unlike': 1,
#           'RIGHT': 1,
#           '#USURY': 1,
#           'TREASON': 1,
#           'dumb': 1,
#           'masses': 1,
#           '@JackJolis': 1,
#           '#': 4,
#           'wings': 1,
#           'Wa': 1,
#           'keUp': 1,
#           'America': 1,
#           'I': 1,
#           'Facts': 1,
#           'USURY': 1}),
#  Counter({'Report': 6,
#           ':': 12,
#           'Germanwings': 6,
#           'Co-Pilot': 6,
#           'Treated': 5,
#           'For': 6,
#           'Depression': 6,
#           'http://t.co/ewynIJ23A2': 1,
#           '@nprnews': 20,
#           'This': 2,
#           'embarrassing': 1,
#           ',': 24,
#           'racist': 1,
#           'ableist': 1,
#           'otherwise': 1,
#           'appalling': 1,
#           'reporting': 1,
#           '.': 29,
#           'What': 1,
#           'u': 1,
#           'know': 1,
#           'That': 2,
#           'thought': 1,
#           'beginning': 1,
#           'Along': 1,
#           '~': 1,
#           '6': 1,
#           '%': 1,
#           'global': 1,
#           'population': 1,
#           'apparently': 1,
#           'must': 1,
#           'pointed': 1,
#           'NOT': 1,
#           'flown': 1,
#           'planes': 1,
#           'mountainsides': 1,
#           'Inform': 1,
#           '!': 4,
#           'Please': 1,
#           'participate': 1,
#           'sensationalism': 1,
#           'stigmatise': 1,
#           'depression': 5,
#           '@justincapps': 1,
#           'exactly': 1,
#           'stigmatizing': 1,
#           'mental': 2,
#           'illness': 2,
#           'THis': 1,
#           'time': 1,
#           'cost': 1,
#           '@amras': 1,
#           'Came': 1,
#           'say': 1,
#           'Tweets': 1,
#           'powerful': 1,
#           'statements': 1,
#           'convey': 1,
#           'far': 1,
#           '140': 1,
#           'characters': 1,
#           'whether': 1,
#           'intended': 1,
#           'So': 1,
#           'else': 1,
#           'going': 1,
#           'forbid': 1,
#           'people': 5,
#           '?': 6,
#           "I'd": 1,
#           'like': 1,
#           'list': 1,
#           '-': 1,
#           "I've": 1,
#           'diagnosed': 1,
#           'since': 1,
#           'I': 4,
#           'teen': 1,
#           '“': 5,
#           'received': 1,
#           '18': 1,
#           'months': 1,
#           'psychiatric': 1,
#           'treatment': 1,
#           'http://t.co/UaNq0REgiP': 1,
#           '”': 4,
#           'Raise': 1,
#           'virtual': 1,
#           'hand': 3,
#           'killed': 1,
#           '🙋': 1,
#           '#nostigma': 1,
#           'MT': 2,
#           'Tx': 1,
#           'Some': 1,
#           'may': 1,
#           'mentally': 1,
#           'ill': 1,
#           ';': 1,
#           'murderers': 1,
#           'But': 1,
#           'things': 1,
#           'go': 1,
#           'story': 1,
#           'serves': 1,
#           'airlines': 1,
#           'bc': 1,
#           'blames': 1,
#           'something': 1,
#           'identifiable': 1,
#           'ppl': 1,
#           'feel': 1,
#           'safe': 1,
#           'even': 1,
#           'thing': 1,
#           'cause': 1,
#           'http://t.co/38qVFIkC5v': 1,
#           'OK': 1,
#           'http://t.co/6R9oHad22d”@JonRottenberg': 1,
#           '#depression': 1,
#           'Cue': 1,
#           'bashing': 1,
#           'http://t.co/2CEYFKu69M': 1,
#           '1': 1,
#           'He': 1,
#           'flying': 1,
#           '2': 2,
#           'Foreign': 1,
#           'carriers': 1,
#           'STILL': 1,
#           'cabin': 1,
#           'times': 1,
#           'policy': 1,
#           'Why': 1,
#           '@MorningEdition': 4,
#           'relevant': 1,
#           'let': 2,
#           '’': 4,
#           'careful': 2,
#           'If': 2,
#           'red': 2,
#           'flag': 2,
#           'end': 2,
#           'one': 4,
#           'fly': 2,
#           'drive': 2,
#           'buses': 1,
#           'teach': 2,
#           'kids': 1,
#           'etc': 2,
#           "LET'S": 1,
#           'STIGMATIZE': 1,
#           'THIS': 1,
#           'INCREDIBLY': 1,
#           'COMMON': 1,
#           'ILLNESS': 1,
#           '@david_burns': 5,
#           'real': 1,
#           'question': 1,
#           'WHY': 1,
#           'many': 1,
#           'Americans': 1,
#           'depressed': 1,
#           'Cant': 1,
#           'contributed': 1,
#           'chemical': 1,
#           'embalance': 1,
#           '@SPLaws': 2,
#           'Germans': 1,
#           'evidently': 1,
#           'Or': 1,
#           'least': 1,
#           'right': 2,
#           'David': 1,
#           'jumped': 1,
#           'As': 1,
#           'citizen': 1,
#           'overactive': 1,
#           'imagination': 1,
#           'pilot': 1,
#           '4': 1,
#           'reasons': 1,
#           'TBD': 1,
#           'point': 1,
#           'worry': 1,
#           'knee-jerk': 1,
#           'over-reactions': 1,
#           'Not': 1,
#           "we're": 1,
#           'prone': 1,
#           'America': 1,
#           'anything': 1,
#           'Wow': 1,
#           'yeah': 1,
#           'NPR': 1,
#           "I'm": 1,
#           'chewing': 1,
#           'bit': 1,
#           '...': 1,
#           'Good': 1,
#           'call': 1,
#           'DB': 1,
#           'You': 1,
#           'paint': 1,
#           'rather': 1,
#           'fine': 1,
#           'portrait': 1,
#           'type': 1,
#           'large': 1,
#           'brush': 1,
#           'use': 1,
#           'whitewash': 1,
#           'barn': 1,
#           '#': 2,
#           'no': 1,
#           'stigma': 1}),
#  Counter({'#Germanwings': 1,
#           '#CoPilot': 1,
#           'recent': 1,
#           'Muslim': 4,
#           'convert': 1,
#           'well': 1,
#           'psychiatric': 1,
#           'patient': 1,
#           '.': 24,
#           '#ISIS': 1,
#           'lauding': 1,
#           'hero': 1,
#           'http://t.co/J29Y3tDjOP': 1,
#           '@Zone6Combat': 20,
#           'Noooooooooooooooo': 1,
#           'Who': 1,
#           'would': 1,
#           'EVER': 1,
#           'thought': 1,
#           'great': 1,
#           'fact': 1,
#           'checking': 1,
#           'idiots': 2,
#           '@ellepuntopi': 3,
#           'È': 1,
#           'bellissimo': 1,
#           'che': 1,
#           'mettono': 1,
#           'la': 1,
#           'foto': 1,
#           'dove': 1,
#           "c'è": 1,
#           'scritto': 1,
#           '"': 4,
#           'known': 2,
#           'terrorist': 4,
#           'asserendo': 1,
#           'il': 1,
#           'contrario': 1,
#           '@DanOClunaigh': 4,
#           'Find': 1,
#           'article': 1,
#           ',': 13,
#           'complete': 1,
#           'w': 2,
#           '/': 2,
#           'screenshots': 1,
#           'personal': 1,
#           'Facebook': 2,
#           'acct': 1,
#           'Jihadist': 1,
#           'rhetoric': 1,
#           'calling': 1,
#           'ppl': 1,
#           '@SimZombie': 1,
#           'Not': 1,
#           'watch': 1,
#           'list': 1,
#           'mean': 1,
#           'jihadist': 1,
#           'sympathies': 1,
#           'beliefs': 1,
#           'better': 1,
#           'yet': 1,
#           'link': 1,
#           'ridiculous': 1,
#           'tweet': 1,
#           'everyone': 1,
#           'read': 2,
#           'The': 2,
#           "'": 2,
#           'Andreas': 1,
#           'Lubitz': 1,
#           'Fans': 1,
#           'page': 2,
#           'set': 1,
#           'brainless': 1,
#           'fool': 1,
#           'variety': 1,
#           'agent': 1,
#           'provocateur': 1,
#           "It's": 1,
#           'As': 2,
#           'say': 1,
#           '#facepalm': 1,
#           'Yeah': 1,
#           "I'm": 3,
#           'delusional': 1,
#           'one': 2,
#           'He': 1,
#           '10': 1,
#           'mins': 1,
#           'microphone': 1,
#           'whole': 1,
#           'world': 2,
#           'listening': 1,
#           'voice': 1,
#           'recorder': 1,
#           'political': 2,
#           'message': 1,
#           '?': 6,
#           'could': 1,
#           'aimed': 1,
#           'plane': 1,
#           'Sagrada': 1,
#           'Familia': 1,
#           'Trade': 1,
#           'Center': 1,
#           'Barcelona': 1,
#           'come': 1,
#           'WHERE': 1,
#           'speak': 1,
#           "Let's": 1,
#           'see': 1,
#           'needs': 1,
#           'evidence': 5,
#           '!': 1,
#           'Um': 1,
#           'yes': 1,
#           'terrorism': 2,
#           'definition': 1,
#           'Lack': 1,
#           'substantial': 2,
#           'motives': 3,
#           'means': 1,
#           'found': 1,
#           'Yep': 1,
#           'sound': 1,
#           'logic': 1,
#           '...': 1,
#           'investigation': 1,
#           'works': 1,
#           'among': 1,
#           'professionals': 1,
#           'hysterical': 1,
#           'islamophobes': 1,
#           'actually': 1,
#           'kidding': 1,
#           'Please': 1,
#           'point': 2,
#           'Evidence': 1,
#           'pls': 1,
#           'Even': 1,
#           'bit': 1,
#           '::': 2,
#           ':': 3,
#           'yawn': 1,
#           'http://t.co/NjBemt7cHo': 1,
#           '@OkKelly22': 3,
#           "there's": 1,
#           'absolutely': 1,
#           'copilot': 1,
#           'either': 2,
#           'Now': 1,
#           'getting': 1,
#           'back': 1,
#           'absence': 1,
#           'ANY': 1,
#           'assertions': 1,
#           'groundless': 1,
#           'make': 1,
#           "Didn't": 1,
#           'assume': 1,
#           'u': 2,
#           'thread': 1,
#           'saw': 1,
#           'tiresome': 1,
#           'word': 1,
#           'mention': 1,
#           'pilot': 1,
#           'r': 1,
#           'non': 1,
#           'curious': 1,
#           'concerns': 1,
#           'implication': 1,
#           'Islamic': 1,
#           'involvement': 2,
#           'I': 2,
#           'concern': 1,
#           'Islamist': 1,
#           'looks': 1,
#           'like': 1,
#           'good': 1,
#           'European': 1,
#           'Christian': 1,
#           'anything': 1,
#           '#': 4,
#           'German': 1,
#           'wings': 1,
#           'CoPilot': 1,
#           'SIS': 1,
#           'face': 1,
#           'palm': 1}),
#  Counter({'GERMAN': 1,
#           'NEWS': 1,
#           'REPORT': 1,
#           ':': 1,
#           'Co-Pilot': 1,
#           'Germanwings': 1,
#           'Airbus': 1,
#           'Was': 1,
#           'MUSLIM': 1,
#           'CONVERT': 1,
#           '…': 1,
#           '’': 2,
#           'Hero': 1,
#           'Islamic': 1,
#           'State': 1,
#           '?': 4,
#           'http://t.co/Pw2kxje31m': 1,
#           'via': 1,
#           '@gatewaypundit': 8,
#           '@jjauthor': 7,
#           'knew': 2,
#           'scarf': 1,
#           'wearing': 1,
#           'photo': 1,
#           'meant': 1,
#           'trouble': 1,
#           '!': 3,
#           '.': 6,
#           'I': 3,
#           'Those': 1,
#           'crazy': 1,
#           'bastards': 1,
#           'ones': 1,
#           'evil': 1,
#           'enough': 1,
#           'shit': 1,
#           'like': 1,
#           'terrorism': 1,
#           'Hmmm.Doesn': 1,
#           "'": 1,
#           'pundit': 1,
#           'mean': 1,
#           'joke': 1,
#           'seen': 1,
#           'news': 1,
#           "Isn't": 1,
#           'Islam': 1,
#           'wonderfully': 1,
#           'peaceful': 2,
#           'religion': 1,
#           'wonder': 1,
#           'Iran': 1,
#           'centrifuges': 1,
#           'O': 1,
#           'gave': 1,
#           '@DesireeAaron': 1,
#           'surprise': 1,
#           'MSM': 1,
#           'refuses': 1,
#           'say': 1,
#           'muslim': 2,
#           'Just': 1,
#           'mental': 1,
#           'case': 1,
#           'As': 1,
#           '/': 1,
#           'jihads': 1}),
#  Counter({'BREAKING': 1,
#           ':': 1,
#           'German': 1,
#           'Media': 1,
#           'Site': 1,
#           'Says': 1,
#           'Germanwings': 2,
#           'Co-Pilot': 1,
#           'Was': 1,
#           'Muslim': 3,
#           'Convert': 1,
#           'http://t.co/bTKvcLMN60': 1,
#           'via': 1,
#           '@anyclinic': 24,
#           '@RWSurferGirl': 25,
#           'mental': 2,
#           'illness': 1,
#           'girlfriend': 2,
#           'discovered': 1,
#           "he's": 1,
#           'convert': 1,
#           'I': 3,
#           'question': 1,
#           'relevancy': 1,
#           'religion': 1,
#           'stability': 1,
#           ',': 8,
#           'Is': 2,
#           'claim': 2,
#           'radicalism': 1,
#           '?': 4,
#           "I've": 1,
#           'seen': 1,
#           'several': 1,
#           'smaller': 1,
#           'websites': 1,
#           'proclaim': 1,
#           'thing': 1,
#           '.': 12,
#           "I'm": 2,
#           'waiting': 1,
#           'confirmation': 1,
#           'retweeting': 1,
#           'legit': 1,
#           'news': 1,
#           'sight': 1,
#           'It': 1,
#           'looks': 1,
#           'suspicious': 1,
#           'true': 3,
#           'said': 1,
#           'cover': 1,
#           'incompetence': 1,
#           'confused': 1,
#           'read': 2,
#           'suffering': 1,
#           'depression': 1,
#           '&': 1,
#           'DRs': 1,
#           'notes': 1,
#           'excusing': 1,
#           'work': 1,
#           '@JohnnyUtah27': 4,
#           "it'll": 1,
#           'awhile': 1,
#           'let': 1,
#           'little': 1,
#           'jewel': 1,
#           '!': 6,
#           'dam': 1,
#           'thought': 1,
#           'muslim': 1,
#           'wonder': 1,
#           'depreased': 1,
#           '@CedarStArt': 2,
#           'Hah': 1,
#           'Literally': 1,
#           'first': 2,
#           'word': 1,
#           'plane': 1,
#           'crash': 1,
#           '"': 2,
#           'Not': 1,
#           'terrorism': 1,
#           'Time': 1,
#           'tell': 1,
#           '@MrJamieD': 2,
#           "can't": 1,
#           'sain': 1,
#           'cut': 1,
#           'heads': 1,
#           'would': 2,
#           'know': 1,
#           'thirty': 1,
#           'seconds': 1,
#           '...': 2,
#           '@weekiwachee03': 2,
#           'In': 1,
#           'fairness': 1,
#           'muslims': 1,
#           'story': 1,
#           'unsubstantiated': 1,
#           'croc': 1,
#           'source': 1,
#           '154': 1,
#           'followers': 1,
#           '@FredSanford13': 2,
#           'A': 1,
#           'good': 1,
#           'rumor': 1,
#           'start': 1,
#           'somewhere': 1,
#           'probably': 2,
#           'nonsense': 2,
#           'though': 1,
#           'yup': 1,
#           'painting': 1,
#           'narrative': 1,
#           'They': 1,
#           'well': 1,
#           'embarrassing': 1,
#           'conservative': 1,
#           'sites': 1,
#           'publish': 1,
#           'makes': 1,
#           'look': 1,
#           'like': 2,
#           'daily': 1,
#           'kos': 1,
#           'yes': 1,
#           'No': 1,
#           'Way': 1,
#           '😵': 1,
#           'Especially': 1,
#           'since': 2,
#           'posts': 1,
#           'twitter': 1,
#           'BS': 1,
#           'nothing': 1,
#           'taken': 2,
#           'granted': 1,
#           'find': 1,
#           'suicide': 1,
#           'revelation': 1,
#           'Screenshots': 1,
#           'social': 1,
#           'media': 1,
#           'enough': 1,
#           'turns': 1,
#           'guy': 1,
#           'handle': 1,
#           'losing': 1,
#           'job': 1,
#           'dumping': 1,
#           'added': 1,
#           'problem': 1,
#           '..': 2,
#           'man': 1,
#           'sick': 1,
#           'allowed': 1,
#           'fly': 1,
#           'doctor': 1,
#           'mentioned': 1,
#           'proactive': 1,
#           '@SoTrophyHntrs': 2,
#           "It's": 1,
#           'legitimate': 1,
#           '@rwsurfergirl': 2,
#           "'": 1,
#           'honesty': 1,
#           '@pbanik': 1,
#           'Away': 1,
#           'troll': 1,
#           'If': 1,
#           'trolls': 1,
#           '/': 1,
#           'follow': 1,
#           'Some': 1,
#           'tweets': 1,
#           'based': 1,
#           'dishonesty': 1})]

# %% [markdown]
# # Text Classification (4 marks)

# %% [markdown]
# ### Question 5 (1.0 mark)
#
# **Instructions**: Here we are interested to do text classification, to predict, given a tweet and its reactions, whether it is a rumour or not. The task here is to create training, development and test partitions from the preprocessed events and convert the bag-of-words representation into feature vectors.
#
# **Task**: Using scikit-learn, create training, development and test partitions with a 60%/20%/20% ratio. Remember to preserve the ratio of rumour/non-rumour events for all your partitions. Next, turn the bag-of-words dictionary of each event into a feature vector, using scikit-learn `DictVectorizer`.

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.model_selection import train_test_split

vectorizer = DictVectorizer()

###
# Your answer BEGINS HERE
###
X = preprocessed_rumour_events + preprocessed_nonrumour_events
y = []

for i in range(len(preprocessed_rumour_events)):
    y.append('rumour')
for j in range(len(preprocessed_nonrumour_events)):
    y.append('not-rumour')

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=345)
X_train, X_dev, y_train, y_dev = train_test_split(X_train, y_train, stratify=y_train, test_size=0.2, random_state=345)

training_data = vectorizer.fit_transform(X_train)
dev_data = vectorizer.transform(X_dev)
test_data = vectorizer.transform(X_test)

###
# Your answer ENDS HERE
###

print("Vocabulary size =", len(vectorizer.vocabulary_))
# Out:
# Vocabulary size = 28724

# %%
dev_data
# Out:
# <240x30350 sparse matrix of type '<class 'numpy.float64'>'
# 	with 22534 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ### Question 6 (2.0 mark)
#
# **Instructions**: Now, let's build some classifiers. Here, we'll be comparing Naive Bayes and Logistic Regression. For each, you need to first find a good value for their main regularisation (hyper)parameters, which you should identify using the scikit-learn docs or other resources. Use the development set you created for this tuning process; do **not** use cross-validation in the training set, or involve the test set in any way. You don't need to show all your work, but you do need to print out the accuracy with enough different settings to strongly suggest you have found an optimal or near-optimal choice. We should not need to look at your code to interpret the output.
#
# **Task**: Implement two text classifiers: Naive Bayes and Logistic Regression. Tune the hyper-parameters of these classifiers and print the task performance for different hyper-parameter settings.

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

###
# Your answer BEGINS HERE
###

alpha_to_test = [0.001, 0.01, 0.05, 0.1, 0.2, 0.3, 0.5, 0.6, 0.7, 0.8, 0.9, 1]
nbcs = [MultinomialNB(alpha=a) for a in alpha_to_test]

c_to_test = [0.001, 0.01, 0.05, 0.1, 0.3, 0.5, 0.7, 1, 10, 100, 1000, 5000]
lrcs = [LogisticRegression(C=c, random_state=345) for c in c_to_test]

def fit_multiple_classifiers(clfs, X_train, y_train, X_dev, y_dev, method):
    for clf in clfs:
        clf.fit(X_train, y_train)
        predictions = clf.predict(X_dev)
        if method == 'nb':
            print (f"accuracy for alpha = {clf.alpha}: {accuracy_score(y_dev, predictions)}")
        elif method == 'lr':
            print (f"accuracy for c = {clf.C}: {accuracy_score(y_dev, predictions)}")


###
# Your answer ENDS HERE
###

# %%
print("Tuning Naive Bayes:\n")
fit_multiple_classifiers(nbcs, training_data, y_train, dev_data, y_dev, 'nb')
print("\n")
print("Tuning Logistic Regression:\n")
fit_multiple_classifiers(lrcs, training_data, y_train, dev_data, y_dev, 'lr')
# Out:
# Tuning Naive Bayes:
#
# accuracy for alpha = 0.001: 0.8041666666666667
# accuracy for alpha = 0.01: 0.8333333333333334
# accuracy for alpha = 0.05: 0.8583333333333333
# accuracy for alpha = 0.1: 0.8458333333333333
# accuracy for alpha = 0.2: 0.8416666666666667
# accuracy for alpha = 0.3: 0.8416666666666667
# accuracy for alpha = 0.5: 0.8416666666666667
# accuracy for alpha = 0.6: 0.85
# accuracy for alpha = 0.7: 0.8541666666666666
# accuracy for alpha = 0.8: 0.8583333333333333
# accuracy for alpha = 0.9: 0.8583333333333333
# accuracy for alpha = 1: 0.8625
#
#
# Tuning Logistic Regression:
#
# accuracy for c = 0.001: 0.7666666666666667
# accuracy for c = 0.01: 0.825
# accuracy for c = 0.05: 0.8625
# accuracy for c = 0.1: 0.8583333333333333
# accuracy for c = 0.3: 0.8541666666666666
# accuracy for c = 0.5: 0.8583333333333333
# accuracy for c = 0.7: 0.8541666666666666
# accuracy for c = 1: 0.8583333333333333
# accuracy for c = 10: 0.8583333333333333
# accuracy for c = 100: 0.8583333333333333
# accuracy for c = 1000: 0.8625
# accuracy for c = 5000: 0.8583333333333333

# %% [markdown]
# ### Question 7 (1.0 mark)
#
# **Instructions**: Using the best settings you have found, compare the two classifiers based on performance in the test set. Print out both accuracy and macro-averaged F-score for each classifier. Be sure to label your output.
#
# **Task**: Compute test performance in terms of accuracy and macro-averaged F-score for both Naive Bayes and Logistic Regression, using optimal hyper-parameter settings.

# %%
# We will use alpha = 1 and C = 1000
nb_best = MultinomialNB(alpha=1)
lr_best = LogisticRegression(C=1000)

nb_best.fit(training_data, y_train)
lr_best.fit(training_data, y_train)

nb_prediction = nb_best.predict(test_data)
lr_prediction = lr_best.predict(test_data)

print("Report for Naive Bayes:\n")
print(classification_report(y_test, nb_prediction))
print(f"Accurary: {accuracy_score(y_test, nb_prediction)}")
print("\n")

print("Report for Logistic Regression:\n")
print(classification_report(y_test, lr_prediction))
print(f"Accurary: {accuracy_score(y_test, lr_prediction)}")
# Out:
# Report for Naive Bayes:
#
#              precision    recall  f1-score   support
#
#  not-rumour       0.85      0.91      0.88       200
#      rumour       0.79      0.67      0.72       100
#
# avg / total       0.83      0.83      0.83       300
#
# Accurary: 0.83
#
#
# Report for Logistic Regression:
#
#              precision    recall  f1-score   support
#
#  not-rumour       0.82      0.91      0.86       200
#      rumour       0.76      0.60      0.67       100
#
# avg / total       0.80      0.80      0.80       300
#
# Accurary: 0.8033333333333333
